# %% [markdown]
# # Manila - Jeepney Route Connection and Genetic Algorithm - Modified CITY_GRAPH

# %% [markdown]
# ## Route Connection and Genetic Algorithm Functions

# %% [markdown]
# ### Setting Up

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import networkx as nx
import shapely
import folium
import geojson
import math
import osmnx as ox
from rtree import index as rtree_index
import pickle
import copy
import utm

from shapely.ops import unary_union
from shapely.geometry import Polygon, MultiPolygon, LineString, Point
from geopy.distance import geodesic
from shapely.ops import split

from __future__ import absolute_import, division
from math import radians, sin, cos, sqrt, atan2, exp, log
import webbrowser
import random
from scipy.spatial import KDTree
from scipy.spatial.distance import euclidean

ox.settings.log_console=True
ox.settings.use_cache=True

WALKING_DISTANCES = [300,550,800]
MAX_DISTANCE = 15
CONNECTION_TYPES = ["Default", "Area", "Degree", "Mixed"]
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_25960\567748778.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Defining classes for the dataframes      
class stopCandidate:
    def __init__(self, lat, long, isTranspo, id, area):
        self.lat = lat
        self.long = long
        self.isTranspo = isTranspo
        self.enabled = False
        self.id = id #Stop ID
        self.area = area
        self.degree = 0
        
    def enable(self):
        self.enabled = True
        
    def disable(self):
        self.enabled = False
        
    def getLat(self):
        return self.lat
    
    def getLong(self):
        return self.long
    
    def getArea(self):
        return self.area
    
    def getDegree(self):
        return self.degree
    
class networkObj:
    def __init__(self, routes, reversed_routes, stops, reversed_stops, graph, conn_type, walk_distance):
        self.routes = routes
        self.reversed_routes = reversed_routes
        self.stops = stops
        self.reversed_stops = reversed_stops
        self.fitness_score = 0
        self.graph = graph
        self.conn_type = conn_type
        self.walk_distance = walk_distance
        
class Route:
    def __init__(self, route, route_id, length):
        self.route = route
        self.route_id = route_id
        self.length = length
        self.reverse = None

# %%
# For units
def degrees_to_meters(angle_degrees):
    return angle_degrees * 6371000 * math.pi / 180

def meters_to_degrees(distance_meters):
    return distance_meters / 6371000 * 180 / math.pi

# %%
# Import and Export networks or graphs to pickle
def export_networks(networks, path):
    with open(path, 'wb') as f:
        pickle.dump(networks, f)

def import_networks(path):
    with open(path, 'rb') as f:
        routes = pickle.load(f)
    return routes

# %% [markdown]
# #### Graph and Features

# %%
# NOTE: SELECT THE CITY HERE, COMMENT OUT THE REMAINING CITIES
select_city = "Manila, Philippines"
city_file = 'map/Manila.graphml'


# GENERATION OF MAIN CITY GRAPH
# IF FIRST TIME RUNNING, RUN THIS CODE TO GENERATE THE GRAPH
def generate_graph():
    mode = 'drive'
    graph = ox.graph_from_place(select_city, network_type = mode) # Generate graph of Metro manila
    ox.save_graphml(graph, city_file) # Save it as a file

def load_graph():
    graph = ox.load_graphml(city_file)
    
    print("Graph loaded successfully")
    print("NUMBER OF EDGES: ", graph.number_of_edges())
    print("NUMBER OF NODES: ", graph.number_of_nodes())
    print('\n')
    return graph

# NOTE: Only run this if you do not have the graph
generate_graph()

# THIS IS THE MAIN GRAPH FOR THE CITY TO BE USED FOR ALL FUNCTIONS
CITY_GRAPH = load_graph()

# Iterate over the edges and assign a unique edge_id
edge_id = 0
for u, v, k in CITY_GRAPH.edges(keys=True):
    CITY_GRAPH[u][v][k]['edge_id'] = edge_id
    edge_id += 1
# Out:
# Graph loaded successfully
# NUMBER OF EDGES:  12617
# NUMBER OF NODES:  4926

# %%
### For Filtering the roads and other features
# GETTING ROADS AND WATERWAYS

# Get all the roads in Manila
road = ox.graph_to_gdfs(CITY_GRAPH,nodes=False, edges=True)


# Get all the roads that are not junctions (ex. Roundabouts, intersection, etc.)
filtered_roads = road[road['junction'].isna()]

# Separate roads whose highway types are only one value and those that are more than 1 (lists)
rows_with_lists = filtered_roads[filtered_roads['highway'].apply(lambda x: isinstance(x, list))]
rows_with_strings = filtered_roads[filtered_roads['highway'].apply(lambda x: isinstance(x, str))]

# Allowed Roads to place stops
filter_options = ['primary', 'secondary', 'tertiary', 'trunk', 'unclassified']

# To separate zones
separation_options = ['primary', 'secondary', 'tertiary', 'unclassified']

# Get the roads whose widths are above the threshold
def check_list(lst):
    return any(x in filter_options for x in lst)

# Download OpenStreetMap data for the area of interest
waterways = ox.features_from_place(select_city, tags={'waterway': True})
filtered_rivers = waterways[waterways['waterway'].isin(['river'])]
filtered_streams = waterways[waterways['waterway'].isin(['stream'])]

# Get all the roads with the allowed road types
filtered_roads_strings = rows_with_strings.loc[rows_with_strings['highway'].isin(filter_options)] 
filtered_roads_lists = rows_with_lists[rows_with_lists['highway'].apply(check_list)]

# Create spatial index
filtered_roads_strings_sindex = filtered_roads_strings.sindex
filtered_roads_lists_sindex = filtered_roads_lists.sindex
filtered_rivers_sindex = filtered_rivers.sindex
filtered_streams_sindex = filtered_streams.sindex

# Total Distance of the allowed road types
TOTAL_NETWORK_ROAD_DISTANCE = 0
for index, row in filtered_roads_strings.iterrows():
    TOTAL_NETWORK_ROAD_DISTANCE += row['length']

# %%
# This function will find which road or river intersects between amenities

def find_intersecting_features(line):
    # Check intersection with filtered roads
    possible_matches_roads = filtered_roads_strings.iloc[list(filtered_roads_strings_sindex.intersection(line.bounds))]
    for index, row in possible_matches_roads.iterrows():
        if line.intersects(row['geometry']) and row['highway'] in separation_options:
            return True

    possible_matches_lists = filtered_roads_lists.iloc[list(filtered_roads_lists_sindex.intersection(line.bounds))]
    for index, row in possible_matches_lists.iterrows():
        if line.intersects(row['geometry']):
            list_highway = row['highway']
            if any(x in separation_options for x in list_highway):
                return True
    
    # Check intersection with filtered rivers
    possible_matches_rivers = filtered_rivers.iloc[list(filtered_rivers_sindex.intersection(line.bounds))]
    for index, row in possible_matches_rivers.iterrows():
        if line.intersects(row['geometry']):
            return True

    # Check intersection with filtered streams
    possible_matches_streams = filtered_streams.iloc[list(filtered_streams_sindex.intersection(line.bounds))]
    for index, row in possible_matches_streams.iterrows():
        if line.intersects(row['geometry']):
            return True
    
    return False

# %%
# Getting all the partner edges (One-way roads that have a partner road that goes the opposite way)


partner_edges = {}
for index, r in filtered_roads_strings.iterrows():
    u1, v1, key1 = index
    if not r['oneway']:
        continue
    road_geometry = r['geometry']
    
    possible_partners = filtered_roads_strings.iloc[list(filtered_roads_strings_sindex.intersection(road_geometry.buffer(0.0005).bounds))]
    for idx, point in possible_partners.iterrows():
        u2, v2, key2 = idx
        if r['edge_id'] != point['edge_id']:
            if point['geometry'].intersects(road_geometry.buffer(0.0005)) and point['oneway'] and r['name'] == point['name']:
                if u1 != v2 and v1 != u2:
                    partner_edges[r['edge_id']] = point['edge_id']

# %% [markdown]
# ### Stop Placement

# %%
# ADD POINTS TO NX GRAPH
# Function to add only points to the networkX graph
# The other functions focuses on adding polygons, this function just iterates and adds points

def add_points_to_graph(graph, graph_to_add):
    for node_key, node_data in graph.nodes.items():
        if 'geometry' in node_data and node_data['geometry'].geom_type in ['Point']:   
            graph_to_add.add_node(node_key, geometry=node_data['geometry'], name=node_data['name'], y=node_data['lat'], amenity=node_data['amenity'],
                                x=node_data['lon'])

# %%
# CREATING STOPS
# It should return a list of coordinates/nodes for stop and a graph of stops
# if residential area, check if the population density

# Global Variables used:
# list_of_stops - List of stops
# graph_of_stops - graph of all stops placed
import random


def place_stops_on_roads(amenity_graph, graph_of_stops, list_of_stops):
    list_relevant_edges_set = []
    string_relevant_edges_set = []
    
    stop_id = 0
    for node_key, node_data in amenity_graph.nodes(data=True):
        # All tranportation points are automatically stops
        if node_data['geometry'].geom_type in ['Point']:
            if node_data['amenity'] == 'transportation':
                # Find the nearest edge to the location point
                nearest_edge = ox.distance.nearest_edges(graph_of_stops, X=node_data['x'], Y=node_data['y'], return_dist=False)
                node1, node2, key = nearest_edge
                edge = graph_of_stops.get_edge_data(node1, node2)
                data = list(edge.values())[0]
            
                
                # get the line
                if 'geometry' not in data:
                    gdf_edges = ox.graph_to_gdfs(graph_of_stops, nodes=False, edges=True)
                    line = gdf_edges.loc[nearest_edge]['geometry']
                    edge_length = gdf_edges.loc[nearest_edge]['length']
                else:
                    line = data['geometry']
                    edge_length = data['length']
                    
                
                if edge_length > 20:
                    # x - lon - 120
                    # y - lat - 14
                    # LineString(lon, lat)
                    # geodesic(lat, lon)
                    
                    print(f"STOP ID: {stop_id}")
                    if node1 < 10000:
                        notice = '!'
                        print(f"SEEN ADDED NODE1{notice} {node1} - {graph_of_stops.nodes[node1]['y']}, {graph_of_stops.nodes[node1]['x']}")
                        
                    if node2 < 10000:
                        notice = '!'
                        print(f"SEEN ADDED NODE2{notice} {node2} - {graph_of_stops.nodes[node2]['y']}, {graph_of_stops.nodes[node2]['x']}")
                        
                    print(f"EDGE NODES ({node1}, {node2})")
                    
                    point_a = (graph_of_stops.nodes[node1]['y'], graph_of_stops.nodes[node1]['x'])
                    point_c = (graph_of_stops.nodes[node2]['y'], graph_of_stops.nodes[node2]['x']) 
                    
                    if len(line.coords) == 2:
                        print("Transpo Stop WAY 1")
                        # Get a random position between the line
                        random_position = random.uniform(0.3 * edge_length, edge_length * 0.7)
                        
                        # Convert to UTM
                        node1_utm = utm.from_latlon(point_a[0], point_a[1])
                        node2_utm = utm.from_latlon(point_c[0], point_c[1])

                        utm_line = LineString([(node1_utm[0], node1_utm[1]), (node2_utm[0], node2_utm[1])])

                        # Calculate the coordinate along the edge at the random position
                        point_on_road_utm = calculate_coordinate_along_edge(utm_line, random_position)
                        to_convert = (point_on_road_utm[0], point_on_road_utm[1], node1_utm[2], node1_utm[3])
                        point_on_road = utm.to_latlon(*to_convert)
                        lon = point_on_road[1]
                        lat = point_on_road[0]
                    else:
                        print("Transpo Stop WAY 2")
                        # Accessing all coordinates
                        coordinates = list(line.coords)
                        coordinates = coordinates[1:-1]
                        # Randomly pick one coordinate
                        point_on_road = random.choice(coordinates)
                        lon = point_on_road[0]
                        lat = point_on_road[1]
                    
                    isTranspo = True
                
                    graph_of_stops.add_node(stop_id, x=lon, y=lat, isTranspo=isTranspo)
                    list_of_stops.append(stopCandidate(lat, lon, True, stop_id, 0))
                
                    # Get the points
                    point_b = (lat, lon) # y,x
                    
                    # Calculate new geometries
                    if len(line.coords) == 2:
                        line_ab = LineString([(point_a[1], point_a[0]), (point_b[1], point_b[0])])
                        line_bc = LineString([(point_b[1], point_b[0]), (point_c[1], point_c[0])])
                    else:
                        result = split(line, Point(point_b[1], point_b[0]))
                        new_lines = [geom for geom in result.geoms]
                        line_ab = new_lines[0]
                        line_bc = new_lines[1]
                    
                    print("POINT B: ", point_b)
                    
                    print("NEW LINES")
                    print(line_ab)
                    print(line_bc)
                    print(f"ORIGINAL LINE: {line}")
                    print("---------")
                    
                    # Calculate the new distances
                    distance_ab = geodesic(point_a, point_b).meters
                    distance_bc = geodesic(point_b, point_c).meters
                    
                    print("NEW DISTANCES")
                    print(distance_ab)
                    print(distance_bc)
                    print(f"ORIGINAL DISTANCE: {data['length']}")
                    print("---------")
                    
                    
                    # Get the edge data and adjust distances
                    edge_data = data.copy()
                    edge_data['length'] = distance_ab
                    edge_data['geometry'] = line_ab
                    graph_of_stops.add_edge(node1, stop_id, **edge_data)
                    
                    edge_data['length'] = distance_bc
                    edge_data['geometry'] = line_bc
                    graph_of_stops.add_edge(stop_id, node2, **edge_data)
                    
                    print(f"HAS EDGE BETWEEN {node1} and {stop_id} : {graph_of_stops.has_edge(node1, stop_id)}")
                    print(f"HAS EDGE BETWEEN {stop_id} and {node2} : {graph_of_stops.has_edge(stop_id, node2)}")

                    # Remove the original edge
                    graph_of_stops.remove_edge(node1, node2)
                    stop_id += 1
                    print()
                
                
        elif node_data['geometry'].geom_type in ['MultiPolygon', 'Polygon']:
            # Get the roads surrounding and inside the node polygons
            buffer_poly = node_data['geometry'].buffer(meters_to_degrees(30))
            relevant_edges = get_relevant_edges(buffer_poly, list_relevant_edges_set, string_relevant_edges_set)
            
            # Calculate the number of stops based on node size and population density
            node_size = degrees_to_meters(node_data['geometry'].area)
            
            # Place stops randomly on these roads
            stop_id = place_stops_along_edges(relevant_edges, buffer_poly, node_size, graph_of_stops, list_of_stops, stop_id)
            

def get_relevant_edges(polygon, list_relevant_edges_set, string_relevant_edges_set):
    relevant_edges = []
    
    # Check intersection with filtered roads
    possible_matches_roads = filtered_roads_strings.iloc[list(filtered_roads_strings_sindex.intersection(polygon.bounds))]
    for index, row in possible_matches_roads.iterrows():
        if polygon.intersects(row['geometry']) and row['highway'] in filter_options:
            row_edge_id = row['edge_id']
            if row_edge_id not in string_relevant_edges_set:
                relevant_edges.append([index, row])
                string_relevant_edges_set.append(row_edge_id)


    possible_matches_lists = filtered_roads_lists.iloc[list(filtered_roads_lists_sindex.intersection(polygon.bounds))]
    for index, row in possible_matches_lists.iterrows():
        if polygon.intersects(row['geometry']):
            list_highway = row['highway']
            if any(x in filter_options for x in list_highway):
                row_edge_id = row['edge_id']
                if row_edge_id not in list_relevant_edges_set:
                    relevant_edges.append([index, row])
                    list_relevant_edges_set.append(row_edge_id)
                
    return relevant_edges

def place_stops_along_edges(edges, polygon, node_size, graph_of_stops, list_of_stops, stop_id):
    # Place stops randomly along the edges within the polygon
    
    if len(edges) > 0:
        for edge in edges:
            # Getting the edge data
            index = edge[0]
            data = edge[1]
            node1 = index[0]
            node2 = index[1]
            
            
            # get the line
            if 'geometry' not in data:
                gdf_edges = ox.graph_to_gdfs(graph_of_stops, nodes=False, edges=True)
                line = gdf_edges.loc[(node1, node2, 0)]['geometry']
                edge_length = gdf_edges.loc[(node1, node2, 0)]['length']
            else:
                line = data['geometry']
                edge_length = data['length'] 
            
            if edge_length > 20:
                # x - lon - 120
                # y - lat - 14
                # LineString(lon, lat)
                # geodesic(lat, lon)
                print(f"Stop ID: {stop_id}")
                
                if node1 < 10000:
                        notice = '!'
                        print(f"SEEN ADDED NODE1{notice} ({node1}, {node2}) - {graph_of_stops.nodes[node1]['y']}, {graph_of_stops.nodes[node1]['x']}")
                        
                if node2 < 10000:
                    notice = '!'
                    print(f"SEEN ADDED NODE2{notice} ({node1}, {node2}) - {graph_of_stops.nodes[node2]['y']}, {graph_of_stops.nodes[node2]['x']}")

                
                # Get the coordinates of the two nodes
                point_a = (graph_of_stops.nodes[node1]['y'], graph_of_stops.nodes[node1]['x'])
                point_c = (graph_of_stops.nodes[node2]['y'], graph_of_stops.nodes[node2]['x'])
                
                if len(line.coords) == 2:
                    print("Along edges WAY 1")
                    # Get a random position between the line
                    random_position = random.uniform(0.3 * edge_length, edge_length * 0.7)
                    
                    # Convert to UTM
                    node1_utm = utm.from_latlon(point_a[0], point_a[1])
                    node2_utm = utm.from_latlon(point_c[0], point_c[1])

                    utm_line = LineString([(node1_utm[0], node1_utm[1]), (node2_utm[0], node2_utm[1])])

                    # Calculate the coordinate along the edge at the random position
                    point_on_road_utm = calculate_coordinate_along_edge(utm_line, random_position)
                    to_convert = (point_on_road_utm[0], point_on_road_utm[1], node1_utm[2], node1_utm[3])
                    point_on_road = utm.to_latlon(*to_convert)
                    lon = point_on_road[1]
                    lat = point_on_road[0]
                else:
                    print("Along edges WAY 2")
                    # Accessing all coordinates
                    coordinates = list(line.coords)
                    coordinates = coordinates[1:-1]
                    # Randomly pick one coordinate
                    point_on_road = random.choice(coordinates)
                    lon = point_on_road[0]
                    lat = point_on_road[1]
                
                # Add the stop to graph and list
                isTranspo = False
                
                graph_of_stops.add_node(stop_id, x=lon, y=lat, isTranspo=isTranspo)
                list_of_stops.append(stopCandidate(lat, lon, False, stop_id, node_size))
                
                # Get the points
                point_b = (lat, lon)
                
                # Calculate new geometries
                
                if len(line.coords) == 2:
                    line_ab = LineString([(point_a[1], point_a[0]), (point_b[1], point_b[0])])
                    line_bc = LineString([(point_b[1], point_b[0]), (point_c[1], point_c[0])])
                else:
                    result = split(line, Point(point_b[1], point_b[0]))
                    new_lines = [geom for geom in result.geoms]
                    line_ab = new_lines[0]
                    line_bc = new_lines[1]
                    
                print("POINT B: ", point_b)
                
                print("NEW LINES")
                print(line_ab)
                print(line_bc)
                print("---------")
                
                # Calculate the new distances
                distance_ab = geodesic(point_a, point_b).meters
                distance_bc = geodesic(point_b, point_c).meters
                
                print("NEW DISTANCES")
                print(distance_ab)
                print(distance_bc)
                print(f"ORIGINAL DISTANCE: {data['length']}")
                print("---------")

                # Add the new distances and new geometries
                edge_data = data.copy()
                edge_data['length'] = distance_ab
                edge_data['geometry'] = line_ab
                graph_of_stops.add_edge(node1, stop_id, **edge_data)
                
                edge_data['length'] = distance_bc
                edge_data['geometry'] = line_bc
                graph_of_stops.add_edge(stop_id, node2, **edge_data)
                
                print(f"HAS EDGE BETWEEN {node1} and {stop_id} : {graph_of_stops.has_edge(node1, stop_id)}")
                print(f"HAS EDGE BETWEEN {stop_id} and {node2} : {graph_of_stops.has_edge(stop_id, node2)}")

                # Remove the original edge
                graph_of_stops.remove_edge(node1, node2)
                stop_id += 1
                print()
                    
    return stop_id
        

def calculate_coordinate_along_edge(edge, position):
    # Calculate the coordinate along the edge at the given position
    point = edge.interpolate(position)
    return point.x, point.y

# %% [markdown]
# ### Route Network Generation

# %%
# V2 - Graph with the snapping function
# Generate Route Network from connected routes

# Global Variables used:
# graph_of_stops - Graph of stops that will be used to create routes
def generate_route_network(stop_nodes, max_walking_dist, max_stops, max_routes, graph_of_stops, city_area_sum, connection_type="Default"):
    overall_graph = nx.MultiDiGraph() # The route network graph
    next_nodes = [n for n in stop_nodes]
    enable_stop_nodes(next_nodes)
    route_network = []
    reverse_route_network = []
    num_routes = 0 # Count number of routes

    while num_routes < max_routes:
        route_id = f'{num_routes}-A' # This will be used as a key for the edge
        next_nodes = [n for n in stop_nodes] # Resets the list of nodes so that nodes can be reused in a different
        selected_node = random.choice(next_nodes) # For the first node
        next_nodes.remove(selected_node)
        route_gen, route_length = generate_route(selected_node, next_nodes, max_walking_dist, connection_type, max_stops, overall_graph, city_area_sum, route_id, graph_of_stops)
        
        if len(route_gen) > 1:  
            new_route = Route(route_gen, route_id, route_length) # Create a new route object to store the Route ID and the route itself
            
            # Snap it to the graph
            add_to_graph(route_gen, overall_graph, graph_of_stops, route_id)
            
            # Get the reverse route
            reverse_route = get_reverse_route(new_route, graph_of_stops, overall_graph, max_walking_dist)
            
            route_network.append(new_route)
            reverse_route_network.append(reverse_route)
            num_routes += 1
               
    return route_network, overall_graph, reverse_route_network

def add_to_graph(route, overall_graph, graph_of_stops, route_id):
    
    # Directly add nodes based on node identifiers
    for connection in route:
        overall_graph.add_node(connection[0], **graph_of_stops.nodes[connection[0]]) # The origin
        overall_graph.add_node(connection[-1], **graph_of_stops.nodes[connection[-1]]) # The destination
        
        distance_travelled = 0
        # Get the total distance from point A to point B
        for i in range(len(connection)-1):
            node_data = graph_of_stops.nodes[connection[i]]
            next_node_data = graph_of_stops.nodes[connection[i+1]]
            distance_travelled += haversine(node_data['y'], node_data['x'], next_node_data['y'], next_node_data['x'])
        
        # Finally, Add the edge
        overall_graph.add_edge(connection[0], connection[-1], key=route_id, road_path = connection, distance = distance_travelled) # Add edge
        

# Generate route from stop nodes
def generate_route(source, next_nodes, max_walking_dist, connection_type, max_stops, network_graph, city_area_sum, route_id, graph_of_stops):
    short_route_list = [] # List of nx.shortest_path results
    totalDistance = 0
    orig_node = source
    num_stops = 0 # Count number of stops
    
    # CONFIGURATION
    max_tries = 3 # This is the max number of tries before breaking the loop || To avoid longer runtimes
    current_tries = 0

    while totalDistance < MAX_DISTANCE and num_stops < max_stops:
        
        #print(f"Selected node is {selected_node.getLat()}, {selected_node.getLong()}")
        enable_surrounding_nodes(next_nodes)
        disable_surrounding_nodes(next_nodes, orig_node, max_walking_dist)
        enabled_nodes = [n for n in next_nodes if n.enabled]
        if len(enabled_nodes) == 0:
            break
        
        #print(f"{len(enabled_nodes)} nodes out of {len(next_nodes)}")
        dest_node = get_enabled_node_with_highest_edge_probability(orig_node, enabled_nodes, connection_type, city_area_sum, network_graph) # Getting the destination node
        
        if (dest_node == None or dest_node.id == orig_node.id):
            break
        
        # Remove it as a candidate
        next_nodes.remove(dest_node)
        
        # This is to check if there is already an exiting edge in the route. If true, then it should not connect
        connection_edge1 = network_graph.has_edge(orig_node.id, dest_node.id, route_id)
        connection_edge2 = network_graph.has_edge(dest_node.id, orig_node.id, route_id)
        
        # If there is no possible path or there is atleast one existing edge, do not connect
        if not nx.has_path(graph_of_stops, orig_node.id, dest_node.id) or connection_edge1 or connection_edge2:
            current_tries += 1
            if current_tries == max_tries:
                break
        else:
            shortest_route = nx.shortest_path(graph_of_stops, orig_node.id, dest_node.id, weight='length')
            distance_travelled = 0
            # Get the total distance from point A to point B
            for i in range(len(shortest_route)-1):
                node_data = graph_of_stops.nodes[shortest_route[i]]
                next_node_data = graph_of_stops.nodes[shortest_route[i+1]]
                
                distance_travelled += haversine(node_data['y'], node_data['x'], next_node_data['y'], next_node_data['x'])

            # Checks if it does not exceed the max distance
            if totalDistance + distance_travelled <= MAX_DISTANCE:
                
                # Updating local degree count used for connection probability
                orig_node.degree += 1
                dest_node.degree += 1
                
                totalDistance += distance_travelled
                short_route_list.append(shortest_route)
                num_stops += 1
                
                orig_node = dest_node # Now change the origin to the destination
            else:
                break
    if len(short_route_list) > 4 and totalDistance > 7:
        print(f"# OF CONNECTIONS AND TOTAL DISTANCE: {len(short_route_list)} - {totalDistance}")
        return short_route_list, totalDistance
    
    else:
        return [], []

# Disable surrounding nodes
def disable_surrounding_nodes(next_nodes, source_node, max_distance):
    max_radius = 2000 # This is max radius in which all nodes outside will be disabled
    source = (source_node.getLat(), source_node.getLong())
    
    for node in next_nodes:
        point = (node.getLat(), node.getLong())
        distance_to_source = geodesic(source, point).meters
        if distance_to_source <= max_distance or distance_to_source > max_radius:
            node.disable()
            
# Enable surrounding nodes
def enable_surrounding_nodes(next_nodes):
    for node in next_nodes:
        node.enable()
        
def get_enabled_node_with_highest_edge_probability(source_node, enabled_nodes, connection_type, city_area_sum, network_graph):

    prob_list = []
    for n in enabled_nodes:
        edge_prob = get_edge_probability(source_node, n, len(enabled_nodes), connection_type, city_area_sum, network_graph)
        prob_list.append(edge_prob)
    
    
    min_score = min(prob_list)
    if min_score < 0: # Shift the scores to ensure all are positive
        prob_list = [score - min_score for score in prob_list]
    total = sum(prob_list)
    selection_p = [score / total for score in prob_list]
    
    chosen_node = np.random.choice(enabled_nodes, 1, p=selection_p)[0]    

    return chosen_node

# Probabilities of candidate nodes based on distance, area, node degree, and if transpo stop
def get_edge_probability(source, destination, normalization_factor, connection_type, city_area_sum, network_graph):
    source_coord = [source.getLat(), source.getLong()]
    dest_coord = [destination.getLat(), destination.getLong()]

    base_prob = exp(-(euclidean(source_coord, dest_coord))) / float(normalization_factor)
    
    # If there is already an existing edge between source and destination, decrease the probability
    if network_graph.has_edge(source.id, destination.id):
        base_prob *= 0.5 # The penalty

    if connection_type == "Default":
        if destination.isTranspo:
            return base_prob * 1.5
        return base_prob
    elif connection_type == "Area":
        if destination.isTranspo:
            return base_prob * 1.5
        return base_prob * (1 + (destination.getArea() / city_area_sum))
    elif connection_type == "Degree":
        if destination.isTranspo:
            return base_prob * 1.5 * (1 + (destination.getDegree() / 10))
        return base_prob * (1 + (destination.getDegree() / 10))

def radius(stops):
    circles = []
    for stop in stops:
        stop_point = Point(stop[1], stop[0])  # Create a Point object from [lat, lon] coordinates
        circle = stop_point.buffer(radius / 111000)  # Buffer the Point to create a circle (assuming 1 degree is approximately 111000 meters)
        circles.append(circle)
    return circles

def enable_stop_nodes(stop_nodes):
    for n in stop_nodes:
        n.enable()

def all_nodes_disabled(stop_nodes):
    return get_num_disabled(stop_nodes) == len(stop_nodes)

def get_num_disabled(stop_nodes):
    return sum(1 for n in stop_nodes if not n.enabled)

def haversine(lat1, lon1, lat2, lon2):
    # Use geopy's geodesic function to calculate the distance
    distance = geodesic((lat1, lon1), (lat2, lon2)).kilometers
    return distance

# Markers for visualization purposes
def add_markers(used_stops, network_graph, map, is_reversed):
    for stop in used_stops:
        #popup_text = f"Name: {stop.name}<br>Type: {stop.a_type}<br>Coordinates: {stop.getLat()}, {stop.getLong()}"
        lat = network_graph.nodes[stop]['y']
        long = network_graph.nodes[stop]['x']
        
        if is_reversed:
            folium.Marker(location=[lat, long],icon=folium.Icon(color='green')).add_to(map)
        else:
            folium.Marker(location=[lat, long],icon=folium.Icon(color='blue')).add_to(map)
            
def add_stops_to_list(routes):
    used_stops = []
    for route in routes:
        if route is None:
            continue
        
        for conn in route.route:
            if conn[0] not in used_stops:
                used_stops.append(conn[0])
            if conn[-1] not in used_stops:
                used_stops.append(conn[-1])
    return used_stops

# %%
# Checking the edges -> This is to see if the stop is in a one-way route
def get_opposite_side_stop(node, graph_of_stops):
    
    out_edges = list(graph_of_stops.out_edges(node, keys=True, data=True))
    n1,n2,key,data = out_edges[0]
    opposite_node = None
    
    if data['edge_id'] in partner_edges:
        partner_edge_id = partner_edges[data['edge_id']]
        for u, v, k, road in graph_of_stops.edges(keys=True, data=True):
            if road['edge_id'] == partner_edge_id:
                if u < 100000:
                    opposite_node = u
                    break
                if v < 100000:
                    opposite_node = v
                    break
                
    return opposite_node

# %%
# Method 1
# Iterate through each node in reverse and get the shortest path

def get_reverse_route(route, graph_of_stops, overall_graph, max_walking_distance):
    paths = route.route
    reverse_paths = paths[::-1]
    reverse_route_list = []
    reverse_route_id = route.route_id[:-1] + 'B' # Reverse Route ID
    totalDistance = 0
    
    used_stops = []
    stop_list = []
    for connection in reverse_paths:
        reverse_route_path = connection[::-1]
        end_node = reverse_route_path[-1]
        
        # Getting the edges of the start node only for the first connection
        if reverse_paths.index(connection) == 0:
            start_node = reverse_route_path[0] # Start node is critical as it should be the same as the last stop previous connection (If this is not the first connection)
            new_start_node = get_opposite_side_stop(start_node, graph_of_stops)
            if new_start_node is not None:
                start_node = new_start_node
            used_stops.append(start_node)
        
        # Getting the edges of the end node
        new_end_node = get_opposite_side_stop(end_node, graph_of_stops)
        if new_end_node is not None:
            end_node = new_end_node
                    
        if not nx.has_path(graph_of_stops, start_node, end_node):
            if not nx.has_path(graph_of_stops, start_node, reverse_route_path[-1]):
                return None
            else:
                end_node = reverse_route_path[-1]
                
        if end_node not in used_stops:
            used_stops.append(end_node)
        else:
            return None
                
        stop_list.append([start_node, end_node])
        start_node = end_node # Next connection start node is the end node of the previous connection
        
    for connection in stop_list:
        start_node = connection[0]
        end_node = connection[-1]
        
        reverse_route = nx.shortest_path(graph_of_stops, start_node, end_node, weight='length')
        reverse_route_list.append(reverse_route)
        
        distance_travelled = 0
        # Get the total distance from point A to point B
        for i in range(len(reverse_route)-1):
            node_data = graph_of_stops.nodes[reverse_route[i]]
            next_node_data = graph_of_stops.nodes[reverse_route[i+1]]
            distance_travelled += haversine(node_data['y'], node_data['x'], next_node_data['y'], next_node_data['x'])
        
        # Finally, Add the edge
        if reverse_route[0] not in overall_graph:
            overall_graph.add_node(reverse_route[0], **graph_of_stops.nodes[reverse_route[0]])
        if reverse_route[-1] not in overall_graph:
            overall_graph.add_node(reverse_route[-1], **graph_of_stops.nodes[reverse_route[-1]])
            
        overall_graph.add_edge(reverse_route[0], reverse_route[-1], key=reverse_route_id, road_path = reverse_route, distance = distance_travelled) # Add edge
        totalDistance += distance_travelled

    print("REVERSE ROUTE DISTANCE: ", totalDistance)
    return Route(reverse_route_list, reverse_route_id, totalDistance)

# %% [markdown]
# ### Genetic Algorithm

# %% [markdown]
# #### Genetic Algorithm Functions

# %%
# GA VERSION 2 - Finding the optimal Network

# This implementation takes only 2 parents from the whole generation and generates the population from them
# Instead of the what's in the paper that says the whole population will go through crossovers and mutations
# Cite Nayeem et al for GA with elitism and growing population size
def perform_genetic_algorithm(network_population, graph_of_stops, mutation_probability, num_mutations_probabilities, num_failure_removal,
                                      weight_random_failure, weight_network_coverage, weight_targeted_failure, weight_connectivity, plateau_threshold, plateau_count_limit, max_gens):
    
    max_fitness_score = 0 # This is the max score of the current population
    max_score_list = [] # This is to store all the max scores of each generation
    #prev_avg_fitness_score = None
    prev_max_fitness_score = None
    plateau_counter = 0
    most_optimal_gen = None # This is to store the most optimal generation
    current_highest_max_score = 0 # This will help determine the most optimal generation
    current_highest_avg_score = 0 # This will help determine the most optimal generation
    
    data_save_counts = 0
    
    generation_num = 1

    while True:
        print(f"Generation {generation_num}", flush=True)
        
        # DATA SAVING JUST IN CASE OF ERRORS
        if data_save_counts == 10:
            save_recent_population(generation_num, network_population)
            data_save_counts = 0
        data_save_counts += 1
        
        # Evaluate the fitness of each network in the population
        for network in network_population:
            network_graph = network.graph
            if network.fitness_score == 0:
                network.fitness_score = compute_fitness_score(network_graph, num_failure_removal, weight_random_failure, weight_network_coverage, weight_targeted_failure, weight_connectivity)
            
        # Sort the network population by fitness score
        sorted_network_population = sorted(network_population, key=lambda x: x.fitness_score, reverse=True)
        fitness_scores = [network.fitness_score for network in sorted_network_population]
        
        # for printing purposes in order
        for network in sorted_network_population:
            print(f"Network Score: {network.fitness_score}", flush=True)
        
        # The max network score of this generation
        max_fitness_score = max(fitness_scores)
        max_score_list.append(max_fitness_score)
        print(f"Generation {generation_num} Max Score: {max_fitness_score}", flush=True)
        
        # The average network score of this generation
        total_score = sum(fitness_scores)
        average_score = total_score / len(fitness_scores)
        print(f"Generation {generation_num} Average Score: {average_score}", flush=True)
        
        # Check if the score is optimal. If it is, then stop
        # if max_fitness_score >= optimal_fitness_score:
        #     print(f"WE FOUND THE OPTIMAL NETWORK IN GENERATION {generation_num}")
        #     most_optimal_network = sorted_network_population[0]
        #     print(f"Fitness Score of the most optimal network: {most_optimal_network.fitness_score}")
        #     break
        
        # Check if this generation has the highest max fitness score and highest average score
        if max_fitness_score >= current_highest_max_score and average_score >= current_highest_avg_score:
            current_highest_avg_score = average_score
            current_highest_max_score = max_fitness_score
            most_optimal_gen = sorted_network_population
            save_recent_best_population(generation_num, most_optimal_gen)
        
        # Check if score plateaus based on max score
        if prev_max_fitness_score is not None and abs(max_fitness_score - prev_max_fitness_score) <= plateau_threshold:
            plateau_counter += 1
            if plateau_counter >= plateau_count_limit:
                print(f"Plateau detected in generation {generation_num}. Stopping.")
                break
        else:
            plateau_counter = 0
        prev_max_fitness_score = max_fitness_score
        
        
        # Choosing 10% of the networks to be parents using Roulette Wheel Selection
        #print("Choosing parents...", flush=True)
        
        #Getting the number of parents to be selected
        num_parents = int(len(network_population) * 0.10)
        if num_parents % 2 == 1:
            num_parents += 1
        
        # List of parents
        parent_networks = []
        #print("NUM PARENTS ", num_parents)
        for i in range(num_parents):
            # Get the list of all fitness scores
            fitness_scores = [network.fitness_score for network in sorted_network_population]
            
            # Shift the scores to ensure all are positive
            min_score = min(fitness_scores)
            if min_score < 0:
                fitness_scores = [score - min_score for score in fitness_scores]
            
            # Get the probabilities
            total = sum(fitness_scores)
            selection_p = [score / total for score in fitness_scores]
            
            # Getting the parent
            chosen_parent = np.random.choice(sorted_network_population, 1, p=selection_p)[0]
            #print(f"parent {i} Score, ", chosen_parent.fitness_score, flush=True)
            sorted_network_population.remove(chosen_parent)
            parent_networks.append(chosen_parent)
            
            
        # Add back all the removed parent networks
        sorted_network_population.extend(parent_networks)
        
        # Sort the networks by fitness function again
        sorted_network_population = sorted(network_population, key=lambda x: x.fitness_score, reverse=True)
        
        # Pairing the parents
        parent_pairs = [parent_networks[i:i+2] for i in range(0, len(parent_networks), 2)]

        # Each parent pair will now produce children
        #print("GETTING CHILDREN", flush=True)
        children_networks = []
        for pair in parent_pairs:
            parent1 = pair[0]
            parent2 = pair[1]
                   
            # Get 2 children from crossovers between the two parents
            child1, child2, is_different = crossover_split_index(parent1, parent2)
            
            # Getting the number of mutations. If the children are entirely different from their parents, there should be atleast one mutation
            if is_different:
                index_array = list(range(len(num_mutations_probabilities)))
                num_mutations = np.random.choice(index_array, 1, p=num_mutations_probabilities)[0]
            else:
                temp_mutation_probs = [0, 0.1, 0.4, 0.3, 0.2]
                index_array = list(range(len(temp_mutation_probs)))
                num_mutations = np.random.choice(index_array, 1, p=temp_mutation_probs)[0]
            
            # # Getting the number of mutations.
            # index_array = list(range(len(num_mutations_probabilities)))
            # num_mutations = np.random.choice(index_array, 1, p=num_mutations_probabilities)[0]

            for j in range(num_mutations):
                # Apply mutations to the children based on mutation probability hyperparameter
                if np.random.rand() < mutation_probability:
                    mutate(child1, graph_of_stops)
                    
                if np.random.rand() < mutation_probability:
                    mutate(child2, graph_of_stops)
            
            # Add the children to the list of children
            children_networks.append(child1)
            children_networks.append(child2)
            
        
        # Preparing the next generation
        
        # Remove the lowest scored networks and replace it with the children
        network_population = sorted_network_population[:-len(children_networks)]
        network_population.extend(children_networks)
        
        # Increment the generation number
        generation_num += 1
        if generation_num > max_gens:
                print(f"Reached maximum generation count of {generation_num}. Stopping.")
                break
        print()
        
    if most_optimal_gen is not None:
        most_optimal_gen = sorted(most_optimal_gen, key=lambda x: x.fitness_score, reverse=True)

    print(f"Highest score of all generations: {max(max_score_list)}")
    return most_optimal_gen

# %%
# V2 - Crossover routes should not have the same routes
# CROSSOVER SPLIT INDEX FUNCTION

def crossover_split_index(network1, network2):
    # Split both networks based on which routes do not have the same connections
    # network.routes is a list of routes or list of lists of shortest_path
    routes_same1 = []
    routes_not_same1 = []
    routes_same2 = []
    routes_not_same2 = []
    
    # Standardize and store the routes of network2 for comparison
    network1_routes_standardized = {standardize_route(route.route): route for route in network1.routes}
    network2_routes_standardized = {standardize_route(route.route): route for route in network2.routes}
    
    # Compare each route in network1 with routes in network2
    for route in network1.routes:
        standardized_route1 = standardize_route(route.route)
        if standardized_route1 in network2_routes_standardized:
            routes_same1.append(route)
        else:
            routes_not_same1.append(route)
            
    for route in network2.routes:
        standardized_route2 = standardize_route(route.route)
        if standardized_route2 in network1_routes_standardized:
            routes_same2.append(route)
        else:
            routes_not_same2.append(route)
    
    # Create new graphs for the left and right sides
    route_graph1 = nx.MultiDiGraph()
    route_graph2 = nx.MultiDiGraph()
    
    route_network1 = []
    route_network2 = []
    
    reversed_route_network1 = []
    reversed_route_network2 = []
    
    used_stops1 = []
    used_stops2 = []
    
    reversed_used_stops1 = []
    reversed_used_stops2 = []
    
    conn_type1 = network1.conn_type
    conn_type2 = network2.conn_type

    walk_type1 = network1.walk_distance
    walk_type2 = network2.walk_distance
    
    # If all have similar connections, then do not split
    if len(routes_not_same1) == 0:
        test_graph_net1 = network1.graph.copy()
        test_routes_net1 = [copy.deepcopy(r) for r in network1.routes]
        test_reversed_routes_net1 = [copy.deepcopy(r) for r in network1.reversed_routes]
        test_stops_net1 = [copy.deepcopy(s) for s in network1.stops]
        test_reversed_stops_net1 = [copy.deepcopy(s) for s in network1.reversed_stops]
        child1 = networkObj(test_routes_net1, test_reversed_routes_net1, test_stops_net1, test_reversed_stops_net1, test_graph_net1, network1.conn_type, network1.walk_distance)

        test_graph_net2 = network2.graph.copy()
        test_routes_net2 = [copy.deepcopy(r) for r in network2.routes]
        test_reversed_routes_net2 = [copy.deepcopy(r) for r in network2.reversed_routes]
        test_stops_net2 = [copy.deepcopy(s) for s in network2.stops]
        test_reversed_stops_net2 = [copy.deepcopy(s) for s in network2.reversed_stops]
        child2 = networkObj(test_routes_net2, test_reversed_routes_net2, test_stops_net2, test_reversed_stops_net2, test_graph_net2, network2.conn_type, network2.walk_distance)
        
        #print("THERE ARE NO DIFFERENT ROUTES")
        is_different = False
        
    # If all routes of both networks are different, then split at a random index
    elif len(routes_same1) == 0:
        # Split both networks at a random index
        # network.routes is a list of routes or list of lists of shortest_path
        if len(network1.routes) < len(network2.routes):
            split_index = random.randint(0, len(network2.routes)-1)
        else:
            split_index = random.randint(0, len(network1.routes)-1)
            
        count = 0 # This is the index count, this will also serve as the new route ID
        for route in network1.routes:
            index = network1.routes.index(route)
            new_route_id = f"{count}-A"
            new_route = Route([copy.deepcopy(r) for r in route.route],new_route_id, route.length)
            
            reversed_route = network1.reversed_routes[index]
            if reversed_route is not None:
                new_reversed_route_id = f"{count}-B"
                new_reversed_route = Route([copy.deepcopy(r) for r in reversed_route.route],new_reversed_route_id, reversed_route.length)
            
            if count < split_index: # if 0-split_index -> child1 graph
                for connection in route.route:
                    route_graph1.add_node(connection[0], **network1.graph.nodes[connection[0]])
                    if connection[0] not in used_stops1:
                        used_stops1.append(connection[0])
                        
                    route_graph1.add_node(connection[-1], **network1.graph.nodes[connection[-1]])
                    if connection[-1] not in used_stops1:
                        used_stops1.append(connection[-1])
                    route_graph1.add_edge(connection[0], connection[-1], key=new_route_id, **network1.graph.get_edge_data(connection[0], connection[-1], route.route_id))
                route_network1.append(new_route)
                
                # Reversed
                if reversed_route is not None:
                    for connection in reversed_route.route:
                        route_graph1.add_node(connection[0], **network1.graph.nodes[connection[0]])
                        if connection[0] not in reversed_used_stops1:
                            reversed_used_stops1.append(connection[0])
                            
                        route_graph1.add_node(connection[-1], **network1.graph.nodes[connection[-1]])
                        if connection[-1] not in reversed_used_stops1:
                            reversed_used_stops1.append(connection[-1])
                        
                        route_graph1.add_edge(connection[0], connection[-1], key=new_reversed_route_id, **network1.graph.get_edge_data(connection[0], connection[-1],  reversed_route.route_id))
                    reversed_route_network1.append(new_reversed_route)
                else:
                    reversed_route_network1.append(None)
                
                    
            else: # else its for child2 graph
                for connection in route.route:
                    route_graph2.add_node(connection[0], **network1.graph.nodes[connection[0]])
                    if connection[0] not in used_stops2:
                        used_stops2.append(connection[0])
                        
                    route_graph2.add_node(connection[-1], **network1.graph.nodes[connection[-1]])
                    if connection[-1] not in used_stops2:
                        used_stops2.append(connection[-1])
                    
                    route_graph2.add_edge(connection[0], connection[-1], key=new_route_id, **network1.graph.get_edge_data(connection[0], connection[-1], route.route_id))
                route_network2.append(new_route)
                # Reversed
                if reversed_route is not None:
                    for connection in reversed_route.route:
                        route_graph2.add_node(connection[0], **network1.graph.nodes[connection[0]])
                        if connection[0] not in reversed_used_stops2:
                            reversed_used_stops2.append(connection[0])
                            
                        route_graph2.add_node(connection[-1], **network1.graph.nodes[connection[-1]])
                        if connection[-1] not in reversed_used_stops2:
                            reversed_used_stops2.append(connection[-1])
                        
                        route_graph2.add_edge(connection[0], connection[-1], key=new_reversed_route_id, **network1.graph.get_edge_data(connection[0], connection[-1], reversed_route.route_id))
                    reversed_route_network2.append(new_reversed_route)
                else:
                    reversed_route_network2.append(None)
            count += 1
            
        # Network 2
        count = 0
        for route in network2.routes:
            index = network2.routes.index(route)
            new_route_id = f"{count}-A"
            new_route = Route([copy.deepcopy(r) for r in route.route],new_route_id, route.length)
            
            reversed_route = network2.reversed_routes[index]
            if reversed_route is not None:
                new_reversed_route_id = f"{count}-B"
                new_reversed_route = Route([copy.deepcopy(r) for r in reversed_route.route], new_reversed_route_id, reversed_route.length)
            
            if count >= split_index: # if split_index-end -> child1 graph
                for connection in route.route:
                    route_graph1.add_node(connection[0], **network2.graph.nodes[connection[0]])
                    if connection[0] not in used_stops1:
                        used_stops1.append(connection[0])
                        
                    route_graph1.add_node(connection[-1], **network2.graph.nodes[connection[-1]])
                    if connection[-1] not in used_stops1:
                        used_stops1.append(connection[-1])  
                    route_graph1.add_edge(connection[0], connection[-1], key=new_route_id, **network2.graph.get_edge_data(connection[0], connection[-1], route.route_id))
                route_network1.append(new_route)
                
                # Reverse
                if reversed_route is not None:
                    for connection in reversed_route.route:
                        route_graph1.add_node(connection[0], **network2.graph.nodes[connection[0]])
                        if connection[0] not in reversed_used_stops1:
                            reversed_used_stops1.append(connection[0])
                            
                        route_graph1.add_node(connection[-1], **network2.graph.nodes[connection[-1]])
                        if connection[-1] not in reversed_used_stops1:
                            reversed_used_stops1.append(connection[-1])
                        route_graph1.add_edge(connection[0], connection[-1], key=new_reversed_route_id, **network2.graph.get_edge_data(connection[0], connection[-1], reversed_route.route_id))
                    reversed_route_network1.append(new_reversed_route)
                else:
                    reversed_route_network1.append(None)
                    
            else: # else its for child2 graph
                for connection in route.route:
                    route_graph2.add_node(connection[0], **network2.graph.nodes[connection[0]])
                    if connection[0] not in used_stops2:
                        used_stops2.append(connection[0])
                        
                    route_graph2.add_node(connection[-1], **network2.graph.nodes[connection[-1]])
                    if connection[-1] not in used_stops2:
                        used_stops2.append(connection[-1])    
                    route_graph2.add_edge(connection[0], connection[-1], key=new_route_id, **network2.graph.get_edge_data(connection[0], connection[-1], route.route_id))
                route_network2.append(new_route)
                
                # Reversed
                if reversed_route is not None:
                    for connection in reversed_route.route:
                        route_graph2.add_node(connection[0], **network2.graph.nodes[connection[0]])
                        if connection[0] not in reversed_used_stops2:
                            reversed_used_stops2.append(connection[0])
                            
                        route_graph2.add_node(connection[-1], **network2.graph.nodes[connection[-1]])
                        if connection[-1] not in reversed_used_stops2:
                            reversed_used_stops2.append(connection[-1])
                        
                        route_graph2.add_edge(connection[0], connection[-1], key=new_reversed_route_id, **network2.graph.get_edge_data(connection[0], connection[-1], reversed_route.route_id))
                    reversed_route_network2.append(new_reversed_route)
                else:
                    reversed_route_network2.append(None)
                
            count += 1
        
        child1 = networkObj(route_network1, reversed_route_network1, used_stops1, reversed_used_stops1, route_graph1, conn_type1, walk_type1)
        child2 = networkObj(route_network2, reversed_route_network2, used_stops2, reversed_used_stops2, route_graph2, conn_type2, walk_type2)
        
        #print("ALL ROUTES ARE DIFFERENT")
        is_different = True
            
    # If there are some different routes, then split according to the number of different routes
    else:
        # CHILD 1        
        # All same routes from parent 1 will go to child 1
        
        count = 0
        for route in routes_same1:
            index = network1.routes.index(route)
            new_route_id = f"{count}-A"
            new_route = Route([copy.deepcopy(r) for r in route.route],new_route_id, route.length)
            
            reversed_route = network1.reversed_routes[index]
            if reversed_route is not None:
                new_reversed_route_id = f"{count}-B"
                new_reversed_route = Route([copy.deepcopy(r) for r in reversed_route.route],new_reversed_route_id, reversed_route.length)
            
            for connection in route.route:
                route_graph1.add_node(connection[0], **network1.graph.nodes[connection[0]])
                if connection[0] not in used_stops1:
                    used_stops1.append(connection[0])
                    
                route_graph1.add_node(connection[-1], **network1.graph.nodes[connection[-1]])
                if connection[-1] not in used_stops1:
                    used_stops1.append(connection[-1])
                
                route_graph1.add_edge(connection[0], connection[-1], key=new_route_id, **network1.graph.get_edge_data(connection[0], connection[-1], route.route_id))
            route_network1.append(new_route)
            
            # Reversed
            if reversed_route is not None:
                for connection in reversed_route.route:
                    route_graph1.add_node(connection[0], **network1.graph.nodes[connection[0]])
                    if connection[0] not in reversed_used_stops1:
                        reversed_used_stops1.append(connection[0])
                        
                    route_graph1.add_node(connection[-1], **network1.graph.nodes[connection[-1]])
                    if connection[-1] not in reversed_used_stops1:
                        reversed_used_stops1.append(connection[-1])
                    
                    route_graph1.add_edge(connection[0], connection[-1], key=new_reversed_route_id, **network1.graph.get_edge_data(connection[0], connection[-1], reversed_route.route_id))
                reversed_route_network1.append(new_reversed_route)
            else:
                reversed_route_network1.append(None)
            
            count += 1
            
        # All not same routes from parent 2 will go to child 1
        for route in routes_not_same2:
            index = network2.routes.index(route)
            new_route_id = f"{count}-A"
            new_route = Route([copy.deepcopy(r) for r in route.route],new_route_id, route.length)
            
            reversed_route = network2.reversed_routes[index]
            if reversed_route is not None:
                new_reversed_route_id = f"{count}-B"
                new_reversed_route = Route([copy.deepcopy(r) for r in reversed_route.route],new_reversed_route_id, reversed_route.length)
            
            for connection in route.route:
                route_graph1.add_node(connection[0], **network2.graph.nodes[connection[0]])
                if connection[0] not in used_stops1:
                    used_stops1.append(connection[0])
                    
                route_graph1.add_node(connection[-1], **network2.graph.nodes[connection[-1]])
                if connection[-1] not in used_stops1:
                    used_stops1.append(connection[-1])
                
                route_graph1.add_edge(connection[0], connection[-1], key=new_route_id, **network2.graph.get_edge_data(connection[0], connection[-1], route.route_id))
            route_network1.append(new_route)
            
            # Reverse
            if reversed_route is not None:
                for connection in reversed_route.route:
                    route_graph1.add_node(connection[0], **network2.graph.nodes[connection[0]])
                    if connection[0] not in reversed_used_stops1:
                        reversed_used_stops1.append(connection[0])
                        
                    route_graph1.add_node(connection[-1], **network2.graph.nodes[connection[-1]])
                    if connection[-1] not in reversed_used_stops1:
                        reversed_used_stops1.append(connection[-1])
                    
                    route_graph1.add_edge(connection[0], connection[-1], key=new_reversed_route_id, **network2.graph.get_edge_data(connection[0], connection[-1], reversed_route.route_id))
                reversed_route_network1.append(new_reversed_route)
            else:
                reversed_route_network1.append(None)
            count += 1
            
        #CHILD2
        # All not same routes from parent 1 will go to child 2
        
        count = 0
        for route in routes_not_same1:
            index = network1.routes.index(route)
            new_route_id = f"{count}-A"
            new_route = Route([copy.deepcopy(r) for r in route.route],new_route_id, route.length)
            
            reversed_route = network1.reversed_routes[index]
            if reversed_route is not None:
                new_reversed_route_id = f"{count}-B"
                new_reversed_route = Route([copy.deepcopy(r) for r in reversed_route.route],new_reversed_route_id, reversed_route.length)
            
            for connection in route.route:
                route_graph2.add_node(connection[0], **network1.graph.nodes[connection[0]])
                if connection[0] not in used_stops2:
                    used_stops2.append(connection[0])
                    
                route_graph2.add_node(connection[-1], **network1.graph.nodes[connection[-1]])
                if connection[-1] not in used_stops2:
                    used_stops2.append(connection[-1])
                
                route_graph2.add_edge(connection[0], connection[-1], key=new_route_id, **network1.graph.get_edge_data(connection[0], connection[-1], route.route_id))
            route_network2.append(new_route)
            
            #Reverse
            if reversed_route is not None:
                for connection in reversed_route.route:
                    route_graph2.add_node(connection[0], **network1.graph.nodes[connection[0]])
                    if connection[0] not in reversed_used_stops2:
                        reversed_used_stops2.append(connection[0])
                        
                    route_graph2.add_node(connection[-1], **network1.graph.nodes[connection[-1]])
                    if connection[-1] not in reversed_used_stops2:
                        reversed_used_stops2.append(connection[-1])
                    
                    route_graph2.add_edge(connection[0], connection[-1], key=new_reversed_route_id, **network1.graph.get_edge_data(connection[0], connection[-1], reversed_route.route_id))
                reversed_route_network2.append(new_reversed_route)
            else:
                reversed_route_network2.append(None)
            count += 1
        
        # All same routes from parent 2 will go to child 2
        for route in routes_same2:
            index = network2.routes.index(route)
            new_route_id = f"{count}-A"
            new_route = Route([copy.deepcopy(r) for r in route.route],new_route_id, route.length)
            
            reversed_route = network2.reversed_routes[index]
            if reversed_route is not None:
                new_reversed_route_id = f"{count}-B"
                new_reversed_route = Route([copy.deepcopy(r) for r in reversed_route.route],new_reversed_route_id, reversed_route.length)
            
            for connection in route.route:
                route_graph2.add_node(connection[0], **network2.graph.nodes[connection[0]])
                if connection[0] not in used_stops2:
                    used_stops2.append(connection[0])
                    
                route_graph2.add_node(connection[-1], **network2.graph.nodes[connection[-1]])
                if connection[-1] not in used_stops2:
                    used_stops2.append(connection[-1])
                
                route_graph2.add_edge(connection[0], connection[-1], key=new_route_id, **network2.graph.get_edge_data(connection[0], connection[-1], route.route_id))
            route_network2.append(new_route)
            
            # Reversed
            if reversed_route is not None:
                for connection in reversed_route.route:
                    route_graph2.add_node(connection[0], **network2.graph.nodes[connection[0]])
                    if connection[0] not in reversed_used_stops2:
                        reversed_used_stops2.append(connection[0])
                        
                    route_graph2.add_node(connection[-1], **network2.graph.nodes[connection[-1]])
                    if connection[-1] not in reversed_used_stops2:
                        reversed_used_stops2.append(connection[-1])
                    
                    route_graph2.add_edge(connection[0], connection[-1], key=new_reversed_route_id, **network2.graph.get_edge_data(connection[0], connection[-1], reversed_route.route_id))
                reversed_route_network2.append(new_reversed_route)
            else:
                reversed_route_network2.append(None)
            count += 1
    
        child1 = networkObj(route_network1, reversed_route_network1, used_stops1, reversed_used_stops1, route_graph1, conn_type1, walk_type1)
        child2 = networkObj(route_network2, reversed_route_network2, used_stops2, reversed_used_stops2, route_graph2, conn_type2, walk_type2)
        
        #print("SOME ROUTES ARE DIFFERENT")
        is_different = True
    
    
    # # ----------- ERROR CHECKING ---------------------
    print("* Checking Child 1 for errors:", flush=True)
    # TODO: DELETE FOR TESTING IF GRAPH IS CONSISTENT WITH ITS LIST OF ROUTES
    print("Checking for graph and route consistency...", flush=True)
    check_graph_with_route(child1)
    print("Checking for graph and list of stops consistency...", flush=True)
    check_graph_with_stops(child1)
    print("Checking if order of routes is correct...", flush=True)
    check_order_route(child1)
    print("Checking for list of stops and route consistency...", flush=True)
    check_stops_routes(child1)
    print("Checking for duplicates in routes...")
    check_duplicate_routes(child1)
    print("Checking for duplicate stops and connections...")
    check_duplicate_stops_routes(child1)
    print()
    
    print("* Checking Child 2 for errors:", flush=True)
    # # TODO: DELETE FOR TESTING IF GRAPH IS CONSISTENT WITH ITS LIST OF ROUTES
    print("Checking for graph and route consistency...", flush=True)
    check_graph_with_route(child2)
    print("Checking for graph and list of stops consistency...", flush=True)
    check_graph_with_stops(child2)
    print("Checking if order of routes is correct...", flush=True)
    check_order_route(child2)
    print("Checking for list of stops and route consistency...", flush=True)
    check_stops_routes(child2)
    print("Checking for duplicates in routes...")
    check_duplicate_routes(child2)
    print("Checking for duplicate stops and connections...")
    check_duplicate_stops_routes(child2)
    print()

    return child1, child2, is_different


# Standardizes the route for more efficiency in comparing routes
def standardize_route(route):
    return tuple(tuple(sorted(connection)) for connection in route)

# %%
# MUTATION FUNCTION

# Modify the stop connections of a random route in the network
# Randomly select a route and randomly select a stop in that route
# Then randomly select another stop that is a not too far from the selected stop based on threshold
# Swap connections with that stop
def mutate(network_to_mutate, graph_of_stops):
    global set_walk_distance, MAX_DISTANCE, list_of_stops_Manila
    
    # Randomly select a route
    random_route_obj = random.choice(network_to_mutate.routes)
    random_route_obj_index = network_to_mutate.routes.index(random_route_obj)
    
    random_route = random_route_obj.route
    random_route_id = random_route_obj.route_id

    # Randomly select a stop in the route
    index_array = list(range(1, len(random_route)-1))
    connection_index = random.choice(index_array)
    random_node_connection = random_route[connection_index]
    
    connection_stop_index = random.choice([0, -1]) # Choose whether the origin or destination node
    random_stop = random_node_connection[connection_stop_index] # The random stop to be swapped
    
    # Get the old total distance
    old_total_distance = 0
    for connection in random_route:
        edge_data = network_to_mutate.graph.get_edge_data(connection[0], connection[-1], random_route_id)
        old_total_distance += edge_data['distance']
    
    
    # This is to get the subset distance (Distance without the connection with chosen random stop)
    if connection_stop_index == 0: # If it is the origin node in that connection (A, B, C and B is the chosen. Get B-C and A-B)
        prev_connection = random_route[connection_index-1] # Get the previous connection
        prev_node = prev_connection[0] # Get the origin node for that connection
        distance1 = network_to_mutate.graph.get_edge_data(prev_node, random_stop, random_route_id)['distance'] # Get the distance of the previous connection
        distance2 = network_to_mutate.graph.get_edge_data(random_stop, random_node_connection[-1], random_route_id)['distance'] # Get the distance of the current connection
        distance_to_subtract = distance1 + distance2
        
        # Previous connection: node1 - random_node
        # Current connection: random_node - node2
        node1 = prev_node # Setting the partner nodes
        node2 = random_node_connection[-1]
        
    else: #If it is the dest node in that connection
        distance1 = network_to_mutate.graph.get_edge_data(random_node_connection[0], random_stop, random_route_id)['distance'] # Get the distance of the current connection
        next_connection = random_route[connection_index+1] # Get the next route
        next_node = next_connection[-1] # Get the destination node for the next connection
        distance2 = network_to_mutate.graph.get_edge_data(random_stop, next_node, random_route_id)['distance']
        distance_to_subtract = distance1 + distance2
        
        # Previous connection: node1 - random_node
        # Current connection: random_node - node2
        node2 = next_node
        node1 = random_node_connection[0]
    
    # Get the subset different -> This will be used to make sure that the distance of the connections to the new node will be less than or equal to MAX_DISTANCE (15km)
    subset_distance = old_total_distance - distance_to_subtract
    
    # Will try searching for a random stop
    for i in range(100):
        # Get a random stop
        new_random_stop = random.choice(list_of_stops_Manila).id
        new_random_stop_data = graph_of_stops.nodes[new_random_stop]
        
        # Check if the new random stop is not within walking distance with the other stop in the route
        # Walking distance between node1 in route and stop to be swapped with
        source = (new_random_stop_data['y'], new_random_stop_data['x'])
        point = (graph_of_stops.nodes[node1]['y'], graph_of_stops.nodes[node1]['x'])
        walking_distance1 = geodesic(source, point).meters
        
        # Walking distance between node2 in route and stop to be swapped with
        source = (new_random_stop_data['y'], new_random_stop_data['x'])
        point = (graph_of_stops.nodes[node2]['y'], graph_of_stops.nodes[node2]['x'])
        walking_distance2 = geodesic(source, point).meters
        
        # Check if it already has been used in the route
        isCandidate = True
        for connection in random_route:
            if new_random_stop == connection[0] or new_random_stop == connection[-1]:
                isCandidate = False
                continue
        
        # Check if the edge has already been used
        has_edge1 = network_to_mutate.graph.has_edge(node1, new_random_stop, random_route_id)
        has_edge2 = network_to_mutate.graph.has_edge(new_random_stop, node1, random_route_id)
        has_edge3 = network_to_mutate.graph.has_edge(new_random_stop, node2, random_route_id)
        has_edge4 = network_to_mutate.graph.has_edge(node2, new_random_stop, random_route_id)
        
        # If it is not within walking distances, has not been used in the same route, has a path, has no existing edge
        if walking_distance1 >= set_walk_distance and walking_distance2 >= set_walk_distance and isCandidate and nx.has_path(graph_of_stops, node1, new_random_stop) and nx.has_path(graph_of_stops, new_random_stop, node2) and not has_edge1 and not has_edge2 and not has_edge3 and not has_edge4:
            # DISTANCE 1: Get the total distance from point A to point B
            shortest_route1 = nx.shortest_path(graph_of_stops, node1, new_random_stop, weight='length')
            distance_travelled1 = 0
            for i in range(len(shortest_route1)-1):
                node_data = graph_of_stops.nodes[shortest_route1[i]]
                next_node_data = graph_of_stops.nodes[shortest_route1[i+1]]
                distance_travelled1 += haversine(node_data['y'], node_data['x'], next_node_data['y'], next_node_data['x'])
            
            # DISTANCE 2: Get the total distance from point A to point B
            shortest_route2 = nx.shortest_path(graph_of_stops, new_random_stop, node2, weight='length')
            distance_travelled2 = 0
            for i in range(len(shortest_route2)-1):
                node_data = graph_of_stops.nodes[shortest_route2[i]]
                next_node_data = graph_of_stops.nodes[shortest_route2[i+1]]
                distance_travelled2 += haversine(node_data['y'], node_data['x'], next_node_data['y'], next_node_data['x'])
            
            newDistance = subset_distance + distance_travelled1 + distance_travelled2
            # If its within the 15km distance, then this new stop can be used
            if newDistance <= MAX_DISTANCE:
                # Add the new stop to the used stops
                if new_random_stop not in network_to_mutate.stops:
                    network_to_mutate.stops.append(new_random_stop)
                
                # Modify the graph by adding the new node
                network_to_mutate.graph.add_node(new_random_stop, **graph_of_stops.nodes[new_random_stop])
                
                # Connect the new stop to the edges
                network_to_mutate.graph.add_edge(shortest_route1[0], shortest_route1[-1], key=random_route_id, distance = distance_travelled1) # Add edge
                network_to_mutate.graph.add_edge(shortest_route2[0], shortest_route2[-1], key=random_route_id, distance = distance_travelled2) # Add edge 
            
                # Remove the old connections and node if it has no other connections
                network_to_mutate.graph.remove_edge(node1, random_stop, random_route_id)
                network_to_mutate.graph.remove_edge(random_stop, node2, random_route_id)
                if (network_to_mutate.graph.degree(random_stop) == 0):
                    network_to_mutate.graph.remove_node(random_stop)                
                    network_to_mutate.stops.remove(random_stop)
                
                
                # Modify the route
                if connection_stop_index == 0: #If its the origin node
                    random_route[connection_index-1] = shortest_route1 # Change the previous connection
                    random_route[connection_index] = shortest_route2 # Change the current connection
                    
                else: #else If its the dest node
                    random_route[connection_index] = shortest_route1 # Change the current connection
                    random_route[connection_index+1] = shortest_route2 # Change the next connection
                    
                # Modify the distance of the modified route
                random_route_obj.length = newDistance
                
                
                # REVERSE
                original_reverse_route = network_to_mutate.reversed_routes[random_route_obj_index]
                if original_reverse_route is not None:
                    original_reverse_route_id = original_reverse_route.route_id
                    print(f"Reverse Key: {original_reverse_route_id}")
                    print(f"Key: {random_route_id}")
                    
                    for connection in original_reverse_route.route:
                        print(f"{connection[0]} - {connection[-1]}")
                        if not network_to_mutate.graph.has_edge(connection[0], connection[-1], original_reverse_route_id):
                            print("EDGE MISSING")
                            if not network_to_mutate.graph.has_node(connection[0]):
                                print(f"{connection[0]} missing")
                                
                            if not network_to_mutate.graph.has_node(connection[-1]):
                                print(f"{connection[-1]} missing")
                                
                        network_to_mutate.graph.remove_edge(connection[0], connection[-1], original_reverse_route_id)
                        if (network_to_mutate.graph.degree(connection[0]) == 0):
                            network_to_mutate.graph.remove_node(connection[0])
                            if connection[0] in network_to_mutate.stops:
                                network_to_mutate.stops.remove(connection[0])
                            
                        if (network_to_mutate.graph.degree(connection[-1]) == 0):
                            network_to_mutate.graph.remove_node(connection[-1])
                            if connection[-1] in network_to_mutate.stops:
                                network_to_mutate.stops.remove(connection[-1])
                            
                    reverse_route = get_reverse_route(random_route_obj, graph_of_stops, network_to_mutate.graph, network_to_mutate.walk_distance)
                    network_to_mutate.reversed_routes[random_route_obj_index] = reverse_route
                    new_reversed_used_stops = add_stops_to_list(network_to_mutate.reversed_routes)
                    network_to_mutate.reversed_stops = new_reversed_used_stops
                
                # ----------- FOR ERROR CHECKING -------------------
                print("Checking for graph and route consistency...")
                check_graph_with_route(network_to_mutate)
                print("Checking for graph and list of stops consistency...")
                check_graph_with_stops(network_to_mutate)
                print("Checking if order of routes is correct...")
                check_order_route(network_to_mutate)
                print("Checking for list of stops and route consistency...")
                check_stops_routes(network_to_mutate)
                print("Checking for duplicates in routes...")
                check_duplicate_routes(network_to_mutate)
                print("Checking for duplicate stops and connections...")
                check_duplicate_stops_routes(network_to_mutate)
                print()
                print("MUTATION DONE", flush=True)
                
                # Break the loop once we swap
                print()
                break

# %% [markdown]
# #### Fitness Function

# %%
# Fitness function

def select_highest_scoring_mutation(candidate_road_snapped_networks, num_failure_removal,
                                    weight_random_failure, weight_targeted_failure, weight_radius_of_gyration):
    max_fitness_score = -np.inf
    max_candidate_route_snapped_network = None

    for n in candidate_road_snapped_networks:
        fitness_score = compute_fitness_score(n, num_failure_removal,
                                              weight_random_failure, weight_targeted_failure, weight_radius_of_gyration)
        if fitness_score > max_fitness_score:
            max_fitness_score = fitness_score
            max_candidate_route_snapped_network = n

    return max_candidate_route_snapped_network

def compute_fitness_score(road_snapped_network_graph, num_failure_removal,
                          weight_random_failure, weight_network_coverage, weight_targeted_failure, weight_connectivity):

    random_failure_robustness = compute_random_failure_robustness(road_snapped_network_graph, num_failure_removal)
    weighted_random_failure_robustness = weight_random_failure * random_failure_robustness

    targeted_failure_robustness = compute_targeted_failure_robustness(road_snapped_network_graph, num_failure_removal)
    weighted_targeted_failure_robustness = weight_targeted_failure * targeted_failure_robustness

    connectivity_score = compute_connectivity(road_snapped_network_graph)
    weighted_connectivity = weight_connectivity * connectivity_score
    
    network_coverage = get_network_coverage(road_snapped_network_graph)
    weighted_network_coverage = weight_network_coverage * network_coverage
    
    # print("Random Failure Score: ", weighted_random_failure_robustness)
    # print("Target Failure Score: ", weighted_targeted_failure_robustness)
    # print("Connectivity: ", weighted_connectivity)
    # print("Network Coverage: ", weighted_network_coverage, flush=True)

    # Will use this return for now to utilize target and random failure nodes 
    return weighted_connectivity + weighted_network_coverage - weighted_random_failure_robustness - weighted_targeted_failure_robustness
    # return weighted_radius_of_gyration


### WRITTEN IN PSEUDOCODE
def compute_connectivity(network):
    # External connectivity - measure how connected is the jeepney route network with other modes of transpo
    
    # Get the ratio of transportation stops to total stops in the network
    transpo_stops = [node for node, node_data in network.nodes(data=True) if node_data['isTranspo'] == True]
    total_stops = len(network.nodes(data=True))
    transpo_stop_ratio = len(transpo_stops) / total_stops

    # Get the average degree of all transportation stops in the network
    if len(transpo_stops) > 0:
        avg_transpo_degree = sum(network.degree(stop) for stop in transpo_stops) / len(transpo_stops)
    else:
        avg_transpo_degree = 1

    # Find a way to normalize the two values and combine them 

    # Internal connectivity - measure how connected is each jeepney route to other jeepney routes
                    
    # This counts how many nodes have intersections (Meaning node is connected to more than one route by route ID)
    num_intersections = 0
    for node, node_data in network.nodes(data=True):
        if network.in_degree(node) > 1 or network.out_degree(node) > 1:
            num_intersections += 1

    
    # Change these weights based on what the expected values for 
    # the transpo_stop_ratio, avg_transpo_degree, and num_intersections will be
    external_weight = 0.5
    internal_weight = 0.5
    
    # TODO: Delete this
    # print("Transpo stop ratio: ", transpo_stop_ratio)
    # print("Num intersections: ", num_intersections)
    # print("Average degree: ", avg_transpo_degree)

    # Formula subject to change
    return external_weight * (transpo_stop_ratio * avg_transpo_degree) + internal_weight * num_intersections


def compute_random_failure_robustness(road_snapped_network_graph, num_removals):
    graph_copy = road_snapped_network_graph.copy() # Make a copy
    
    for i in range(num_removals):
        selected_node = random.choice(list(graph_copy.nodes()))
        graph_copy.remove_node(selected_node)

    diameter, avg_path_length = compute_network_statistics(graph_copy)
    return compute_failure_robustness(graph_copy, diameter)

def compute_targeted_failure_robustness(road_snapped_network_graph, num_removals):
    graph_copy = road_snapped_network_graph.copy() # Make a copy
    
    for i in range(num_removals):
        node_degrees = graph_copy.degree()
        # Iterate over the DegreeView object to find the maximum degree
        max_degree = max(degree for _, degree in node_degrees)
        max_degree_node = get_node_with_degree(node_degrees, max_degree)
        graph_copy.remove_node(max_degree_node)

    diameter, avg_path_length = compute_network_statistics(graph_copy)
    return compute_failure_robustness(graph_copy, diameter)

def compute_failure_robustness(road_snapped_network_graph, max_path_length):
    return float(max_path_length) / float(len(road_snapped_network_graph) - 1)

def compute_network_statistics(road_snapped_network_graph):
    path_lengths = get_path_lengths(road_snapped_network_graph) # Get the sum of all possible
    avg_path_length = np.mean(path_lengths)
    max_path_length = max(path_lengths)

    #network_size = len(path_lengths)
    #gcc = sorted(nx.connected_component_subgraphs(road_snapped_network_graph), key=len, reverse=True)
    #giant_component_fraction = float(float(gcc[0].order()) / float(network_size))
    #return max_path_length, avg_path_length, giant_component_fraction
    return max_path_length, avg_path_length

def get_node_with_degree(node_degrees, degree):
    # Iterate over the DegreeView object to find the node with the specified degree
    for node, _ in node_degrees:
        if _ == degree:
            return node
    return None  # Return None if no node with the specified degree is found

def get_path_lengths(snapped_road_network_graph):
    return [sum(nx.single_source_shortest_path_length(snapped_road_network_graph, n).values())
            for n in snapped_road_network_graph]
    
def get_network_coverage(network_graph):
    global TOTAL_NETWORK_ROAD_DISTANCE
    
    travelled_distance = 0
    edge_set = [] # This will contain all the edges travelled
    
    for node1, node2, edge_data in network_graph.edges(data=True):
        string_key1 = f"{node1}_{node2}"
        string_key2 = f"{node2}_{node1}"
        
        if string_key1 not in edge_set and string_key2 not in edge_set:
            edge_set.append(string_key1)
            edge_set.append(string_key2)
            travelled_distance += edge_data['distance'] * 1000 # km to meters   
    return travelled_distance / TOTAL_NETWORK_ROAD_DISTANCE

# %% [markdown]
# ### Graph Error Checks

# %%
# # ERROR CHECK - Checking if there are duplicate routes in the list of routes
def check_duplicate_routes(network):
    routes = network.routes
    seen_routes = set()
    error = "xxx"

    for route_obj in routes:
        standardized_route = tuple(tuple(sorted(sublist)) for sublist in route_obj.route)

        if standardized_route in seen_routes:
            print(f"----- ERROR{error} FOUND EXACT DUPLICATE ROUTES")
        else:
            seen_routes.add(standardized_route)

# %%
# ERROR Check - Checks if routes is consistent with its stops
def check_stops_routes(network):
    error = "xxx"
    # Checks if each node in the route is in the list of stops
    for route in network.routes:
        for connection in route.route:
            if connection[0] not in network.stops:
                print(f"---- ERROR{error} MISSING ROUTE ORIGIN STOP IN LIST OF STOPS ", connection[0])
            if connection[-1] not in network.stops:
                print(f"---- ERROR{error} MISSING ROUTE DEST STOP IN LIST OF STOPS ", connection[-1])
    
    # Reverse routees
    for route in network.reversed_routes:
        if route is None:
            continue
        for connection in route.route:
            if connection[0] not in network.reversed_stops:
                print(f"---- ERROR{error} MISSING REVERSE ROUTE ORIGIN STOP IN LIST OF STOPS ", connection[0])
            if connection[-1] not in network.reversed_stops:
                print(f"---- ERROR{error} MISSING REVERSE ROUTE DEST STOP IN LIST OF STOPS ", connection[-1])

# %%
# ERROR Check - Checks if the routes are in correct order
def check_order_route(network):
    error = "xxx"

    for route in network.routes:
        for connection in route.route:
            if route.route.index(connection) > 0:
                if connection[0] != prev_connection[-1]:
                    print(f"---- ERROR{error} WRONG ORDER DETECTED --")
                    print(prev_connection[0], " - ", prev_connection[-1])
                    print(connection[0], " - ", connection[-1])
                    print("--------------------------")
            prev_connection = connection
    
    # Reversed
    for route in network.reversed_routes:
        if route is None:
            continue
        for connection in route.route:
            if route.route.index(connection) > 0:
                if connection[0] != prev_connection[-1]:
                    print(f"---- ERROR{error} WRONG ORDER DETECTED IN REVERSE ROUTE --")
                    print(prev_connection[0], " - ", prev_connection[-1])
                    print(connection[0], " - ", connection[-1])
                    print("--------------------------")
            prev_connection = connection

# %%
# ERROR CHECK - Checks the consistency of the network with its routes
def check_graph_with_route(network):
    error = "xxx"
    for route in network.routes:
        for connection in route.route:
            if not network.graph.has_node(connection[0]):
                print(f"---- ERROR{error} MISSING NODE IN GRAPH: ", connection[0])
            if not network.graph.has_node(connection[-1]):
                print(f"---- ERROR{error} MISSING NODE IN GRAPH: ", connection[-1])
            if not network.graph.has_edge(connection[0], connection[-1], route.route_id):
                print(f"---- ERROR{error} MISSING EDGE IN GRAPH: ", connection[0], " - ", connection[-1])
    
    # Reversed
    for route in network.reversed_routes:
        if route is None:
            continue
        for connection in route.route:
            if not network.graph.has_node(connection[0]):
                print(f"---- ERROR{error} MISSING REVERSE ROUTE NODE IN GRAPH: ", connection[0])
            if not network.graph.has_node(connection[-1]):
                print(f"---- ERROR{error} MISSING REVERSE ROUTE NODE IN GRAPH: ", connection[-1])
            if not network.graph.has_edge(connection[0], connection[-1], route.route_id):
                print(f"---- ERROR{error} MISSING REVERSE ROUTE NODE IN GRAPH: ", connection[0], " - ", connection[-1])

# %%
# ERROR CHECK - Checks the consistency of the network with its list of stops
def check_graph_with_stops(network):
    error = "xxx"
    # Checks if all stops in the list is in the graph
    for stop in network.stops:
        if not network.graph.has_node(stop):
            print(f"---- ERROR{error} MISSING LIST STOP IN GRAPH: ", stop)
    
    # Reversed Stops
    for stop in network.reversed_stops:
        if not network.graph.has_node(stop):
            print(f"---- ERROR{error} MISSING REVERSED LIST STOP IN GRAPH: ", stop)
            
    # Checks if all nodes in the graph are in the list
    for node, node_data in network.graph.nodes(data=True):
        if node < 10000:
            if node not in network.stops and node not in network.reversed_stops:
                print(f"---- ERROR{error} MISSING GRAPH NODE IN LISTS: ", node)

# %%
def check_duplicate_stops_routes(network):
    error = "xxx"
    
    # Check for duplicate stops in the routes, and duplcoate routes
    for route in network.routes:
        used_stops = []
        used_reverse_stops = []
        used_routes = []
        used_reverse_routes = []
        route_index = network.routes.index(route)
        
        
        reversed_route = network.reversed_routes[route_index]
        for connection in route.route:
            connection_index = route.route.index(connection)
            # Reverse routes
            if reversed_route is not None:
                reversed_connection = reversed_route.route[connection_index]
                reversed_connection1 = reversed_connection[0]
                reversed_connection2 = reversed_connection[-1]
                
                if connection_index == 0:
                    used_reverse_stops.append(reversed_connection1)
                if reversed_connection2 not in used_reverse_stops:
                    used_reverse_stops.append(reversed_connection2)
                else:
                    print(f"---- ERROR{error} DUPLICATE STOPS IN REVERSE ROUTE. STOP ", reversed_connection2)
                    
                pair = f"{reversed_connection1}-{reversed_connection2}"
                if pair not in used_reverse_routes:
                    used_reverse_routes.append(pair)
                else:
                    print(f"---- ERROR{error} DUPLICATE REVERSE ROUTES. ROUTE ", reversed_connection1, " - ", reversed_connection2)
            
            if connection_index == 0:
                used_stops.append(connection[0])
                
            if connection[-1] not in used_stops:
                used_stops.append(connection[-1])
            else:
                print(f"---- ERROR{error} DUPLICATE STOPS IN ROUTE. STOP ", connection[-1])
                
            pair = f"{connection[0]}-{connection[-1]}"
            if pair not in used_routes:
                used_routes.append(pair)
            else:
                print(f"---- ERROR{error} DUPLICATE ROUTES. ROUTE ", connection[0], " - ", connection[-1])

# %% [markdown]
# ### Simplicity

# %%
# TODO: WORKING IN PROGRESS
def simplicity_metric(network):
    routes = network.routes
    
    for route in routes:
        for i in range(len(route) - 1):
            u, v = route[i], route[i + 1]
            
            if graph_of_stops.has_edge(u, v):
                edge_data = graph_of_stops.get_edge_data(u, v)
            else:
                # Skip if there's no direct edge between u and v
                continue
            
            # Edge data might have multiple edges with different keys
            for key in edge_data:
                road_name = edge_data[key].get('name', 'Unnamed Road')
            
            
            
            # Compare

# %% [markdown]
# ### Network Analysis Metrics

# %%
# Longest Route
def get_longest_route(network_routes):
    sorted_routes = sorted(network_routes, key=lambda x: x.length, reverse=True)
    longest_route = sorted_routes[0]
    
    stop_list = [] # Get all the stops
    for connection in longest_route.route:
        if connection[0] not in stop_list:
            stop_list.append(connection[0])
        if connection[-1] not in stop_list:
            stop_list.append(connection[-1])
    
    return longest_route, stop_list

# Shortest Route
def get_shortest_route(network_routes):
    sorted_routes = sorted(network_routes, key=lambda x: x.length, reverse=True)
    shortest_route = sorted_routes[-1]
    
    stop_list = [] # Get all the stops
    for connection in shortest_route.route:
        if connection[0] not in stop_list:
            stop_list.append(connection[0])
        if connection[-1] not in stop_list:
            stop_list.append(connection[-1])
    
    return shortest_route, stop_list

# Average Route Length
def get_average_route_length(network_routes):
    sum_length = sum([n.length for n in network_routes])
    average_length = sum_length / len(network_routes)
    return average_length

# Network Diameter
def get_network_diameter(network_graph):
    diameter = nx.diameter(network_graph)
    return diameter

# %%
# Node Centrality
def get_node_centrality(network_graph):
    degree_centrality = nx.degree_centrality(network_graph)
    betweenness_centrality = nx.betweenness_centrality(network_graph)
    closeness_centrality = nx.closeness_centrality(network_graph)
    
    return degree_centrality, betweenness_centrality, closeness_centrality

# %% [markdown]
# ### Visualizations

# %%
# Function to plot/visualize connected zones on the map
import random

# This is to better visualize the networks
def plot_connected_zones_network_on_map(graph, initial_location=[0, 0], zoom_start=10):
    # Create a map centered at the initial location
    map_center = (14.599512, 120.984222) # TEMPORARY WILL ZOOM TO MANILA
    m = folium.Map(location=map_center, zoom_start=zoom_start, tiles='openstreetmap')
    
    #Colours for Visualization
    colors = [
    "Red", "Green", "Blue", "Yellow", "Orange", "Purple", "Cyan", "Magenta", "Maroon",
    "Olive", "Lime", "Teal", "Navy", "Aqua", "Fuchsia", "Coral", "Indigo", "Violet"]
    
    color_map = {}

    # Iterate over the nodes in the network
    for node, data in graph.nodes(data=True):
        # Check if the node has a geometry attribute
        if 'geometry' in data:
            # Get the geometry of the node
            geometry = data['geometry']

            # Check the geometry type and plot accordingly
            if geometry.geom_type == 'Point':
                # Plot a marker for points    
                #folium.Marker(location=[geometry.y, geometry.x], popup=f"{data['name']}").add_to(m)
                continue
            elif geometry.geom_type in ['Polygon', 'MultiPolygon']:
                
                network_id = data["network_id"]
                
                if network_id not in color_map:
                    color = random.choice(colors)
                    color_map[network_id] = color
                else:
                    color = color_map[network_id]
                
                if geometry.geom_type == 'Polygon':
                    polygons = [geometry]
                else:
                    polygons = geometry.geoms

                for polygon in polygons:
                    coordinates = []
                    for point in polygon.exterior.coords:
                        coordinates.append([point[1], point[0]])
                    folium.Polygon(locations=coordinates, fill=True, color=color, fill_opacity=0.4).add_to(m)

    # Return the map
    return m

# %%
# This is to visualize the stops
def plot_stops_on_map(stops):
    # Iterate over the nodes in the network
    map_center = (14.599512, 120.984222)
    network_map = folium.Map(location=map_center, zoom_start=10, tiles='openstreetmap')
    for stop in stops:
        
        if stop.isTranspo:
            marker_color = 'blue'
        else:
            marker_color = 'red'
            
        folium.Marker(location=[stop.lat, stop.long], popup=f"Transportation: {stop.isTranspo}", icon=folium.Icon(color=marker_color)).add_to(network_map)
        
    return network_map

# %%
#Plotting filtered roads FOR VISUALIZATION ONLY
def plot_all_filtered_roads():
    map_center = (14.599512, 120.984222)
    m = folium.Map(location=map_center, zoom_start=10, tiles='openstreetmap')

    # Iterate through each road
    for index, road in filtered_roads_strings.iterrows():
        line_coords = list(road['geometry'].coords)

        if road['highway'] == 'primary':
            folium.PolyLine(locations=[(y, x) for x, y in line_coords], popup=f"OSMID: {road['osmid']}\nReversed: {road['reversed']} ",  color='blue').add_to(m)

    #     if road['highway'] == 'secondary':
    #         folium.PolyLine(locations=[(y, x) for x, y in line_coords], color='red').add_to(m)

    #     if road['highway'] == 'tertiary':
    #         folium.PolyLine(locations=[(y, x) for x, y in line_coords], color='green').add_to(m)
            
    #     if road['highway'] == 'trunk':
    #         folium.PolyLine(locations=[(y, x) for x, y in line_coords], color='black').add_to(m)
            
    #     if road['highway'] == 'residential':
    #         folium.PolyLine(locations=[(y, x) for x, y in line_coords], color='brown').add_to(m)

    #     if road['highway'] == 'unclassified':
    #         folium.PolyLine(locations=[(y, x) for x, y in line_coords], color='orange').add_to(m)

    # for index, road in filtered_roads_lists.iterrows():
    #     line_coords = list(road['geometry'].coords)
    #     folium.PolyLine(locations=[(y, x) for x, y in line_coords], color='purple').add_to(m)

    # Return the map
    return m

# %%
def plot_route_folium(graph, route, map, route_id, is_reversed):
    # Get the route coordinates
    route_coords = [(graph.nodes[node]['y'], graph.nodes[node]['x']) for node in route]
    # Add the route to the map with a popup and a green color
    
    if is_reversed:
        folium.PolyLine(route_coords, popup=f"{route_id}", color='green').add_to(map)
    else:
        folium.PolyLine(route_coords, popup=f"{route_id}", color='blue').add_to(map)

# %% [markdown]
# ### Data Saving

# %% [markdown]
# #### Genetic Algorithm Exports

# %%
# Export most recent population into pikl in case of errors
def save_recent_population(population_num, population):
    filename = f"GA Backup Files/GA_recent_population_backup.pikl"
    data = {
        "population": population,
        "population_num": population_num,
    }
    
    export_networks(data, filename)
    

# Export current best population into pikl in case of errors
def save_recent_best_population(population_num, population):
    filename = f"GA Backup Files/GA_recent_best_population_backup.pikl"
    data = {
        "population": population,
        "population_num": population_num,
    }
    
    export_networks(data, filename)

# %%
# Import recent population backup file
def import_recent_population():
    filename = f"GA Backup Files/GA_recent_population_backup.pikl"
    data = import_networks(filename)
    
    return data['population_num'], data['population']
    

# Import best population 
def import_recent_best_population():
    filename = f"GA Backup Files/GA_recent_best_population_backup.pikl"
    data = import_networks(filename)
    
    return data['population_num'], data['population']

# %% [markdown]
# ## Main

# %% [markdown]
# ### Manila Test

# %% [markdown]
# #### Reading Data

# %%
# File Paths
Manila_pikl_filepath = "Saved Networks/Manila/"
Manila_map_filepath = "Saved Maps/Manila/"

# %%
# READING DATA (All Amenities in Manila)
#CHANGE THIS BACK
merged_amenities_points_gdf = gpd.read_file('./City Data/Manila_point.geojson')
merged_amenities_polygons_gdf= gpd.read_file('././City Data/Manila_polygon.geojson')

merged_amenities_polygons_gdf['amenity_points'] = None

# %%
# Getting total area to be used for the area connection type
merged_amenities_polygons_gdf['area'] = degrees_to_meters(merged_amenities_polygons_gdf['geometry'].area)
manila_area_sum = merged_amenities_polygons_gdf['area'].sum()

manila_area_sum
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_25960\2666581131.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged_amenities_polygons_gdf['area'] = degrees_to_meters(merged_amenities_polygons_gdf['geometry'].area)
# 135.26544316259222

# %%
# Create spatial index for points
idx = rtree_index.Index()
for j, point in merged_amenities_points_gdf.iterrows():
    idx.insert(j, point['geometry'].bounds)

# Iterate over polygons
for i, polygon in merged_amenities_polygons_gdf.iterrows():
    points_within_polygon = []
    
    # Iterate over points within the bounding box of the polygon
    for j in idx.intersection(polygon['geometry'].bounds):
        point = merged_amenities_points_gdf.loc[j]
        if polygon['geometry'].intersects(point['geometry']):
            points_within_polygon.append(j)
    
    merged_amenities_polygons_gdf.at[i, 'amenity_points'] = points_within_polygon

# %% [markdown]
# #### Importing Manila Zone Network Data

# %%
# ------- LEVEL 1 
# IMPORT INITIAL NETWORK
initial_network_Manila = import_networks(f"{Manila_pikl_filepath}Manila_Initial_Network.pkl")

# IMPORT FILTERED NETWORK
filtered_manila_amenities_network = import_networks(f"{Manila_pikl_filepath}Manila_Filtered_Network.pkl")

# IMPORT COMBINED AMENITIES NETWORK
combined_graph_Manila = import_networks(f"{Manila_pikl_filepath}Manila_Combined_Amenities_Network.pkl")

# ------- LEVEL 2
# IMPORT POPULATION GRAPH
pop_graph = import_networks(f"{Manila_pikl_filepath}Manila_Population_Graph.pkl")

# IMPORT ZONE NETWORK
graph_networks_of_polygons_Manila = import_networks(f"{Manila_pikl_filepath}Manila_Zone_Network.pkl")
networks_map_Manila = plot_connected_zones_network_on_map(graph_networks_of_polygons_Manila, initial_location=[0, 0], zoom_start=100)

add_points_to_graph(initial_network_Manila, graph_networks_of_polygons_Manila) # Add all points

# %%
# # Importing Stop list and Graph (Only to test the same stops)
# list_of_stops_Manila = import_networks(f"{Manila_pikl_filepath}stop_list_Manila.pkl")
# graph_of_stops_Manila = import_networks(f"{Manila_pikl_filepath}stop_graph_Manila.pkl")

# # Visualize the stops
# stops_map = plot_stops_on_map(list_of_stops_Manila)
# stops_map.save(f"{Manila_map_filepath}stops_map.html") # Save the map to an HTML file

# %%
# # Importing Generated Routes (Only to test the same routes)
# # WALKING_DISTANCES -> 300,550,800
# # CONNECTION_TYPES -> "Default", "Area", "Degree", "Mixed"
# import_conn_type = CONNECTION_TYPES[0]
# import_walk_distance = WALKING_DISTANCES[0]

# if import_conn_type == 'Mixed':
#     list_of_networks_Manila = import_networks(f"{Manila_pikl_filepath}Manila_Route_networks_{import_conn_type}.pkl")
# else:
#     list_of_networks_Manila = import_networks(f"{Manila_pikl_filepath}Manila_Route_networks_{import_conn_type}_{import_walk_distance}.pkl")

# %%
# # Importing GA Results (Only to analyze shared results)
# # WALKING_DISTANCES -> 300,550,800
# # CONNECTION_TYPES -> "Default", "Area", "Degree", "Mixed"
# import_conn_type = CONNECTION_TYPES[0]
# import_walk_distance = WALKING_DISTANCES[0]

# if import_conn_type == 'Mixed':
#     population = import_networks(f"{Manila_pikl_filepath}Manila_GA_Route_networks_{import_conn_type}.pkl")
# else:
#     population = import_networks(f"{Manila_pikl_filepath}Manila_GA_Route_networks_{import_conn_type}_{import_walk_distance}.pkl")

# %% [markdown]
# #### Stop Placement (Only to generate new stops)

# %%
# LEVEL 3 - CREATING STOPS TO BE PLACED ON ZONES
graph_of_stops_Manila = copy.deepcopy(CITY_GRAPH)
list_of_stops_Manila = []
place_stops_on_roads(graph_networks_of_polygons_Manila, graph_of_stops_Manila, list_of_stops_Manila) # Adds stops graph_of_stops, and gets the relevant edges
if graph_of_stops_Manila.nodes(len(list_of_stops_Manila)) == {}:
    graph_of_stops_Manila.remove_node(len(list_of_stops_Manila))

# Visualize the stops
stops_map = plot_stops_on_map(list_of_stops_Manila)
stops_map.save(f"{Manila_map_filepath}stops_map.html") # Save the map to an HTML file
# Out:
# Stop ID: 0
# Along edges WAY 1
# POINT B:  (14.575608088564437, 120.97976152074453)
# NEW LINES
# LINESTRING (120.9800499 14.5750983, 120.97976152074453 14.575608088564437)
# LINESTRING (120.97976152074453 14.575608088564437, 120.9793335 14.5763647)
# ---------
# NEW DISTANCES
# 64.39925435411011
# 95.58011949311097
# ORIGINAL DISTANCE: 160.541
# ---------
# HAS EDGE BETWEEN 243973011 and 0 : True
# HAS EDGE BETWEEN 0 and 243973012 : True
#
# Stop ID: 1
# Along edges WAY 2
# POINT B:  (14.5763093, 120.9792208)
# NEW LINES
# LINESTRING (120.9779706 14.5784948, 120.9784756 14.5776301, 120.9785399 14.5775184, 120.9785736 14.5774531, 120.9792208 14.5763093)
# LINESTRING (120.9792208 14.5763093, 120.9795983 14.5755992, 120.9796753 14.5754543, 120.9797241 14.5753625, 120.9803721 14.5741819, 120.9807425 14.5734203, 120.9809511 14.5730182)
# ---------
# NEW DISTANCES
# 276.80940402855873
# 409.10404719388396
# ORIGINAL DISTANCE: 688.462
# ---------
# HAS EDGE BETWEEN 1020279307 and 1 : True
# HAS EDGE BETWEEN 1 and 26032777 : True
#
# Stop ID: 2
# Along edges WAY 2
# POINT B:  (14.575351, 120.9801733)
# NEW LINES
# LINESTRING (120.9795543 14.576476, 120.9797738 14.5760771, 120.9801733 14.575351)
# LINESTRING (120.9801733 14.575351, 120.9802528 14.575209)
# ---------
# NEW DISTANCES
# 141.2210635858894
# 17.895370842102572
# ORIGINAL DISTANCE: 159.685
# ---------
# HAS EDGE BETWEEN 1020278940 and 2 : True
# HAS EDGE BETWEEN 2 and 1067685905 : True
#
# Stop ID: 3
# Along edges WAY 2
# POINT B:  (14.575351, 120.9801733)
# NEW LINES
# LINESTRING (120.9802528 14.575209, 120.9801733 14.575351)
# LINESTRING (120.9801733 14.575351, 120.9797738 14.5760771, 120.9795543 14.576476)
# ---------
# NEW DISTANCES
# 17.895370842102572
# 141.2210635858894
# ORIGINAL DISTANCE: 159.685
# ---------
# HAS EDGE BETWEEN 1067685905 and 3 : True
# HAS EDGE BETWEEN 3 and 1020278940 : True
#
# Stop ID: 4
# Along edges WAY 2
# POINT B:  (14.5790959, 120.9757366)
# NEW LINES
# LINESTRING (120.9747827 14.5825522, 120.9745172 14.582403, 120.9744407 14.5823582, 120.9743777 14.5823219, 120.974302 14.5822843, 120.9740014 14.5821253, 120.9737192 14.5819572, 120.9736079 14.5818638, 120.9735435 14.5817859, 120.973518 14.5817171, 120.9735234 14.5816561, 120.9735596 14.5815834, 120.9737014 14.5812683, 120.9737388 14.5812119, 120.9746872 14.5795438, 120.9747118 14.5795027, 120.9750388 14.5789361, 120.9750987 14.5788917, 120.9751597 14.5788566, 120.9752274 14.5788476, 120.9752868 14.5788593, 120.9753419 14.5788814, 120.9755393 14.5789886, 120.9757366 14.5790959)
# LINESTRING (120.9757366 14.5790959, 120.9764204 14.5794612, 120.976701 14.5796079)
# ---------
# NEW DISTANCES
# 395.99453657751377
# 118.35938848191151
# ORIGINAL DISTANCE: 721.0540000000001
# ---------
# HAS EDGE BETWEEN 5829002202 and 4 : True
# HAS EDGE BETWEEN 4 and 4393408024 : True
#
# Stop ID: 5
# Along edges WAY 2
# POINT B:  (14.5789361, 120.9750388)
# NEW LINES
# LINESTRING (120.976701 14.5796079, 120.9764204 14.5794612, 120.9757366 14.5790959, 120.9755393 14.5789886, 120.9753419 14.5788814, 120.9752868 14.5788593, 120.9752274 14.5788476, 120.9751597 14.5788566, 120.9750987 14.5788917, 120.9750388 14.5789361)
# LINESTRING (120.9750388 14.5789361, 120.9747118 14.5795027, 120.9746872 14.5795438, 120.9737388 14.5812119, 120.9737014 14.5812683, 120.9735596 14.5815834, 120.9735234 14.5816561, 120.973518 14.5817171, 120.9735435 14.5817859, 120.9736079 14.5818638, 120.9737192 14.5819572, 120.9740014 14.5821253, 120.974302 14.5822843, 120.9743777 14.5823219, 120.9744407 14.5823582, 120.9745172 14.582403, 120.9747827 14.5825522)
# ---------
# NEW DISTANCES
# 193.92615735647888
# 401.0528248858776
# ORIGINAL DISTANCE: 721.0539999999999
# ---------
# HAS EDGE BETWEEN 4393408024 and 5 : True
# HAS EDGE BETWEEN 5 and 5829002202 : True
#
# Stop ID: 6
# Along edges WAY 1
# POINT B:  (14.574452810677588, 120.98168069154926)
# NEW LINES
# LINESTRING (120.9815364 14.5747503, 120.98168069154926 14.574452810677588)
# LINESTRING (120.98168069154926 14.574452810677588, 120.9818665 14.5740697)
# ---------
# NEW DISTANCES
# 36.40335174527453
# 46.88017161808659
# ORIGINAL DISTANCE: 83.602
# ---------
# HAS EDGE BETWEEN 26032773 and 6 : True
# HAS EDGE BETWEEN 6 and 6124583345 : True
#
# Stop ID: 7
# Along edges WAY 2
# POINT B:  (14.5746468, 120.9813213)
# NEW LINES
# LINESTRING (120.9815364 14.5747503, 120.9813213 14.5746468)
# LINESTRING (120.9813213 14.5746468, 120.9812622 14.5746188)
# ---------
# NEW DISTANCES
# 25.853765911933266
# 7.082181252836658
# ORIGINAL DISTANCE: 32.932
# ---------
# HAS EDGE BETWEEN 26032773 and 7 : True
# HAS EDGE BETWEEN 7 and 279672199 : True
#
# Stop ID: 8
# Along edges WAY 1
# POINT B:  (14.574967189574764, 120.9819420116847)
# NEW LINES
# LINESTRING (120.9823391 14.5751795, 120.9819420116847 14.574967189574764)
# LINESTRING (120.9819420116847 14.574967189574764, 120.9815364 14.5747503)
# ---------
# NEW DISTANCES
# 48.81423526275125
# 49.86322374808939
# ORIGINAL DISTANCE: 98.691
# ---------
# HAS EDGE BETWEEN 170828317 and 8 : True
# HAS EDGE BETWEEN 8 and 26032773 : True
#
# Stop ID: 9
# Along edges WAY 1
# POINT B:  (14.575289666791154, 120.98127144212852)
# NEW LINES
# LINESTRING (120.9810873 14.5756645, 120.98127144212852 14.575289666791154)
# LINESTRING (120.98127144212852 14.575289666791154, 120.9815364 14.5747503)
# ---------
# NEW DISTANCES
# 45.975885477384416
# 66.15645286305813
# ORIGINAL DISTANCE: 112.559
# ---------
# HAS EDGE BETWEEN 26032770 and 9 : True
# HAS EDGE BETWEEN 9 and 26032773 : True
#
# Stop ID: 10
# Along edges WAY 1
# POINT B:  (14.575542848666412, 120.98216947930472)
# NEW LINES
# LINESTRING (120.9823391 14.5751795, 120.98216947930472 14.575542848666412)
# LINESTRING (120.98216947930472 14.575542848666412, 120.9818928 14.5761355)
# ---------
# NEW DISTANCES
# 44.16269092244401
# 72.03355865983808
# ORIGINAL DISTANCE: 116.649
# ---------
# HAS EDGE BETWEEN 170828317 and 10 : True
# HAS EDGE BETWEEN 10 and 279672161 : True
#
# Stop ID: 11
# Along edges WAY 1
# POINT B:  (14.576691300149957, 120.98164652942236)
# NEW LINES
# LINESTRING (120.9818928 14.5761355, 120.98164652942236 14.576691300149957)
# LINESTRING (120.98164652942236 14.576691300149957, 120.9813317 14.5774018)
# ---------
# NEW DISTANCES
# 66.97804221891585
# 85.6210096770245
# ORIGINAL DISTANCE: 153.208
# ---------
# HAS EDGE BETWEEN 279672161 and 11 : True
# HAS EDGE BETWEEN 11 and 34012966 : True
#
# Stop ID: 12
# Along edges WAY 1
# POINT B:  (14.57489906945822, 120.98250586185277)
# NEW LINES
# LINESTRING (120.982723 14.5745339, 120.98250586185277 14.57489906945822)
# LINESTRING (120.98250586185277 14.57489906945822, 120.9823391 14.5751795)
# ---------
# NEW DISTANCES
# 46.69037892302651
# 35.85630860980138
# ORIGINAL DISTANCE: 82.827
# ---------
# HAS EDGE BETWEEN 6124583346 and 12 : True
# HAS EDGE BETWEEN 12 and 170828317 : True
#
# Stop ID: 13
# Along edges WAY 1
# POINT B:  (14.57542028772798, 120.98280562123834)
# NEW LINES
# LINESTRING (120.9823391 14.5751795, 120.98280562123834 14.57542028772798)
# LINESTRING (120.98280562123834 14.57542028772798, 120.9830777 14.5755607)
# ---------
# NEW DISTANCES
# 56.895412188844105
# 33.180938777593234
# ORIGINAL DISTANCE: 90.081
# ---------
# HAS EDGE BETWEEN 170828317 and 13 : True
# HAS EDGE BETWEEN 13 and 279672188 : True
#
# Stop ID: 14
# Along edges WAY 1
# POINT B:  (14.575379032088824, 120.98272568567087)
# NEW LINES
# LINESTRING (120.9830777 14.5755607, 120.98272568567087 14.575379032088824)
# LINESTRING (120.98272568567087 14.575379032088824, 120.9823391 14.5751795)
# ---------
# NEW DISTANCES
# 42.929520250925826
# 47.146830713241805
# ORIGINAL DISTANCE: 90.081
# ---------
# HAS EDGE BETWEEN 279672188 and 14 : True
# HAS EDGE BETWEEN 14 and 170828317 : True
#
# Stop ID: 15
# Along edges WAY 2
# POINT B:  (14.5752607, 120.9809862)
# NEW LINES
# LINESTRING (120.9812622 14.5746188, 120.9809862 14.5752607)
# LINESTRING (120.9809862 14.5752607, 120.9808659 14.5755403)
# ---------
# NEW DISTANCES
# 76.99875536680895
# 33.54255833398052
# ORIGINAL DISTANCE: 110.988
# ---------
# HAS EDGE BETWEEN 279672199 and 15 : True
# HAS EDGE BETWEEN 15 and 279672198 : True
#
# Stop ID: 16
# Along edges WAY 1
# POINT B:  (14.576114435231892, 120.98087567691744)
# NEW LINES
# LINESTRING (120.9804963 14.576921, 120.98087567691744 14.576114435231892)
# LINESTRING (120.98087567691744 14.576114435231892, 120.9810873 14.5756645)
# ---------
# NEW DISTANCES
# 98.16024114495507
# 54.757465113583564
# ORIGINAL DISTANCE: 153.512
# ---------
# HAS EDGE BETWEEN 26032767 and 16 : True
# HAS EDGE BETWEEN 16 and 26032770 : True
#
# Stop ID: 17
# Along edges WAY 1
# POINT B:  (14.576886247183769, 120.98042051852063)
# NEW LINES
# LINESTRING (120.9804963 14.576921, 120.98042051852063 14.576886247183769)
# LINESTRING (120.98042051852063 14.576886247183769, 120.9802443 14.5768054)
# ---------
# NEW DISTANCES
# 9.026156537936822
# 20.990620131272994
# ORIGINAL DISTANCE: 30.011
# ---------
# HAS EDGE BETWEEN 26032767 and 17 : True
# HAS EDGE BETWEEN 17 and 316966616 : True
#
# Stop ID: 18
# Along edges WAY 2
# POINT B:  (14.5771734, 120.98093)
# NEW LINES
# LINESTRING (120.9813317 14.5774018, 120.98093 14.5771734)
# LINESTRING (120.98093 14.5771734, 120.9805394 14.5769446, 120.9804963 14.576921)
# ---------
# NEW DISTANCES
# 50.1236142975247
# 54.44325080065094
# ORIGINAL DISTANCE: 104.6
# ---------
# HAS EDGE BETWEEN 34012966 and 18 : True
# HAS EDGE BETWEEN 18 and 26032767 : True
#
# Stop ID: 19
# Along edges WAY 1
# POINT B:  (14.577285899159, 120.98032216193003)
# NEW LINES
# LINESTRING (120.9800665 14.5778216, 120.98032216193003 14.577285899159)
# LINESTRING (120.98032216193003 14.577285899159, 120.9804963 14.576921)
# ---------
# NEW DISTANCES
# 65.36216779894974
# 44.521835613542166
# ORIGINAL DISTANCE: 110.308
# ---------
# HAS EDGE BETWEEN 26032763 and 19 : True
# HAS EDGE BETWEEN 19 and 26032767 : True
#
# Stop ID: 20
# Along edges WAY 2
# POINT B:  (14.5710303, 120.9856207)
# NEW LINES
# LINESTRING (120.9853833 14.5714885, 120.9856207 14.5710303)
# LINESTRING (120.9856207 14.5710303, 120.9857262 14.5708314, 120.986148 14.5701102)
# ---------
# NEW DISTANCES
# 56.78638362024691
# 116.58868198733947
# ORIGINAL DISTANCE: 174.007
# ---------
# HAS EDGE BETWEEN 33956013 and 20 : True
# HAS EDGE BETWEEN 20 and 33956095 : True
#
# Stop ID: 21
# Along edges WAY 2
# POINT B:  (14.5711381, 120.9863859)
# NEW LINES
# LINESTRING (120.9866339 14.5706873, 120.9863859 14.5711381)
# LINESTRING (120.9863859 14.5711381, 120.9860019 14.5718134)
# ---------
# NEW DISTANCES
# 56.587070281941294
# 85.41175592980329
# ORIGINAL DISTANCE: 142.5
# ---------
# HAS EDGE BETWEEN 33956092 and 21 : True
# HAS EDGE BETWEEN 21 and 260211888 : True
#
# Stop ID: 22
# Along edges WAY 1
# POINT B:  (14.571608613202208, 120.98561197196105)
# NEW LINES
# LINESTRING (120.9860019 14.5718134, 120.98561197196105 14.571608613202208)
# LINESTRING (120.98561197196105 14.571608613202208, 120.9853833 14.5714885)
# ---------
# NEW DISTANCES
# 47.73916553358086
# 27.997362061903623
# ORIGINAL DISTANCE: 75.744
# ---------
# HAS EDGE BETWEEN 260211888 and 22 : True
# HAS EDGE BETWEEN 22 and 33956013 : True
#
# Stop ID: 23
# Along edges WAY 1
# POINT B:  (14.571632488366726, 120.9853060030134)
# NEW LINES
# LINESTRING (120.9851321 14.5719564, 120.9853060030134 14.571632488366726)
# LINESTRING (120.9853060030134 14.571632488366726, 120.9853833 14.5714885)
# ---------
# NEW DISTANCES
# 40.44290680653694
# 17.97767668864688
# ORIGINAL DISTANCE: 58.632
# ---------
# HAS EDGE BETWEEN 459406040 and 23 : True
# HAS EDGE BETWEEN 23 and 33956013 : True
#
# Stop ID: 24
# Along edges WAY 1
# POINT B:  (14.57213553298244, 120.98503314658676)
# NEW LINES
# LINESTRING (120.9848371 14.5724904, 120.98503314658676 14.57213553298244)
# LINESTRING (120.98503314658676 14.57213553298244, 120.9851321 14.5719564)
# ---------
# NEW DISTANCES
# 44.58686683413508
# 22.506520502702685
# ORIGINAL DISTANCE: 67.332
# ---------
# HAS EDGE BETWEEN 33956025 and 24 : True
# HAS EDGE BETWEEN 24 and 459406040 : True
#
# Stop ID: 25
# Along edges WAY 1
# POINT B:  (14.572344386784135, 120.98455067054681)
# NEW LINES
# LINESTRING (120.9839042 14.5720148, 120.98455067054681 14.572344386784135)
# LINESTRING (120.98455067054681 14.572344386784135, 120.9848371 14.5724904)
# ---------
# NEW DISTANCES
# 78.63198446488848
# 34.83836712529131
# ORIGINAL DISTANCE: 113.474
# ---------
# HAS EDGE BETWEEN 1302744521 and 25 : True
# HAS EDGE BETWEEN 25 and 33956025 : True
#
# Stop ID: 26
# Along edges WAY 2
# POINT B:  (14.5719607, 120.9862883)
# NEW LINES
# LINESTRING (120.9867489 14.5721975, 120.9862883 14.5719607)
# LINESTRING (120.9862883 14.5719607, 120.9860019 14.5718134)
# ---------
# NEW DISTANCES
# 56.12572002096598
# 34.90187712969918
# ORIGINAL DISTANCE: 91.03200000000001
# ---------
# HAS EDGE BETWEEN 191592313 and 26 : True
# HAS EDGE BETWEEN 26 and 260211888 : True
#
# Stop ID: 27
# Along edges WAY 1
# POINT B:  (14.57200946424889, 120.98589228903573)
# NEW LINES
# LINESTRING (120.9860019 14.5718134, 120.98589228903573 14.57200946424889)
# LINESTRING (120.98589228903573 14.57200946424889, 120.9857327 14.5722949)
# ---------
# NEW DISTANCES
# 24.70071458471504
# 35.960714741214304
# ORIGINAL DISTANCE: 60.876
# ---------
# HAS EDGE BETWEEN 260211888 and 27 : True
# HAS EDGE BETWEEN 27 and 459406041 : True
#
# Stop ID: 28
# Along edges WAY 1
# POINT B:  (14.572640863835048, 120.98554489869493)
# NEW LINES
# LINESTRING (120.9857327 14.5722949, 120.98554489869493 14.572640863835048)
# LINESTRING (120.98554489869493 14.572640863835048, 120.9854578 14.5728013)
# ---------
# NEW DISTANCES
# 43.299520532721004
# 20.079995730183548
# ORIGINAL DISTANCE: 63.608
# ---------
# HAS EDGE BETWEEN 459406041 and 28 : True
# HAS EDGE BETWEEN 28 and 260211891 : True
#
# Stop ID: 29
# Along edges WAY 1
# POINT B:  (14.573041831727133, 120.98593473468249)
# NEW LINES
# LINESTRING (120.9854578 14.5728013, 120.98593473468249 14.573041831727133)
# LINESTRING (120.98593473468249 14.573041831727133, 120.9861893 14.5731702)
# ---------
# NEW DISTANCES
# 57.87677554161082
# 30.891055277782822
# ORIGINAL DISTANCE: 88.768
# ---------
# HAS EDGE BETWEEN 260211891 and 29 : True
# HAS EDGE BETWEEN 29 and 33956046 : True
#
# Stop ID: 30
# Along edges WAY 1
# POINT B:  (14.573007379320229, 120.98586641817067)
# NEW LINES
# LINESTRING (120.9861893 14.5731702, 120.98586641817067 14.573007379320229)
# LINESTRING (120.98586641817067 14.573007379320229, 120.9854578 14.5728013)
# ---------
# NEW DISTANCES
# 39.18128962453404
# 49.586541192924784
# ORIGINAL DISTANCE: 88.768
# ---------
# HAS EDGE BETWEEN 33956046 and 30 : True
# HAS EDGE BETWEEN 30 and 260211891 : True
#
# Stop ID: 31
# Along edges WAY 1
# POINT B:  (14.572176468323274, 120.98422129466081)
# NEW LINES
# LINESTRING (120.9848371 14.5724904, 120.98422129466081 14.572176468323274)
# LINESTRING (120.98422129466081 14.572176468323274, 120.9839042 14.5720148)
# ---------
# NEW DISTANCES
# 74.90096175684124
# 38.56938983277605
# ORIGINAL DISTANCE: 113.474
# ---------
# HAS EDGE BETWEEN 33956025 and 31 : True
# HAS EDGE BETWEEN 31 and 1302744521 : True
#
# Stop ID: 32
# Along edges WAY 2
# POINT B:  (14.572524, 120.9849075)
# NEW LINES
# LINESTRING (120.9848371 14.5724904, 120.9849075 14.572524)
# LINESTRING (120.9849075 14.572524, 120.9854578 14.5728013)
# ---------
# NEW DISTANCES
# 8.448328551499415
# 66.7680367467078
# ORIGINAL DISTANCE: 75.215
# ---------
# HAS EDGE BETWEEN 33956025 and 32 : True
# HAS EDGE BETWEEN 32 and 260211891 : True
#
# Stop ID: 33
# Along edges WAY 2
# POINT B:  (14.572524, 120.9849075)
# NEW LINES
# LINESTRING (120.9854578 14.5728013, 120.9849075 14.572524)
# LINESTRING (120.9849075 14.572524, 120.9848371 14.5724904)
# ---------
# NEW DISTANCES
# 66.7680367467078
# 8.448328551499415
# ORIGINAL DISTANCE: 75.215
# ---------
# HAS EDGE BETWEEN 260211891 and 33 : True
# HAS EDGE BETWEEN 33 and 33956025 : True
#
# Stop ID: 34
# Along edges WAY 2
# POINT B:  (14.5731367, 120.9844566)
# NEW LINES
# LINESTRING (120.9838587 14.5741701, 120.9844566 14.5731367)
# LINESTRING (120.9844566 14.5731367, 120.9847896 14.5725789, 120.9848371 14.5724904)
# ---------
# NEW DISTANCES
# 131.24367930128264
# 82.43103859262763
# ORIGINAL DISTANCE: 214.42000000000002
# ---------
# HAS EDGE BETWEEN 25526952 and 34 : True
# HAS EDGE BETWEEN 34 and 33956025 : True
#
# Stop ID: 35
# Along edges WAY 2
# POINT B:  (14.5740798, 120.9847471)
# NEW LINES
# LINESTRING (120.9854578 14.5728013, 120.9847471 14.5740798)
# LINESTRING (120.9847471 14.5740798, 120.9845323 14.574462)
# ---------
# NEW DISTANCES
# 160.86029201473445
# 48.20877865872856
# ORIGINAL DISTANCE: 209.81
# ---------
# HAS EDGE BETWEEN 260211891 and 35 : True
# HAS EDGE BETWEEN 35 and 260211894 : True
#
# Stop ID: 36
# Along edges WAY 2
# POINT B:  (14.5766123, 120.9879334)
# NEW LINES
# LINESTRING (120.9860574 14.5798981, 120.9867675 14.5786294, 120.9868942 14.5784041, 120.9869379 14.5783299, 120.987234 14.5778094, 120.9872813 14.5777301, 120.9873805 14.5775626, 120.9875988 14.5771856, 120.9877323 14.5769549, 120.987767 14.5768949, 120.9879334 14.5766123)
# LINESTRING (120.9879334 14.5766123, 120.9882093 14.5761439, 120.9882534 14.576069)
# ---------
# NEW DISTANCES
# 415.9803582775207
# 69.30134743152763
# ORIGINAL DISTANCE: 486.9870000000001
# ---------
# HAS EDGE BETWEEN 34012968 and 36 : True
# HAS EDGE BETWEEN 36 and 34011583 : True
#
# Stop ID: 37
# Along edges WAY 2
# POINT B:  (14.5793778, 120.986458)
# NEW LINES
# LINESTRING (120.9868484 14.5786858, 120.9864972 14.5793084, 120.986458 14.5793778)
# LINESTRING (120.986458 14.5793778, 120.9864464 14.5793984, 120.9863948 14.5794895, 120.9861396 14.5799401)
# ---------
# NEW DISTANCES
# 87.3621582429993
# 71.04891264774426
# ORIGINAL DISTANCE: 158.968
# ---------
# HAS EDGE BETWEEN 33957031 and 37 : True
# HAS EDGE BETWEEN 37 and 33957058 : True
#
# Stop ID: 38
# Along edges WAY 2
# POINT B:  (14.5799709, 120.9861977)
# NEW LINES
# LINESTRING (120.9869416 14.5803178, 120.9861977 14.5799709)
# LINESTRING (120.9861977 14.5799709, 120.9861396 14.5799401)
# ---------
# NEW DISTANCES
# 88.87619315188773
# 7.1281151328989605
# ORIGINAL DISTANCE: 95.992
# ---------
# HAS EDGE BETWEEN 33956676 and 38 : True
# HAS EDGE BETWEEN 38 and 33957058 : True
#
# Stop ID: 39
# Along edges WAY 2
# POINT B:  (14.5821295, 120.9849071)
# NEW LINES
# LINESTRING (120.9861396 14.5799401, 120.9860288 14.5801357, 120.9857687 14.5805951, 120.985392 14.5812625, 120.9853083 14.5814077, 120.9849071 14.5821295)
# LINESTRING (120.9849071 14.5821295, 120.9848545 14.5822257)
# ---------
# NEW DISTANCES
# 276.2634781974316
# 12.059074346017118
# ORIGINAL DISTANCE: 289.341
# ---------
# HAS EDGE BETWEEN 33957058 and 39 : True
# HAS EDGE BETWEEN 39 and 9773039793 : True
#
# Stop ID: 40
# Along edges WAY 2
# POINT B:  (14.5823012, 120.9846797)
# NEW LINES
# LINESTRING (120.9846464 14.5823585, 120.9846797 14.5823012)
# LINESTRING (120.9846797 14.5823012, 120.9847547 14.5821678, 120.9848053 14.582079, 120.9850058 14.5817271, 120.9852156 14.5813589, 120.9852884 14.58123, 120.9856006 14.5806854, 120.985755 14.5804193, 120.9860574 14.5798981)
# ---------
# NEW DISTANCES
# 7.284961637491853
# 304.52758357724747
# ORIGINAL DISTANCE: 312.899
# ---------
# HAS EDGE BETWEEN 117101805 and 40 : True
# HAS EDGE BETWEEN 40 and 34012968 : True
#
# Stop ID: 41
# Along edges WAY 2
# POINT B:  (14.5824121, 120.985016)
# NEW LINES
# LINESTRING (120.9849029 14.5824753, 120.985016 14.5824121)
# LINESTRING (120.985016 14.5824121, 120.986015 14.5819198, 120.9861787 14.5818391)
# ---------
# NEW DISTANCES
# 14.050885371562027
# 140.4161338518554
# ORIGINAL DISTANCE: 154.464
# ---------
# HAS EDGE BETWEEN 9773122286 and 41 : True
# HAS EDGE BETWEEN 41 and 1058992856 : True
#
# Stop ID: 42
# Along edges WAY 1
# POINT B:  (14.579853095383811, 120.98720542338697)
# NEW LINES
# LINESTRING (120.9876304 14.5791045, 120.98720542338697 14.579853095383811)
# LINESTRING (120.98720542338697 14.579853095383811, 120.9869416 14.5803178)
# ---------
# NEW DISTANCES
# 94.64476893937517
# 58.75306240754081
# ORIGINAL DISTANCE: 153.935
# ---------
# HAS EDGE BETWEEN 33957032 and 42 : True
# HAS EDGE BETWEEN 42 and 33956676 : True
#
# Stop ID: 43
# Along edges WAY 1
# POINT B:  (14.580486544233112, 120.98730179532141)
# NEW LINES
# LINESTRING (120.9875993 14.5806259, 120.98730179532141 14.580486544233112)
# LINESTRING (120.98730179532141 14.580486544233112, 120.9869416 14.5803178)
# ---------
# NEW DISTANCES
# 35.573569130718724
# 43.070823381305296
# ORIGINAL DISTANCE: 78.633
# ---------
# HAS EDGE BETWEEN 33956682 and 43 : True
# HAS EDGE BETWEEN 43 and 33956676 : True
#
# Stop ID: 44
# Along edges WAY 2
# POINT B:  (14.5807427, 120.987865)
# NEW LINES
# LINESTRING (120.988127 14.5808653, 120.987865 14.5807427)
# LINESTRING (120.987865 14.5807427, 120.9875993 14.5806259)
# ---------
# NEW DISTANCES
# 31.32215078043956
# 31.412592177596178
# ORIGINAL DISTANCE: 62.722
# ---------
# HAS EDGE BETWEEN 33957027 and 44 : True
# HAS EDGE BETWEEN 44 and 33956682 : True
#
# Stop ID: 45
# Along edges WAY 2
# POINT B:  (14.5786889, 120.9837409)
# NEW LINES
# LINESTRING (120.9860574 14.5798981, 120.9859919 14.5798642, 120.9859661 14.5798509, 120.9855911 14.5796572, 120.9853969 14.5795566, 120.9848409 14.5792744, 120.9846928 14.5791917, 120.9840809 14.5788685, 120.9838993 14.5787726, 120.9838303 14.5787362, 120.9837409 14.5786889)
# LINESTRING (120.9837409 14.5786889, 120.9836437 14.5786374, 120.9835127 14.5785677, 120.9834887 14.578555, 120.9832551 14.5784316)
# ---------
# NEW DISTANCES
# 283.2152623232714
# 59.58934001573878
# ORIGINAL DISTANCE: 342.849
# ---------
# HAS EDGE BETWEEN 34012968 and 45 : True
# HAS EDGE BETWEEN 45 and 170828239 : True
#
# Stop ID: 46
# Along edges WAY 2
# POINT B:  (14.5817891, 120.9862728)
# NEW LINES
# LINESTRING (120.9861787 14.5818391, 120.9862728 14.5817891)
# LINESTRING (120.9862728 14.5817891, 120.9866422 14.5815917, 120.9866733 14.5815751, 120.9871228 14.5813371, 120.9875114 14.5811314, 120.9879565 14.5809011, 120.988127 14.5808653)
# ---------
# NEW DISTANCES
# 11.550896943105533
# 224.4299088568173
# ORIGINAL DISTANCE: 236.677
# ---------
# HAS EDGE BETWEEN 1058992856 and 46 : True
# HAS EDGE BETWEEN 46 and 33957027 : True
#
# Stop ID: 47
# Along edges WAY 2
# POINT B:  (14.5675286, 120.9875954)
# NEW LINES
# LINESTRING (120.9867971 14.5689498, 120.9875954 14.5675286)
# LINESTRING (120.9875954 14.5675286, 120.9882918 14.5663271)
# ---------
# NEW DISTANCES
# 179.24191642784882
# 152.65945625368764
# ORIGINAL DISTANCE: 333.06100000000004
# ---------
# HAS EDGE BETWEEN 33955830 and 47 : True
# HAS EDGE BETWEEN 47 and 25526943 : True
#
# Stop ID: 48
# Along edges WAY 2
# POINT B:  (14.5690491, 120.9871517)
# NEW LINES
# LINESTRING (120.9874776 14.5692104, 120.9872322 14.5690893, 120.9871517 14.5690491)
# LINESTRING (120.9871517 14.5690491, 120.9867971 14.5689498)
# ---------
# NEW DISTANCES
# 39.394440402900976
# 39.76086243132554
# ORIGINAL DISTANCE: 79.121
# ---------
# HAS EDGE BETWEEN 34012930 and 48 : True
# HAS EDGE BETWEEN 48 and 33955830 : True
#
# Stop ID: 49
# Along edges WAY 2
# POINT B:  (14.5690491, 120.9871517)
# NEW LINES
# LINESTRING (120.9867971 14.5689498, 120.9871517 14.5690491)
# LINESTRING (120.9871517 14.5690491, 120.9872322 14.5690893, 120.9874776 14.5692104)
# ---------
# NEW DISTANCES
# 39.76086243132554
# 39.394440402900976
# ORIGINAL DISTANCE: 79.121
# ---------
# HAS EDGE BETWEEN 33955830 and 49 : True
# HAS EDGE BETWEEN 49 and 34012930 : True
#
# Stop ID: 50
# Along edges WAY 2
# POINT B:  (14.5693509, 120.987777)
# NEW LINES
# LINESTRING (120.9882141 14.5695556, 120.9878739 14.5693964, 120.987777 14.5693509)
# LINESTRING (120.987777 14.5693509, 120.9874776 14.5692104)
# ---------
# NEW DISTANCES
# 52.265409119940394
# 35.81397728433383
# ORIGINAL DISTANCE: 88.06700000000001
# ---------
# HAS EDGE BETWEEN 33956049 and 50 : True
# HAS EDGE BETWEEN 50 and 34012930 : True
#
# Stop ID: 51
# Along edges WAY 2
# POINT B:  (14.5693509, 120.987777)
# NEW LINES
# LINESTRING (120.9874776 14.5692104, 120.987777 14.5693509)
# LINESTRING (120.987777 14.5693509, 120.9878739 14.5693964, 120.9882141 14.5695556)
# ---------
# NEW DISTANCES
# 35.81397728433383
# 52.265409119940394
# ORIGINAL DISTANCE: 88.06700000000001
# ---------
# HAS EDGE BETWEEN 34012930 and 51 : True
# HAS EDGE BETWEEN 51 and 33956049 : True
#
# Stop ID: 52
# Along edges WAY 1
# POINT B:  (14.569631971759355, 120.98837585720734)
# NEW LINES
# LINESTRING (120.9886098 14.5697424, 120.98837585720734 14.569631971759355)
# LINESTRING (120.98837585720734 14.569631971759355, 120.9882141 14.5695556)
# ---------
# NEW DISTANCES
# 28.015073195809574
# 19.37156246931019
# ORIGINAL DISTANCE: 47.381
# ---------
# HAS EDGE BETWEEN 33956182 and 52 : True
# HAS EDGE BETWEEN 52 and 33956049 : True
#
# Stop ID: 53
# Along edges WAY 1
# POINT B:  (14.569632356655177, 120.9883766725351)
# NEW LINES
# LINESTRING (120.9882141 14.5695556, 120.9883766725351 14.569632356655177)
# LINESTRING (120.9883766725351 14.569632356655177, 120.9886098 14.5697424)
# ---------
# NEW DISTANCES
# 19.469201195837826
# 27.917434468928672
# ORIGINAL DISTANCE: 47.381
# ---------
# HAS EDGE BETWEEN 33956049 and 53 : True
# HAS EDGE BETWEEN 53 and 33956182 : True
#
# Stop ID: 54
# Along edges WAY 1
# POINT B:  (14.569553013224713, 120.98728147575018)
# NEW LINES
# LINESTRING (120.9874776 14.5692104, 120.98728147575018 14.569553013224713)
# LINESTRING (120.98728147575018 14.569553013224713, 120.9868645 14.5702814)
# ---------
# NEW DISTANCES
# 43.401864661140216
# 92.27226904739405
# ORIGINAL DISTANCE: 136.147
# ---------
# HAS EDGE BETWEEN 34012930 and 54 : True
# HAS EDGE BETWEEN 54 and 33956099 : True
#
# Stop ID: 55
# Along edges WAY 2
# POINT B:  (14.5697671, 120.9886644)
# NEW LINES
# LINESTRING (120.9886098 14.5697424, 120.9886644 14.5697671)
# LINESTRING (120.9886644 14.5697671, 120.9889892 14.5699156)
# ---------
# NEW DISTANCES
# 6.487553758209178
# 38.66595663037925
# ORIGINAL DISTANCE: 45.144999999999996
# ---------
# HAS EDGE BETWEEN 33956182 and 55 : True
# HAS EDGE BETWEEN 55 and 33955833 : True
#
# Stop ID: 56
# Along edges WAY 2
# POINT B:  (14.5697671, 120.9886644)
# NEW LINES
# LINESTRING (120.9889892 14.5699156, 120.9886644 14.5697671)
# LINESTRING (120.9886644 14.5697671, 120.9886098 14.5697424)
# ---------
# NEW DISTANCES
# 38.66595663037925
# 6.487553758209178
# ORIGINAL DISTANCE: 45.144999999999996
# ---------
# HAS EDGE BETWEEN 33955833 and 56 : True
# HAS EDGE BETWEEN 56 and 33956182 : True
#
# Stop ID: 57
# Along edges WAY 1
# POINT B:  (14.570667796256677, 120.98706675817564)
# NEW LINES
# LINESTRING (120.9868222 14.5705409, 120.98706675817564 14.570667796256677)
# LINESTRING (120.98706675817564 14.570667796256677, 120.9874858 14.5708852)
# ---------
# NEW DISTANCES
# 29.860863366063462
# 51.16402344266466
# ORIGINAL DISTANCE: 81.03
# ---------
# HAS EDGE BETWEEN 33956005 and 57 : True
# HAS EDGE BETWEEN 57 and 33956048 : True
#
# Stop ID: 58
# Along edges WAY 1
# POINT B:  (14.568923684236015, 120.98650942699493)
# NEW LINES
# LINESTRING (120.9859867 14.5688762, 120.98650942699493 14.568923684236015)
# LINESTRING (120.98650942699493 14.568923684236015, 120.9867971 14.5689498)
# ---------
# NEW DISTANCES
# 56.57507412995904
# 31.134859251645047
# ORIGINAL DISTANCE: 87.598
# ---------
# HAS EDGE BETWEEN 416500384 and 58 : True
# HAS EDGE BETWEEN 58 and 33955830 : True
#
# Stop ID: 59
# Along edges WAY 1
# POINT B:  (14.568916061231159, 120.98642549075342)
# NEW LINES
# LINESTRING (120.9867971 14.5689498, 120.98642549075342 14.568916061231159)
# LINESTRING (120.98642549075342 14.568916061231159, 120.9859867 14.5688762)
# ---------
# NEW DISTANCES
# 40.21931343546851
# 47.49061994420966
# ORIGINAL DISTANCE: 87.598
# ---------
# HAS EDGE BETWEEN 33955830 and 59 : True
# HAS EDGE BETWEEN 59 and 416500384 : True
#
# Stop ID: 60
# Along edges WAY 1
# POINT B:  (14.569721928606679, 120.98636519638201)
# NEW LINES
# LINESTRING (120.986148 14.5701102, 120.98636519638201 14.569721928606679)
# LINESTRING (120.98636519638201 14.569721928606679, 120.9867971 14.5689498)
# ---------
# NEW DISTANCES
# 48.922336286742286
# 97.28751371219207
# ORIGINAL DISTANCE: 146.727
# ---------
# HAS EDGE BETWEEN 33956095 and 60 : True
# HAS EDGE BETWEEN 60 and 33955830 : True
#
# Stop ID: 61
# Along edges WAY 1
# POINT B:  (14.569989393273183, 120.98580307129737)
# NEW LINES
# LINESTRING (120.9854374 14.5698613, 120.98580307129737 14.569989393273183)
# LINESTRING (120.98580307129737 14.569989393273183, 120.986148 14.5701102)
# ---------
# NEW DISTANCES
# 41.8768746340576
# 39.500634530651276
# ORIGINAL DISTANCE: 81.328
# ---------
# HAS EDGE BETWEEN 32548284 and 61 : True
# HAS EDGE BETWEEN 61 and 33956095 : True
#
# Stop ID: 62
# Along edges WAY 1
# POINT B:  (14.56994950200249, 120.98568918331016)
# NEW LINES
# LINESTRING (120.986148 14.5701102, 120.98568918331016 14.56994950200249)
# LINESTRING (120.98568918331016 14.56994950200249, 120.9854374 14.5698613)
# ---------
# NEW DISTANCES
# 52.54302399344626
# 28.834485172814926
# ORIGINAL DISTANCE: 81.328
# ---------
# HAS EDGE BETWEEN 33956095 and 62 : True
# HAS EDGE BETWEEN 62 and 32548284 : True
#
# Stop ID: 63
# Along edges WAY 2
# POINT B:  (14.5710806, 120.9878415)
# NEW LINES
# LINESTRING (120.9874858 14.5708852, 120.9878415 14.5710806)
# LINESTRING (120.9878415 14.5710806, 120.9882182 14.5712875)
# ---------
# NEW DISTANCES
# 44.00774275318741
# 46.60389911812828
# ORIGINAL DISTANCE: 90.62899999999999
# ---------
# HAS EDGE BETWEEN 33956048 and 63 : True
# HAS EDGE BETWEEN 63 and 33956004 : True
#
# Stop ID: 64
# Along edges WAY 1
# POINT B:  (14.571529349267077, 120.98866105871083)
# NEW LINES
# LINESTRING (120.9882182 14.5712875, 120.98866105871083 14.571529349267077)
# LINESTRING (120.98866105871083 14.571529349267077, 120.9889386 14.5716809)
# ---------
# NEW DISTANCES
# 54.71349022111669
# 34.28820765437401
# ORIGINAL DISTANCE: 89.018
# ---------
# HAS EDGE BETWEEN 33956004 and 64 : True
# HAS EDGE BETWEEN 64 and 33956169 : True
#
# Stop ID: 65
# Along edges WAY 1
# POINT B:  (14.571386329402806, 120.9872044062303)
# NEW LINES
# LINESTRING (120.9874858 14.5708852, 120.9872044062303 14.571386329402806)
# LINESTRING (120.9872044062303 14.571386329402806, 120.9867489 14.5721975)
# ---------
# NEW DISTANCES
# 63.19741888832242
# 102.29759300551962
# ORIGINAL DISTANCE: 166.079
# ---------
# HAS EDGE BETWEEN 33956048 and 65 : True
# HAS EDGE BETWEEN 65 and 191592313 : True
#
# Stop ID: 66
# Along edges WAY 1
# POINT B:  (14.571686914940916, 120.9870356174879)
# NEW LINES
# LINESTRING (120.9867489 14.5721975, 120.9870356174879 14.571686914940916)
# LINESTRING (120.9870356174879 14.571686914940916, 120.9874858 14.5708852)
# ---------
# NEW DISTANCES
# 64.39055453541383
# 101.10445735798221
# ORIGINAL DISTANCE: 166.079
# ---------
# HAS EDGE BETWEEN 191592313 and 66 : True
# HAS EDGE BETWEEN 66 and 33956048 : True
#
# Stop ID: 67
# Along edges WAY 1
# POINT B:  (14.572415105955661, 120.98714617262765)
# NEW LINES
# LINESTRING (120.9874823 14.5725992, 120.98714617262765 14.572415105955661)
# LINESTRING (120.98714617262765 14.572415105955661, 120.9867489 14.5721975)
# ---------
# NEW DISTANCES
# 41.5558956125362
# 49.11665984572551
# ORIGINAL DISTANCE: 90.69
# ---------
# HAS EDGE BETWEEN 33956012 and 67 : True
# HAS EDGE BETWEEN 67 and 191592313 : True
#
# Stop ID: 68
# Along edges WAY 1
# POINT B:  (14.572552563680699, 120.98654463635701)
# NEW LINES
# LINESTRING (120.9861893 14.5731702, 120.98654463635701 14.572552563680699)
# LINESTRING (120.98654463635701 14.572552563680699, 120.9867489 14.5721975)
# ---------
# NEW DISTANCES
# 78.33473881731726
# 45.0321603769071
# ORIGINAL DISTANCE: 123.795
# ---------
# HAS EDGE BETWEEN 33956046 and 68 : True
# HAS EDGE BETWEEN 68 and 191592313 : True
#
# Stop ID: 69
# Along edges WAY 1
# POINT B:  (14.572509340674321, 120.98656950275969)
# NEW LINES
# LINESTRING (120.9867489 14.5721975, 120.98656950275969 14.572509340674321)
# LINESTRING (120.98656950275969 14.572509340674321, 120.9861893 14.5731702)
# ---------
# NEW DISTANCES
# 39.55021655833315
# 83.81668263692143
# ORIGINAL DISTANCE: 123.795
# ---------
# HAS EDGE BETWEEN 191592313 and 69 : True
# HAS EDGE BETWEEN 69 and 33956046 : True
#
# Stop ID: 70
# Along edges WAY 1
# POINT B:  (14.578298495282127, 120.98806853909414)
# NEW LINES
# LINESTRING (120.9883943 14.5776992, 120.98806853909414 14.578298495282127)
# LINESTRING (120.98806853909414 14.578298495282127, 120.9876304 14.5791045)
# ---------
# NEW DISTANCES
# 75.02743513146469
# 100.90672618849116
# ORIGINAL DISTANCE: 176.567
# ---------
# HAS EDGE BETWEEN 33956668 and 70 : True
# HAS EDGE BETWEEN 70 and 33957032 : True
#
# Stop ID: 71
# Along edges WAY 2
# POINT B:  (14.5787138, 120.9868997)
# NEW LINES
# LINESTRING (120.9876304 14.5791045, 120.9868997 14.5787138)
# LINESTRING (120.9868997 14.5787138, 120.9868484 14.5786858)
# ---------
# NEW DISTANCES
# 89.82503645822133
# 6.336926436000754
# ORIGINAL DISTANCE: 96.175
# ---------
# HAS EDGE BETWEEN 33957032 and 71 : True
# HAS EDGE BETWEEN 71 and 33957031 : True
#
# Stop ID: 72
# Along edges WAY 2
# POINT B:  (14.5791547, 120.9892513)
# NEW LINES
# LINESTRING (120.9889092 14.5797835, 120.9892513 14.5791547)
# LINESTRING (120.9892513 14.5791547, 120.989682 14.5783896)
# ---------
# NEW DISTANCES
# 78.73629253063167
# 96.54200956256436
# ORIGINAL DISTANCE: 175.901
# ---------
# HAS EDGE BETWEEN 33957034 and 72 : True
# HAS EDGE BETWEEN 72 and 33956703 : True
#
# Stop ID: 73
# Along edges WAY 1
# POINT B:  (14.579903842998364, 120.98924656737134)
# NEW LINES
# LINESTRING (120.9889092 14.5797835, 120.98924656737134 14.579903842998364)
# LINESTRING (120.98924656737134 14.579903842998364, 120.9895745 14.5800208)
# ---------
# NEW DISTANCES
# 38.715679123504955
# 37.632166688323856
# ORIGINAL DISTANCE: 76.303
# ---------
# HAS EDGE BETWEEN 33957034 and 73 : True
# HAS EDGE BETWEEN 73 and 33957035 : True
#
# Stop ID: 74
# Along edges WAY 1
# POINT B:  (14.57987377259478, 120.98916226130176)
# NEW LINES
# LINESTRING (120.9895745 14.5800208, 120.98916226130176 14.57987377259478)
# LINESTRING (120.98916226130176 14.57987377259478, 120.9889092 14.5797835)
# ---------
# NEW DISTANCES
# 47.3068810855072
# 29.040964728518407
# ORIGINAL DISTANCE: 76.303
# ---------
# HAS EDGE BETWEEN 33957035 and 74 : True
# HAS EDGE BETWEEN 74 and 33957034 : True
#
# Stop ID: 75
# Along edges WAY 1
# POINT B:  (14.579275754961616, 120.9879387778743)
# NEW LINES
# LINESTRING (120.9882569 14.5794524, 120.9879387778743 14.579275754961616)
# LINESTRING (120.9879387778743 14.579275754961616, 120.9876304 14.5791045)
# ---------
# NEW DISTANCES
# 39.4604804598517
# 38.252939310240265
# ORIGINAL DISTANCE: 77.731
# ---------
# HAS EDGE BETWEEN 33957033 and 75 : True
# HAS EDGE BETWEEN 75 and 33957032 : True
#
# Stop ID: 76
# Along edges WAY 1
# POINT B:  (14.579328554438058, 120.98803385948052)
# NEW LINES
# LINESTRING (120.9876304 14.5791045, 120.98803385948052 14.579328554438058)
# LINESTRING (120.98803385948052 14.579328554438058, 120.9882569 14.5794524)
# ---------
# NEW DISTANCES
# 50.047217281018845
# 27.66620249201659
# ORIGINAL DISTANCE: 77.731
# ---------
# HAS EDGE BETWEEN 33957032 and 76 : True
# HAS EDGE BETWEEN 76 and 33957033 : True
#
# Stop ID: 77
# Along edges WAY 1
# POINT B:  (14.579553665106374, 120.98845638181237)
# NEW LINES
# LINESTRING (120.9889092 14.5797835, 120.98845638181237 14.579553665106374)
# LINESTRING (120.98845638181237 14.579553665106374, 120.9882569 14.5794524)
# ---------
# NEW DISTANCES
# 55.02365615148697
# 24.24057414815602
# ORIGINAL DISTANCE: 79.266
# ---------
# HAS EDGE BETWEEN 33957034 and 77 : True
# HAS EDGE BETWEEN 77 and 33957033 : True
#
# Stop ID: 78
# Along edges WAY 1
# POINT B:  (14.579565251303322, 120.98847920774408)
# NEW LINES
# LINESTRING (120.9882569 14.5794524, 120.98847920774408 14.579565251303322)
# LINESTRING (120.98847920774408 14.579565251303322, 120.9889092 14.5797835)
# ---------
# NEW DISTANCES
# 27.014268468109346
# 52.24996183004655
# ORIGINAL DISTANCE: 79.266
# ---------
# HAS EDGE BETWEEN 33957033 and 78 : True
# HAS EDGE BETWEEN 78 and 33957034 : True
#
# Stop ID: 79
# Along edges WAY 2
# POINT B:  (14.5801886, 120.9886802)
# NEW LINES
# LINESTRING (120.9884458 14.5806034, 120.9886802 14.5801886)
# LINESTRING (120.9886802 14.5801886, 120.9889092 14.5797835)
# ---------
# NEW DISTANCES
# 52.386751220448105
# 51.16594920160985
# ORIGINAL DISTANCE: 103.917
# ---------
# HAS EDGE BETWEEN 33956704 and 79 : True
# HAS EDGE BETWEEN 79 and 33957034 : True
#
# Stop ID: 80
# Along edges WAY 2
# POINT B:  (14.5804214, 120.9888409)
# NEW LINES
# LINESTRING (120.9884458 14.5806034, 120.9888409 14.5804214)
# LINESTRING (120.9888409 14.5804214, 120.9895745 14.5800208)
# ---------
# NEW DISTANCES
# 47.09707716965982
# 90.62933819871753
# ORIGINAL DISTANCE: 137.735
# ---------
# HAS EDGE BETWEEN 33956704 and 80 : True
# HAS EDGE BETWEEN 80 and 33957035 : True
#
# Stop ID: 81
# Along edges WAY 2
# POINT B:  (14.5807138, 120.9883218)
# NEW LINES
# LINESTRING (120.988127 14.5808653, 120.9883218 14.5807138)
# LINESTRING (120.9883218 14.5807138, 120.9884458 14.5806034)
# ---------
# NEW DISTANCES
# 26.86285725588409
# 18.10388592426895
# ORIGINAL DISTANCE: 45.025000000000006
# ---------
# HAS EDGE BETWEEN 33957027 and 81 : True
# HAS EDGE BETWEEN 81 and 33956704 : True
#
# Stop ID: 82
# Along edges WAY 2
# POINT B:  (14.5810872, 120.9893246)
# NEW LINES
# LINESTRING (120.9884458 14.5806034, 120.9886812 14.5807295, 120.9887399 14.5807582, 120.9888012 14.5807642, 120.9889153 14.5807751, 120.9890625 14.5808262, 120.9891629 14.5808926, 120.9892539 14.5809716, 120.9893246 14.5810872)
# LINESTRING (120.9893246 14.5810872, 120.9893638 14.5812138, 120.9893825 14.5813083, 120.9893988 14.5813839, 120.989417 14.5814431, 120.9894557 14.5815042, 120.9895263 14.5815716)
# ---------
# NEW DISTANCES
# 108.77943236130481
# 57.835570525552555
# ORIGINAL DISTANCE: 172.49699999999999
# ---------
# HAS EDGE BETWEEN 33956704 and 82 : True
# HAS EDGE BETWEEN 82 and 33957088 : True
#
# Stop ID: 83
# Along edges WAY 2
# POINT B:  (14.5819591, 120.9888849)
# NEW LINES
# LINESTRING (120.9889824 14.5821026, 120.9888849 14.5819591)
# LINESTRING (120.9888849 14.5819591, 120.9888481 14.5819166, 120.9887805 14.5818856, 120.9886948 14.5818668, 120.9885532 14.5818274, 120.9884364 14.5817589, 120.9883385 14.5816636, 120.9882824 14.5815585, 120.9882412 14.5814478, 120.988227 14.5812971, 120.9882447 14.5811875, 120.9882541 14.5811285, 120.9882402 14.5810663, 120.988127 14.5808653)
# ---------
# NEW DISTANCES
# 19.038829083109828
# 146.00142897227374
# ORIGINAL DISTANCE: 182.83100000000002
# ---------
# HAS EDGE BETWEEN 33957090 and 83 : True
# HAS EDGE BETWEEN 83 and 33957027 : True
#
# Stop ID: 84
# Along edges WAY 2
# POINT B:  (14.5810187, 120.9880582)
# NEW LINES
# LINESTRING (120.9872722 14.5827309, 120.9880582 14.5810187)
# LINESTRING (120.9880582 14.5810187, 120.988127 14.5808653)
# ---------
# NEW DISTANCES
# 207.5168891609447
# 18.52139034662369
# ORIGINAL DISTANCE: 226.927
# ---------
# HAS EDGE BETWEEN 1058992845 and 84 : True
# HAS EDGE BETWEEN 84 and 33957027 : True
#
# Stop ID: 85
# Along edges WAY 2
# POINT B:  (14.5811852, 120.9903214)
# NEW LINES
# LINESTRING (120.9906798 14.5804296, 120.9903214 14.5811852)
# LINESTRING (120.9903214 14.5811852, 120.9899607 14.5820011)
# ---------
# NEW DISTANCES
# 92.09233829351723
# 98.28675839036829
# ORIGINAL DISTANCE: 191.128
# ---------
# HAS EDGE BETWEEN 33957037 and 85 : True
# HAS EDGE BETWEEN 85 and 314144309 : True
#
# Stop ID: 86
# Along edges WAY 2
# POINT B:  (14.5811852, 120.9903214)
# NEW LINES
# LINESTRING (120.9899607 14.5820011, 120.9903214 14.5811852)
# LINESTRING (120.9903214 14.5811852, 120.9906798 14.5804296)
# ---------
# NEW DISTANCES
# 98.28675839036829
# 92.09233829351723
# ORIGINAL DISTANCE: 191.128
# ---------
# HAS EDGE BETWEEN 314144309 and 86 : True
# HAS EDGE BETWEEN 86 and 33957037 : True
#
# Stop ID: 87
# Along edges WAY 2
# POINT B:  (14.5816566, 120.9896123)
# NEW LINES
# LINESTRING (120.9895263 14.5815716, 120.9896123 14.5816566)
# LINESTRING (120.9896123 14.5816566, 120.9899607 14.5820011)
# ---------
# NEW DISTANCES
# 13.203371702199238
# 53.50089792963025
# ORIGINAL DISTANCE: 66.829
# ---------
# HAS EDGE BETWEEN 33957088 and 87 : True
# HAS EDGE BETWEEN 87 and 314144309 : True
#
# Stop ID: 88
# Along edges WAY 2
# POINT B:  (14.5816566, 120.9896123)
# NEW LINES
# LINESTRING (120.9899607 14.5820011, 120.9896123 14.5816566)
# LINESTRING (120.9896123 14.5816566, 120.9895263 14.5815716)
# ---------
# NEW DISTANCES
# 53.50089792963025
# 13.203371702199238
# ORIGINAL DISTANCE: 66.829
# ---------
# HAS EDGE BETWEEN 314144309 and 88 : True
# HAS EDGE BETWEEN 88 and 33957088 : True
#
# Stop ID: 89
# Along edges WAY 2
# POINT B:  (14.5824019, 120.9887095)
# NEW LINES
# LINESTRING (120.9889824 14.5821026, 120.9888332 14.5822112, 120.9887582 14.5823015, 120.9887095 14.5824019)
# LINESTRING (120.9887095 14.5824019, 120.9885542 14.5827772, 120.9884 14.5831501, 120.9882013 14.5836311)
# ---------
# NEW DISTANCES
# 44.28795104134039
# 146.61532042248064
# ORIGINAL DISTANCE: 192.523
# ---------
# HAS EDGE BETWEEN 33957090 and 89 : True
# HAS EDGE BETWEEN 89 and 33957092 : True
#
# Stop ID: 90
# Along edges WAY 2
# POINT B:  (14.5833985, 120.9875067)
# NEW LINES
# LINESTRING (120.9870513 14.5832573, 120.9875067 14.5833985)
# LINESTRING (120.9875067 14.5833985, 120.9875614 14.583415, 120.9881019 14.5836, 120.9882013 14.5836311)
# ---------
# NEW DISTANCES
# 51.49897944253926
# 79.1482335455914
# ORIGINAL DISTANCE: 130.563
# ---------
# HAS EDGE BETWEEN 33957110 and 90 : True
# HAS EDGE BETWEEN 90 and 33957092 : True
#
# Stop ID: 91
# Along edges WAY 2
# POINT B:  (14.5836, 120.9881019)
# NEW LINES
# LINESTRING (120.9882013 14.5836311, 120.9881019 14.5836)
# LINESTRING (120.9881019 14.5836, 120.9875614 14.583415, 120.9875067 14.5833985, 120.9870513 14.5832573)
# ---------
# NEW DISTANCES
# 11.250099325289355
# 119.38967196404514
# ORIGINAL DISTANCE: 130.563
# ---------
# HAS EDGE BETWEEN 33957092 and 91 : True
# HAS EDGE BETWEEN 91 and 33957110 : True
#
# Stop ID: 92
# Along edges WAY 2
# POINT B:  (14.5837881, 120.9886809)
# NEW LINES
# LINESTRING (120.9890726 14.5839213, 120.989021 14.5839057, 120.988936 14.5838801, 120.9887524 14.5838132, 120.9886809 14.5837881)
# LINESTRING (120.9886809 14.5837881, 120.9885762 14.5837539, 120.9884791 14.5837242, 120.9883015 14.5836625, 120.9882013 14.5836311)
# ---------
# NEW DISTANCES
# 44.70694893172272
# 54.521056107398316
# ORIGINAL DISTANCE: 99.184
# ---------
# HAS EDGE BETWEEN 33957128 and 92 : True
# HAS EDGE BETWEEN 92 and 33957092 : True
#
# Stop ID: 93
# Along edges WAY 2
# POINT B:  (14.5837539, 120.9885762)
# NEW LINES
# LINESTRING (120.9882013 14.5836311, 120.9883015 14.5836625, 120.9884791 14.5837242, 120.9885762 14.5837539)
# LINESTRING (120.9885762 14.5837539, 120.9886809 14.5837881, 120.9887524 14.5838132, 120.988936 14.5838801, 120.989021 14.5839057, 120.9890726 14.5839213)
# ---------
# NEW DISTANCES
# 42.62135111056573
# 56.60594332722302
# ORIGINAL DISTANCE: 99.184
# ---------
# HAS EDGE BETWEEN 33957092 and 93 : True
# HAS EDGE BETWEEN 93 and 33957128 : True
#
# Stop ID: 94
# Along edges WAY 2
# POINT B:  (14.5818975, 120.989252)
# NEW LINES
# LINESTRING (120.9895263 14.5815716, 120.9895107 14.5816522, 120.9894945 14.5817021, 120.9894651 14.5817405, 120.989252 14.5818975)
# LINESTRING (120.989252 14.5818975, 120.9889824 14.5821026)
# ---------
# NEW DISTANCES
# 46.62525480899131
# 36.86398010805147
# ORIGINAL DISTANCE: 85.97200000000001
# ---------
# HAS EDGE BETWEEN 33957088 and 94 : True
# HAS EDGE BETWEEN 94 and 33957090 : True
#
# Stop ID: 95
# Along edges WAY 2
# POINT B:  (14.5822492, 120.9904455)
# NEW LINES
# LINESTRING (120.9905915 14.5822263, 120.9904455 14.5822492)
# LINESTRING (120.9904455 14.5822492, 120.9903707 14.5822149, 120.9902872 14.5821765, 120.9899607 14.5820011)
# ---------
# NEW DISTANCES
# 15.935171301344733
# 59.01363544255496
# ORIGINAL DISTANCE: 74.959
# ---------
# HAS EDGE BETWEEN 314144440 and 95 : True
# HAS EDGE BETWEEN 95 and 314144309 : True
#
# Stop ID: 96
# Along edges WAY 2
# POINT B:  (14.5822149, 120.9903707)
# NEW LINES
# LINESTRING (120.9899607 14.5820011, 120.9902872 14.5821765, 120.9903707 14.5822149)
# LINESTRING (120.9903707 14.5822149, 120.9904455 14.5822492, 120.9905915 14.5822263)
# ---------
# NEW DISTANCES
# 50.11472886065728
# 23.82603756545817
# ORIGINAL DISTANCE: 74.959
# ---------
# HAS EDGE BETWEEN 314144309 and 96 : True
# HAS EDGE BETWEEN 96 and 314144440 : True
#
# Stop ID: 97
# Along edges WAY 2
# POINT B:  (14.5831091, 120.9894509)
# NEW LINES
# LINESTRING (120.9899607 14.5820011, 120.9896027 14.5827756, 120.9894509 14.5831091)
# LINESTRING (120.9894509 14.5831091, 120.9893215 14.5833935, 120.9890726 14.5839213)
# ---------
# NEW DISTANCES
# 134.33960920723993
# 98.67896357669926
# ORIGINAL DISTANCE: 233.933
# ---------
# HAS EDGE BETWEEN 314144309 and 97 : True
# HAS EDGE BETWEEN 97 and 33957128 : True
#
# Stop ID: 98
# Along edges WAY 2
# POINT B:  (14.5833935, 120.9893215)
# NEW LINES
# LINESTRING (120.9890726 14.5839213, 120.9893215 14.5833935)
# LINESTRING (120.9893215 14.5833935, 120.9894509 14.5831091, 120.9896027 14.5827756, 120.9899607 14.5820011)
# ---------
# NEW DISTANCES
# 64.2626883165764
# 168.75766586259226
# ORIGINAL DISTANCE: 233.933
# ---------
# HAS EDGE BETWEEN 33957128 and 98 : True
# HAS EDGE BETWEEN 98 and 314144309 : True
#
# Stop ID: 99
# Along edges WAY 1
# POINT B:  (14.584016552828482, 120.98934553814068)
# NEW LINES
# LINESTRING (120.9899028 14.584211, 120.98934553814068 14.584016552828482)
# LINESTRING (120.98934553814068 14.584016552828482, 120.9890726 14.5839213)
# ---------
# NEW DISTANCES
# 63.78592689226642
# 31.241951096548917
# ORIGINAL DISTANCE: 94.97
# ---------
# HAS EDGE BETWEEN 159443308 and 99 : True
# HAS EDGE BETWEEN 99 and 33957128 : True
#
# Stop ID: 100
# Along edges WAY 1
# POINT B:  (14.584106706082734, 120.98960389238287)
# NEW LINES
# LINESTRING (120.9890726 14.5839213, 120.98960389238287 14.584106706082734)
# LINESTRING (120.98960389238287 14.584106706082734, 120.9899028 14.584211)
# ---------
# NEW DISTANCES
# 60.81416998551075
# 34.213708002141956
# ORIGINAL DISTANCE: 94.97
# ---------
# HAS EDGE BETWEEN 33957128 and 100 : True
# HAS EDGE BETWEEN 100 and 159443308 : True
#
# Stop ID: 101
# Along edges WAY 2
# POINT B:  (14.5875293, 120.9869329)
# NEW LINES
# LINESTRING (120.9882013 14.5836311, 120.9880769 14.5840033, 120.988039 14.5841336, 120.9879855 14.5843181, 120.9878229 14.5848514, 120.9877543 14.5850765, 120.9876411 14.5854227, 120.9874583 14.585961, 120.9873228 14.5863603, 120.9871843 14.5867768, 120.987143 14.586901, 120.9869329 14.5875293)
# LINESTRING (120.9869329 14.5875293, 120.9868658 14.5877363, 120.9867071 14.5882382)
# ---------
# NEW DISTANCES
# 452.45248901318644
# 82.12309687394982
# ORIGINAL DISTANCE: 536.9749999999999
# ---------
# HAS EDGE BETWEEN 33957092 and 101 : True
# HAS EDGE BETWEEN 101 and 1059036057 : True
#
# Stop ID: 102
# Along edges WAY 2
# POINT B:  (14.5635378, 120.9946891)
# NEW LINES
# LINESTRING (120.9943036 14.5643463, 120.994328 14.5642967, 120.9943426 14.5642656, 120.9944881 14.5639613, 120.9945678 14.5637982, 120.9946405 14.5636421, 120.9946891 14.5635378)
# LINESTRING (120.9946891 14.5635378, 120.9947075 14.5635027, 120.994843 14.5632079, 120.9948617 14.5631677, 120.9951171 14.562618)
# ---------
# NEW DISTANCES
# 98.6319359264422
# 111.73495663638197
# ORIGINAL DISTANCE: 211.19199999999995
# ---------
# HAS EDGE BETWEEN 25004636 and 102 : True
# HAS EDGE BETWEEN 102 and 25006626 : True
#
# Stop ID: 103
# Along edges WAY 2
# POINT B:  (14.5643356, 120.994419)
# NEW LINES
# LINESTRING (120.9951972 14.5626614, 120.995032 14.5630212, 120.9949306 14.5632406, 120.9947447 14.5636458, 120.9947285 14.5636801, 120.994419 14.5643356)
# LINESTRING (120.994419 14.5643356, 120.9943959 14.5643861)
# ---------
# NEW DISTANCES
# 203.34029687629703
# 6.11699970186452
# ORIGINAL DISTANCE: 210.28
# ---------
# HAS EDGE BETWEEN 21717801 and 103 : True
# HAS EDGE BETWEEN 103 and 191592042 : True
#
# Stop ID: 104
# Along edges WAY 2
# POINT B:  (14.5636768, 120.9956791)
# NEW LINES
# LINESTRING (120.9951649 14.5647487, 120.9951839 14.5647069, 120.9956791 14.5636768)
# LINESTRING (120.9956791 14.5636768, 120.9959896 14.5629901)
# ---------
# NEW DISTANCES
# 130.90651051447276
# 83.02139448142404
# ORIGINAL DISTANCE: 214.762
# ---------
# HAS EDGE BETWEEN 32614910 and 104 : True
# HAS EDGE BETWEEN 104 and 25004292 : True
#
# Stop ID: 105
# Along edges WAY 2
# POINT B:  (14.5644155, 120.9944633)
# NEW LINES
# LINESTRING (120.9951649 14.5647487, 120.9951303 14.5647335, 120.9944633 14.5644155)
# LINESTRING (120.9944633 14.5644155, 120.9943959 14.5643861)
# ---------
# NEW DISTANCES
# 84.11729384320171
# 7.958530418424172
# ORIGINAL DISTANCE: 92.065
# ---------
# HAS EDGE BETWEEN 32614910 and 105 : True
# HAS EDGE BETWEEN 105 and 191592042 : True
#
# Stop ID: 106
# Along edges WAY 2
# POINT B:  (14.5649164, 120.9955292)
# NEW LINES
# LINESTRING (120.9957228 14.5650052, 120.9955292 14.5649164)
# LINESTRING (120.9955292 14.5649164, 120.9952012 14.564765, 120.9951649 14.5647487)
# ---------
# NEW DISTANCES
# 23.061037333047548
# 43.42281909139438
# ORIGINAL DISTANCE: 66.473
# ---------
# HAS EDGE BETWEEN 1132110707 and 106 : True
# HAS EDGE BETWEEN 106 and 32614910 : True
#
# Stop ID: 107
# Along edges WAY 2
# POINT B:  (14.5652569, 120.9949353)
# NEW LINES
# LINESTRING (120.9948661 14.5654105, 120.9949353 14.5652569)
# LINESTRING (120.9949353 14.5652569, 120.9951389 14.5648047, 120.9951649 14.5647487)
# ---------
# NEW DISTANCES
# 18.55913767285532
# 61.432636202270686
# ORIGINAL DISTANCE: 80.309
# ---------
# HAS EDGE BETWEEN 243426126 and 107 : True
# HAS EDGE BETWEEN 107 and 32614910 : True
#
# Stop ID: 108
# Along edges WAY 2
# POINT B:  (14.5652569, 120.9949353)
# NEW LINES
# LINESTRING (120.9951649 14.5647487, 120.9951389 14.5648047, 120.9949353 14.5652569)
# LINESTRING (120.9949353 14.5652569, 120.9948661 14.5654105)
# ---------
# NEW DISTANCES
# 61.432636202270686
# 18.55913767285532
# ORIGINAL DISTANCE: 80.309
# ---------
# HAS EDGE BETWEEN 32614910 and 108 : True
# HAS EDGE BETWEEN 108 and 243426126 : True
#
# Stop ID: 109
# Along edges WAY 2
# POINT B:  (14.5686294, 120.9923061)
# NEW LINES
# LINESTRING (120.9919761 14.5693684, 120.9920051 14.5693054, 120.9923061 14.5686294)
# LINESTRING (120.9923061 14.5686294, 120.992403 14.5684215, 120.9928128 14.5675539, 120.9928656 14.567441, 120.993021 14.5671065, 120.9930613 14.5670153, 120.9932004 14.5666999)
# ---------
# NEW DISTANCES
# 89.16485919358884
# 234.23312086151296
# ORIGINAL DISTANCE: 324.681
# ---------
# HAS EDGE BETWEEN 5867060681 and 109 : True
# ...
#
# STOP ID: 4571
# SEEN ADDED NODE1! 2504 - 14.5837811, 120.9748558
# EDGE NODES (2504, 21590497)
# Transpo Stop WAY 2
# POINT B:  (14.5830557, 120.9752869)
# NEW LINES
# LINESTRING (120.9748558 14.5837811, 120.9752869 14.5830557)
# LINESTRING (120.9752869 14.5830557, 120.9753493 14.5829055)
# ORIGINAL LINE: LINESTRING (120.9748558 14.5837811, 120.9752869 14.5830557, 120.9753493 14.5829055)
# ---------
# NEW DISTANCES
# 92.73547740480284
# 17.92756423864993
# ORIGINAL DISTANCE: 110.51553381000639
# ---------
# HAS EDGE BETWEEN 2504 and 4571 : True
# HAS EDGE BETWEEN 4571 and 21590497 : True
#
# STOP ID: 4572
# SEEN ADDED NODE2! 2358 - 14.5840426, 120.9749952
# EDGE NODES (12067342, 2358)
# Transpo Stop WAY 2
# POINT B:  (14.5835852, 120.9752192)
# NEW LINES
# LINESTRING (120.9755533 14.5830191, 120.9754585 14.5831484, 120.9752192 14.5835852)
# LINESTRING (120.9752192 14.5835852, 120.975104 14.5838164, 120.9749952 14.5840426)
# ORIGINAL LINE: LINESTRING (120.9755533 14.5830191, 120.9754585 14.5831484, 120.9752192 14.5835852, 120.975104 14.5838164, 120.9749952 14.5840426)
# ---------
# NEW DISTANCES
# 72.24510346068196
# 56.07020377309317
# ORIGINAL DISTANCE: 128.22261885485617
# ---------
# HAS EDGE BETWEEN 12067342 and 4572 : True
# HAS EDGE BETWEEN 4572 and 2358 : True
#
# STOP ID: 4573
# SEEN ADDED NODE1! 1067 - 14.568783, 120.9829582
# EDGE NODES (1067, 8057579272)
# Transpo Stop WAY 2
# POINT B:  (14.5649152, 120.9846734)
# NEW LINES
# LINESTRING (120.9829582 14.568783, 120.9830729 14.5685302, 120.9839289 14.5666119, 120.9843938 14.5655543, 120.9846734 14.5649152)
# LINESTRING (120.9846734 14.5649152, 120.9849008 14.5643956, 120.9849448 14.5642985)
# ORIGINAL LINE: LINESTRING (120.9829582 14.568783, 120.9830729 14.5685302, 120.9839289 14.5666119, 120.9843938 14.5655543, 120.9846734 14.5649152, 120.9849008 14.5643956, 120.9849448 14.5642985)
# ---------
# NEW DISTANCES
# 466.16161551609815
# 74.23850945978307
# ORIGINAL DISTANCE: 540.3998805275388
# ---------
# HAS EDGE BETWEEN 1067 and 4573 : True
# HAS EDGE BETWEEN 4573 and 8057579272 : True
#
# STOP ID: 4574
# EDGE NODES (8366466914, 3199833787)
# Transpo Stop WAY 2
# POINT B:  (14.5800304, 120.9770465)
# NEW LINES
# LINESTRING (120.9765798 14.5808219, 120.9770465 14.5800304)
# LINESTRING (120.9770465 14.5800304, 120.9771181 14.5799)
# ORIGINAL LINE: LINESTRING (120.9765798 14.5808219, 120.9770465 14.5800304, 120.9771181 14.5799)
# ---------
# NEW DISTANCES
# 100.98784880358214
# 16.36145171980557
# ORIGINAL DISTANCE: 117.753
# ---------
# HAS EDGE BETWEEN 8366466914 and 4574 : True
# HAS EDGE BETWEEN 4574 and 3199833787 : True
#
# STOP ID: 4575
# EDGE NODES (3202651584, 8366466913)
# Transpo Stop WAY 2
# POINT B:  (14.5800943, 120.977234)
# NEW LINES
# LINESTRING (120.9773439 14.5799075, 120.977234 14.5800943)
# LINESTRING (120.977234 14.5800943, 120.9767573 14.5809217)
# ORIGINAL LINE: LINESTRING (120.9773439 14.5799075, 120.977234 14.5800943, 120.9767573 14.5809217)
# ---------
# NEW DISTANCES
# 23.820786497443372
# 104.9742303402206
# ORIGINAL DISTANCE: 129.24
# ---------
# HAS EDGE BETWEEN 3202651584 and 4575 : True
# HAS EDGE BETWEEN 4575 and 8366466913 : True
#
# STOP ID: 4576
# SEEN ADDED NODE2! 1519 - 14.622788, 120.9890269
# EDGE NODES (1655369853, 1519)
# Transpo Stop WAY 2
# POINT B:  (14.6236761, 120.9890035)
# NEW LINES
# LINESTRING (120.988809 14.6239869, 120.988858 14.6239111, 120.9889086 14.6238381, 120.9889794 14.623724, 120.9890035 14.6236761)
# LINESTRING (120.9890035 14.6236761, 120.9890234 14.6236238, 120.9890399 14.6235651, 120.9890545 14.6234685, 120.9890322 14.6229661, 120.9890269 14.622788)
# ORIGINAL LINE: LINESTRING (120.988809 14.6239869, 120.988858 14.6239111, 120.9889086 14.6238381, 120.9889794 14.623724, 120.9890035 14.6236761, 120.9890234 14.6236238, 120.9890399 14.6235651, 120.9890545 14.6234685, 120.9890322 14.6229661, 120.9890269 14.622788)
# ---------
# NEW DISTANCES
# 40.26993376641408
# 98.29623257137918
# ORIGINAL DISTANCE: 134.71365430527018
# ---------
# HAS EDGE BETWEEN 1655369853 and 4576 : True
# HAS EDGE BETWEEN 4576 and 1519 : True
#
# STOP ID: 4577
# SEEN ADDED NODE1! 1764 - 14.615284842361454, 120.98790286932076
# EDGE NODES (1764, 68070848)
# Transpo Stop WAY 1
# POINT B:  (14.615491653644115, 120.9881274207994)
# NEW LINES
# LINESTRING (120.98790286932076 14.615284842361454, 120.9881274207994 14.615491653644115)
# LINESTRING (120.9881274207994 14.615491653644115, 120.9882871 14.6156387)
# ORIGINAL LINE: LINESTRING (120.98790286932076 14.615284842361454, 120.9882871 14.6156387)
# ---------
# NEW DISTANCES
# 33.30057428579899
# 23.678775298516367
# ORIGINAL DISTANCE: 56.97934955945385
# ---------
# HAS EDGE BETWEEN 1764 and 4577 : True
# HAS EDGE BETWEEN 4577 and 68070848 : True
#
# STOP ID: 4578
# SEEN ADDED NODE2! 1527 - 14.623437042482484, 120.98911425600703
# EDGE NODES (72482708, 1527)
# Transpo Stop WAY 1
# POINT B:  (14.623350154718489, 120.9891116022088)
# NEW LINES
# LINESTRING (120.9891056 14.6231536, 120.9891116022088 14.623350154718489)
# LINESTRING (120.9891116022088 14.623350154718489, 120.98911425600703 14.623437042482484)
# ORIGINAL LINE: LINESTRING (120.9891056 14.6231536, 120.98911425600703 14.623437042482484)
# ---------
# NEW DISTANCES
# 21.75742505027698
# 9.617954548116426
# ORIGINAL DISTANCE: 31.375379598651428
# ---------
# HAS EDGE BETWEEN 72482708 and 4578 : True
# HAS EDGE BETWEEN 4578 and 1527 : True
#
# STOP ID: 4579
# SEEN ADDED NODE2! 812 - 14.5829432, 120.9861539
# EDGE NODES (33957110, 812)
# Transpo Stop WAY 2
# POINT B:  (14.5830217, 120.9863738)
# NEW LINES
# LINESTRING (120.9870513 14.5832573, 120.9867041 14.5831333, 120.9863738 14.5830217)
# LINESTRING (120.9863738 14.5830217, 120.9861539 14.5829432)
# ORIGINAL LINE: LINESTRING (120.9870513 14.5832573, 120.9867041 14.5831333, 120.9863738 14.5830217, 120.9861539 14.5829432)
# ---------
# NEW DISTANCES
# 77.51916547464741
# 25.237265258930083
# ORIGINAL DISTANCE: 102.75576233393346
# ---------
# HAS EDGE BETWEEN 33957110 and 4579 : True
# HAS EDGE BETWEEN 4579 and 812 : True
#
# STOP ID: 4580
# SEEN ADDED NODE2! 90 - 14.5833985, 120.9875067
# EDGE NODES (33957110, 90)
# Transpo Stop WAY 1
# POINT B:  (14.583330549753258, 120.9872875127967)
# NEW LINES
# LINESTRING (120.9870513 14.5832573, 120.9872875127967 14.583330549753258)
# LINESTRING (120.9872875127967 14.583330549753258, 120.9875067 14.5833985)
# ORIGINAL LINE: LINESTRING (120.9870513 14.5832573, 120.9875067 14.5833985)
# ---------
# NEW DISTANCES
# 26.71251012172472
# 24.786469364164738
# ORIGINAL DISTANCE: 51.49897944253926
# ---------
# HAS EDGE BETWEEN 33957110 and 4580 : True
# HAS EDGE BETWEEN 4580 and 90 : True
#
# STOP ID: 4581
# SEEN ADDED NODE1! 382 - 14.5846997, 120.9914012
# EDGE NODES (382, 159443308)
# Transpo Stop WAY 2
# POINT B:  (14.5845881, 120.9910823)
# NEW LINES
# LINESTRING (120.9914012 14.5846997, 120.9910823 14.5845881)
# LINESTRING (120.9910823 14.5845881, 120.9910675 14.5845829, 120.9909824 14.5845528, 120.9909227 14.5845326, 120.9905613 14.5844209, 120.9904462 14.5843859, 120.9903821 14.5843664, 120.9902129 14.584317, 120.9899028 14.584211)
# ORIGINAL LINE: LINESTRING (120.9914012 14.5846997, 120.9910823 14.5845881, 120.9910675 14.5845829, 120.9909824 14.5845528, 120.9909227 14.5845326, 120.9905613 14.5844209, 120.9904462 14.5843859, 120.9903821 14.5843664, 120.9902129 14.584317, 120.9899028 14.584211)
# ---------
# NEW DISTANCES
# 36.51436140601831
# 133.77098123418935
# ORIGINAL DISTANCE: 170.2742809562743
# ---------
# HAS EDGE BETWEEN 382 and 4581 : True
# HAS EDGE BETWEEN 4581 and 159443308 : True
#
# STOP ID: 4582
# SEEN ADDED NODE1! 2212 - 14.5929359, 121.0025744
# EDGE NODES (2212, 191593252)
# Transpo Stop WAY 2
# POINT B:  (14.5929047, 121.002164)
# NEW LINES
# LINESTRING (121.0025744 14.5929359, 121.0024215 14.5929268, 121.002164 14.5929047)
# LINESTRING (121.002164 14.5929047, 121.0016646 14.5928474)
# ORIGINAL LINE: LINESTRING (121.0025744 14.5929359, 121.0024215 14.5929268, 121.002164 14.5929047, 121.0016646 14.5928474)
# ---------
# NEW DISTANCES
# 44.35565519522278
# 54.18318303039164
# ORIGINAL DISTANCE: 98.51993762273818
# ---------
# HAS EDGE BETWEEN 2212 and 4582 : True
# HAS EDGE BETWEEN 4582 and 191593252 : True
#
# STOP ID: 4583
# SEEN ADDED NODE2! 879 - 14.5852924, 120.9931547
# EDGE NODES (8383174519, 879)
# Transpo Stop WAY 2
# POINT B:  (14.5853555, 120.9933096)
# NEW LINES
# LINESTRING (120.9937345 14.5855268, 120.9933096 14.5853555)
# LINESTRING (120.9933096 14.5853555, 120.9931547 14.5852924)
# ORIGINAL LINE: LINESTRING (120.9937345 14.5855268, 120.9933096 14.5853555, 120.9931547 14.5852924)
# ---------
# NEW DISTANCES
# 49.553043636290695
# 18.092579654781694
# ORIGINAL DISTANCE: 67.64553355890345
# ---------
# HAS EDGE BETWEEN 8383174519 and 4583 : True
# HAS EDGE BETWEEN 4583 and 879 : True
#
# STOP ID: 4584
# SEEN ADDED NODE1! 382 - 14.5846997, 120.9914012
# SEEN ADDED NODE2! 4581 - 14.5845881, 120.9910823
# EDGE NODES (382, 4581)
# Transpo Stop WAY 1
# POINT B:  (14.584649780392908, 120.99125852447753)
# NEW LINES
# LINESTRING (120.9914012 14.5846997, 120.99125852447753 14.584649780392908)
# LINESTRING (120.99125852447753 14.584649780392908, 120.9910823 14.5845881)
# ORIGINAL LINE: LINESTRING (120.9914012 14.5846997, 120.9910823 14.5845881)
# ---------
# NEW DISTANCES
# 16.33610621198313
# 20.178255254243865
# ORIGINAL DISTANCE: 36.51436140601831
# ---------
# HAS EDGE BETWEEN 382 and 4584 : True
# HAS EDGE BETWEEN 4584 and 4581 : True
#
# STOP ID: 4585
# SEEN ADDED NODE1! 4169 - 14.5867023, 120.9948883
# SEEN ADDED NODE2! 1987 - 14.5881528, 120.9961528
# EDGE NODES (4169, 1987)
# Transpo Stop WAY 2
# POINT B:  (14.5879608, 120.9959823)
# NEW LINES
# LINESTRING (120.9948883 14.5867023, 120.9950143 14.586847, 120.9953307 14.5872098, 120.9954153 14.5873072, 120.9955478 14.5874645, 120.9956332 14.5875618, 120.9957322 14.5876745, 120.9957802 14.5877251, 120.9959154 14.5878837, 120.9959823 14.5879608)
# LINESTRING (120.9959823 14.5879608, 120.9961095 14.5881038, 120.9961528 14.5881528)
# ORIGINAL LINE: LINESTRING (120.9948883 14.5867023, 120.9950143 14.586847, 120.9953307 14.5872098, 120.9954153 14.5873072, 120.9955478 14.5874645, 120.9956332 14.5875618, 120.9957322 14.5876745, 120.9957802 14.5877251, 120.9959154 14.5878837, 120.9959823 14.5879608, 120.9961095 14.5881038, 120.9961528 14.5881528)
# ---------
# NEW DISTANCES
# 182.44431565058096
# 28.086096312378764
# ORIGINAL DISTANCE: 210.52906335576938
# ---------
# HAS EDGE BETWEEN 4169 and 4585 : True
# HAS EDGE BETWEEN 4585 and 1987 : True
#
# STOP ID: 4586
# SEEN ADDED NODE2! 1878 - 14.5925455, 120.9999531
# EDGE NODES (26082709, 1878)
# Transpo Stop WAY 2
# POINT B:  (14.5927165, 121.0004131)
# NEW LINES
# LINESTRING (121.0015839 14.5928325, 121.001414 14.5928379, 121.0011105 14.5928027, 121.0006973 14.5927574, 121.0005639 14.592736, 121.0004131 14.5927165)
# LINESTRING (121.0004131 14.5927165, 121.0002801 14.5926885, 121.0002068 14.5926646, 121.0001335 14.592634, 121.0000664 14.5926091, 121.0000053 14.5925758, 120.9999531 14.5925455)
# ORIGINAL LINE: LINESTRING (121.0015839 14.5928325, 121.001414 14.5928379, 121.0011105 14.5928027, 121.0006973 14.5927574, 121.0005639 14.592736, 121.0004131 14.5927165, 121.0002801 14.5926885, 121.0002068 14.5926646, 121.0001335 14.592634, 121.0000664 14.5926091, 121.0000053 14.5925758, 120.9999531 14.5925455)
# ---------
# NEW DISTANCES
# 126.80646602642953
# 53.05402074115711
# ORIGINAL DISTANCE: 178.56715575454515
# ---------
# HAS EDGE BETWEEN 26082709 and 4586 : True
# HAS EDGE BETWEEN 4586 and 1878 : True
#
# STOP ID: 4587
# SEEN ADDED NODE2! 4169 - 14.5867023, 120.9948883
# EDGE NODES (7838739155, 4169)
# Transpo Stop WAY 2
# POINT B:  (14.5864171, 120.9946339)
# NEW LINES
# LINESTRING (120.9945419 14.5863155, 120.9946339 14.5864171)
# LINESTRING (120.9946339 14.5864171, 120.9947234 14.586516, 120.9948883 14.5867023)
# ORIGINAL LINE: LINESTRING (120.9945419 14.5863155, 120.9946339 14.5864171, 120.9947234 14.586516, 120.9948883 14.5867023)
# ---------
# NEW DISTANCES
# 14.988232337072004
# 41.799879893776044
# ORIGINAL DISTANCE: 56.787806162223845
# ---------
# HAS EDGE BETWEEN 7838739155 and 4587 : True
# HAS EDGE BETWEEN 4587 and 4169 : True
#
# STOP ID: 4588
# EDGE NODES (33445321, 165758777)
# Transpo Stop WAY 2
# POINT B:  (14.5944458, 120.979788)
# NEW LINES
# LINESTRING (120.9800574 14.5951019, 120.9798684 14.5946314, 120.979788 14.5944458)
# LINESTRING (120.979788 14.5944458, 120.9797305 14.5943212)
# ORIGINAL LINE: LINESTRING (120.9800574 14.5951019, 120.9798684 14.5946314, 120.979788 14.5944458, 120.9797305 14.5943212)
# ---------
# NEW DISTANCES
# 78.182603447766
# 15.114543285184753
# ORIGINAL DISTANCE: 93.68299999999999
# ---------
# HAS EDGE BETWEEN 33445321 and 4588 : True
# HAS EDGE BETWEEN 4588 and 165758777 : True
#
# STOP ID: 4589
# SEEN ADDED NODE2! 2780 - 14.6048946, 120.9819314
# EDGE NODES (191592003, 2780)
# Transpo Stop WAY 2
# POINT B:  (14.6051396, 120.981948)
# NEW LINES
# LINESTRING (120.9819511 14.6051854, 120.981948 14.6051396)
# LINESTRING (120.981948 14.6051396, 120.9819314 14.6048946)
# ORIGINAL LINE: LINESTRING (120.9819511 14.6051854, 120.981948 14.6051396, 120.9819314 14.6048946)
# ---------
# NEW DISTANCES
# 5.078532653271044
# 27.166943631895567
# ORIGINAL DISTANCE: 32.24547627551573
# ---------
# HAS EDGE BETWEEN 191592003 and 4589 : True
# HAS EDGE BETWEEN 4589 and 2780 : True
#
# STOP ID: 4590
# SEEN ADDED NODE1! 2263 - 14.6023162, 121.0107994
# EDGE NODES (2263, 1737833878)
# Transpo Stop WAY 2
# POINT B:  (14.6022957, 121.0105815)
# NEW LINES
# LINESTRING (121.0107994 14.6023162, 121.0105815 14.6022957)
# LINESTRING (121.0105815 14.6022957, 121.010273 14.602264)
# ORIGINAL LINE: LINESTRING (121.0107994 14.6023162, 121.0105815 14.6022957, 121.010273 14.602264)
# ---------
# NEW DISTANCES
# 23.587315585526767
# 33.42439600810467
# ORIGINAL DISTANCE: 57.011174023061116
# ---------
# HAS EDGE BETWEEN 2263 and 4590 : True
# HAS EDGE BETWEEN 4590 and 1737833878 : True
#
# STOP ID: 4591
# SEEN ADDED NODE2! 2456 - 14.5959951, 120.9823007
# EDGE NODES (1869703210, 2456)
# Transpo Stop WAY 2
# POINT B:  (14.5963144, 120.9820549)
# NEW LINES
# LINESTRING (120.9825521 14.5966431, 120.9820549 14.5963144)
# LINESTRING (120.9820549 14.5963144, 120.9823007 14.5959951)
# ORIGINAL LINE: LINESTRING (120.9825521 14.5966431, 120.9820549 14.5963144, 120.9823007 14.5959951)
# ---------
# NEW DISTANCES
# 64.75163346859507
# 44.15403859294277
# ORIGINAL DISTANCE: 76.64433961501427
# ---------
# HAS EDGE BETWEEN 1869703210 and 4591 : True
# HAS EDGE BETWEEN 4591 and 2456 : True
#
# STOP ID: 4592
# SEEN ADDED NODE1! 4182 - 14.5805951, 120.9857687
# SEEN ADDED NODE2! 4162 - 14.5814077, 120.9853083
# EDGE NODES (4182, 4162)
# Transpo Stop WAY 2
# POINT B:  (14.5812625, 120.985392)
# NEW LINES
# LINESTRING (120.9857687 14.5805951, 120.985392 14.5812625)
# LINESTRING (120.985392 14.5812625, 120.9853083 14.5814077)
# ORIGINAL LINE: LINESTRING (120.9857687 14.5805951, 120.985392 14.5812625, 120.9853083 14.5814077)
# ---------
# NEW DISTANCES
# 84.2656103526702
# 18.424187291924408
# ORIGINAL DISTANCE: 102.6891932790851
# ---------
# HAS EDGE BETWEEN 4182 and 4592 : True
# HAS EDGE BETWEEN 4592 and 4162 : True
#
# STOP ID: 4593
# SEEN ADDED NODE1! 449 - 14.5740009, 120.9900854
# EDGE NODES (449, 33956011)
# Transpo Stop WAY 1
# POINT B:  (14.573874037709455, 120.98984536633805)
# NEW LINES
# LINESTRING (120.9900854 14.5740009, 120.98984536633805 14.573874037709455)
# LINESTRING (120.98984536633805 14.573874037709455, 120.9896565 14.5737742)
# ORIGINAL LINE: LINESTRING (120.9900854 14.5740009, 120.9896565 14.5737742)
# ---------
# NEW DISTANCES
# 29.429311425605537
# 23.156920402545076
# ORIGINAL DISTANCE: 52.58623179152933
# ---------
# HAS EDGE BETWEEN 449 and 4593 : True
# HAS EDGE BETWEEN 4593 and 33956011 : True
#
# STOP ID: 4594
# SEEN ADDED NODE1! 4190 - 14.5895446, 120.9807517
# SEEN ADDED NODE2! 4399 - 14.588394, 120.9809042
# EDGE NODES (4190, 4399)
# Transpo Stop WAY 2
# POINT B:  (14.5886962, 120.9809052)
# NEW LINES
# LINESTRING (120.9807517 14.5895446, 120.9808507 14.5890772, 120.9808585 14.5890014, 120.9808582 14.5889197, 120.9809052 14.5886962)
# LINESTRING (120.9809052 14.5886962, 120.9809184 14.5885884, 120.9809151 14.5885112, 120.9809042 14.588394)
# ORIGINAL LINE: LINESTRING (120.9807517 14.5895446, 120.9808507 14.5890772, 120.9808585 14.5890014, 120.9808582 14.5889197, 120.9809052 14.5886962, 120.9809184 14.5885884, 120.9809151 14.5885112, 120.9809042 14.588394)
# ---------
# NEW DISTANCES
# 95.31706213387618
# 33.43701851906638
# ORIGINAL DISTANCE: 128.36398842452732
# ---------
# HAS EDGE BETWEEN 4190 and 4594 : True
# HAS EDGE BETWEEN 4594 and 4399 : True

# %%
#Export stops to pickle
file_path = f'{Manila_pikl_filepath}stop_list_Manila.pkl'
with open(file_path, 'wb') as f:
    pickle.dump(list_of_stops_Manila, f)
    
file_path = f'{Manila_pikl_filepath}stop_graph_Manila.pkl'
with open(file_path, 'wb') as f:
    pickle.dump(graph_of_stops_Manila, f)

# %% [markdown]
# #### Stop Connection (Only to generate new routes)

# %%
used_stops = []
for node, data in graph_of_stops_Manila.nodes(data=True):
    if node < 100000:
        if node not in used_stops:
            used_stops.append(node)
        else:
            print("DUPLICATE ", node)

# %%
# LEVEL 4 - CONNECTING STOPS INTO A NETWORK

# Configuration
set_walk_distance = WALKING_DISTANCES[1]
num_of_networks = 100
conn_type = CONNECTION_TYPES[3]
max_stops = 20
max_routes = 30 # temporary, should be 30
map_html_location = f"Generated Route Networks HTML/Manila/{conn_type}/"
        
# Generate route network
list_of_networks_Manila = []

print(f"CHOSEN CONNECTION TYPE: {conn_type}")
current_network_count = 0
for _ in range(num_of_networks):
    
    print(f"NETWORK {current_network_count}")
    if conn_type == "Mixed":
        temp_conn_type = random.choice(CONNECTION_TYPES[:-1])
        temp_walk_type = random.choice(WALKING_DISTANCES)
        print(f"NETWORK CONNECTION TYPE: {temp_conn_type}")
        route_network, route_graph, reversed_route_network = generate_route_network(list_of_stops_Manila, set_walk_distance, max_stops, max_routes, graph_of_stops_Manila, manila_area_sum, temp_conn_type) # Default max walking distance is 300m
        used_stops = add_stops_to_list(route_network)
        reversed_used_stops = add_stops_to_list(reversed_route_network)
        new_network = networkObj(route_network, reversed_route_network, used_stops, reversed_used_stops, route_graph, temp_conn_type, temp_walk_type)
    else:
        route_network, route_graph, reversed_route_network = generate_route_network(list_of_stops_Manila, set_walk_distance, max_stops, max_routes, graph_of_stops_Manila, manila_area_sum, conn_type) # Default max walking distance is 300m
        used_stops = add_stops_to_list(route_network)
        reversed_used_stops = add_stops_to_list(reversed_route_network)
        new_network = networkObj(route_network, reversed_route_network, used_stops, reversed_used_stops, route_graph, conn_type, set_walk_distance)
    
    # ERROR CHECKS----------
    print("Checking for graph and route consistency...", flush=True)
    check_graph_with_route(new_network)
    print("Checking for graph and list of stops consistency...", flush=True)
    check_graph_with_stops(new_network)
    print("Checking if order of routes is correct...", flush=True)
    check_order_route(new_network)
    print("Checking for list of stops and route consistency...", flush=True)
    check_stops_routes(new_network)
    print("Checking for duplicates in routes...")
    check_duplicate_routes(new_network)
    print("Checking for duplicate stops and connections...")
    check_duplicate_stops_routes(new_network)
    print()
    
    
    print()
    list_of_networks_Manila.append(new_network) # Append to list of networks
    current_network_count += 1

#Export networks and graphs using pickl
if conn_type == 'Mixed':
    export_networks(list_of_networks_Manila, f"{Manila_pikl_filepath}Manila_Route_networks_{conn_type}.pkl")
else:
    export_networks(list_of_networks_Manila, f"{Manila_pikl_filepath}Manila_Route_networks_{conn_type}_{set_walk_distance}.pkl")
# Out:
# CHOSEN CONNECTION TYPE: Mixed
# NETWORK 0
# NETWORK CONNECTION TYPE: Default
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.41108173008529
# REVERSE ROUTE DISTANCE:  14.265128658307074
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.548076787715738
# REVERSE ROUTE DISTANCE:  13.87214919148582
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.836468607395018
# REVERSE ROUTE DISTANCE:  14.989133179197239
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.111093214246887
# REVERSE ROUTE DISTANCE:  14.898301284212305
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.339174412212767
# REVERSE ROUTE DISTANCE:  13.425370191760777
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.97941577425868
# REVERSE ROUTE DISTANCE:  16.471243599409913
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.641370993563747
# REVERSE ROUTE DISTANCE:  16.280265401777392
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.936081087915884
# REVERSE ROUTE DISTANCE:  14.754772012485633
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.282129194308578
# REVERSE ROUTE DISTANCE:  14.999206355836654
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.078156751481849
# REVERSE ROUTE DISTANCE:  13.35172835604461
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.218793685587608
# REVERSE ROUTE DISTANCE:  12.643160634021665
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.551495742866955
# REVERSE ROUTE DISTANCE:  13.460361616485153
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.503574147728928
# REVERSE ROUTE DISTANCE:  13.9583910035627
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.701452659146787
# REVERSE ROUTE DISTANCE:  16.33280318003552
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.643778505257622
# REVERSE ROUTE DISTANCE:  14.606233886823174
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.490368715872687
# REVERSE ROUTE DISTANCE:  14.838250635188652
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.658613557290915
# REVERSE ROUTE DISTANCE:  14.655444320295738
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.25336086747918
# REVERSE ROUTE DISTANCE:  13.09145532717755
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.351070300980606
# REVERSE ROUTE DISTANCE:  12.551073617697975
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.780760614114714
# REVERSE ROUTE DISTANCE:  14.248936869161836
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 11.30732246262149
# REVERSE ROUTE DISTANCE:  10.931002746040523
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.296814681439898
# REVERSE ROUTE DISTANCE:  14.567343633729749
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.555424167317188
# REVERSE ROUTE DISTANCE:  14.16429553984604
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.65118079854577
# REVERSE ROUTE DISTANCE:  15.1080287469262
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.524809039722994
# REVERSE ROUTE DISTANCE:  12.469306267956012
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.564715869968577
# REVERSE ROUTE DISTANCE:  14.575143335635852
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.652156169424131
# REVERSE ROUTE DISTANCE:  13.460089524907918
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 11.921815493419903
# REVERSE ROUTE DISTANCE:  9.726182585220094
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.359435700921702
# REVERSE ROUTE DISTANCE:  13.906111135510121
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.097060334123027
# REVERSE ROUTE DISTANCE:  14.979969992666346
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 1
# NETWORK CONNECTION TYPE: Default
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.630713143877427
# REVERSE ROUTE DISTANCE:  14.947736965841912
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.752010890684222
# REVERSE ROUTE DISTANCE:  13.473821769896432
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.608898955646104
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.99615651949236
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.846757285405749
# REVERSE ROUTE DISTANCE:  15.236052698111209
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.73882788097777
# REVERSE ROUTE DISTANCE:  12.23034064911484
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.419468644122933
# REVERSE ROUTE DISTANCE:  14.378461038914473
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.131669053772187
# REVERSE ROUTE DISTANCE:  12.989097966343934
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.556104711656438
# REVERSE ROUTE DISTANCE:  12.65669234900644
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.077287868351712
# REVERSE ROUTE DISTANCE:  14.17410951989363
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.846443199852992
# REVERSE ROUTE DISTANCE:  14.079168023963664
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.534762586382959
# REVERSE ROUTE DISTANCE:  13.880713719017157
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.882867612546033
# REVERSE ROUTE DISTANCE:  11.644547785688772
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.416335337685783
# REVERSE ROUTE DISTANCE:  13.619562374496509
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.09338632219248
# REVERSE ROUTE DISTANCE:  13.826358912875053
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.51522297766206
# REVERSE ROUTE DISTANCE:  13.915018334816688
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.114189351474277
# REVERSE ROUTE DISTANCE:  14.43111258874703
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.54316379225422
# REVERSE ROUTE DISTANCE:  14.886686790553117
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.948669096695564
# REVERSE ROUTE DISTANCE:  14.999993352829192
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.437462296297495
# REVERSE ROUTE DISTANCE:  14.152572185891342
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.376413754352683
# REVERSE ROUTE DISTANCE:  14.575239594969561
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.796619575395086
# REVERSE ROUTE DISTANCE:  14.067309623005851
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 13.679010806314624
# REVERSE ROUTE DISTANCE:  13.739964254250188
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.522201681449287
# REVERSE ROUTE DISTANCE:  12.840126037631606
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.885797420192574
# REVERSE ROUTE DISTANCE:  12.029300759514234
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.489992195955189
# REVERSE ROUTE DISTANCE:  14.221354531352421
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.12427335300102
# REVERSE ROUTE DISTANCE:  12.855333008937384
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.449934563350538
# REVERSE ROUTE DISTANCE:  14.024947176331116
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.075219449130884
# REVERSE ROUTE DISTANCE:  15.794342621542144
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.618215036538405
# REVERSE ROUTE DISTANCE:  14.420038269495068
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 2
# NETWORK CONNECTION TYPE: Default
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.600028865284349
# REVERSE ROUTE DISTANCE:  14.507789713563534
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.54237066394487
# REVERSE ROUTE DISTANCE:  14.247883611755505
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.29290958252234
# REVERSE ROUTE DISTANCE:  14.480591527382762
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.754227232975923
# REVERSE ROUTE DISTANCE:  14.473802940485488
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.821496089352049
# REVERSE ROUTE DISTANCE:  13.093532095609346
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.393460001269139
# REVERSE ROUTE DISTANCE:  12.91679619875189
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.395218315873237
# REVERSE ROUTE DISTANCE:  11.90119917925755
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.947525838246106
# REVERSE ROUTE DISTANCE:  13.30396195599182
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.439374621978818
# REVERSE ROUTE DISTANCE:  14.205436496420562
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.578984612559664
# REVERSE ROUTE DISTANCE:  13.333932689167945
# # OF CONNECTIONS AND TOTAL DISTANCE: 10 - 14.41310641642123
# REVERSE ROUTE DISTANCE:  13.846227409485614
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.702122853740692
# REVERSE ROUTE DISTANCE:  12.739429229238937
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.837819689875595
# REVERSE ROUTE DISTANCE:  13.509247208634946
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.586006808113705
# REVERSE ROUTE DISTANCE:  15.16311585150277
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.62383858409611
# REVERSE ROUTE DISTANCE:  14.851010251493083
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.268118671310981
# REVERSE ROUTE DISTANCE:  13.636650296414457
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.671174632191079
# REVERSE ROUTE DISTANCE:  14.829984525176192
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.595837135604228
# REVERSE ROUTE DISTANCE:  15.58550839475645
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.591035286057656
# REVERSE ROUTE DISTANCE:  15.499858261273113
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.61839729599493
# REVERSE ROUTE DISTANCE:  15.320974907041826
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.82275977746661
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.84136999897948
# REVERSE ROUTE DISTANCE:  14.891283710209729
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.173587731929231
# REVERSE ROUTE DISTANCE:  13.200256034839814
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.235033407399591
# REVERSE ROUTE DISTANCE:  14.677487466242706
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.50434300208077
# REVERSE ROUTE DISTANCE:  15.289451056962642
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.484639852977338
# REVERSE ROUTE DISTANCE:  13.885711703813367
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.406418213915796
# REVERSE ROUTE DISTANCE:  14.988860770149067
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.901627800183153
# REVERSE ROUTE DISTANCE:  14.628433911302508
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.176733804551544
# REVERSE ROUTE DISTANCE:  14.711267194832377
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.828893951674253
# REVERSE ROUTE DISTANCE:  12.46379020928838
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 3
# NETWORK CONNECTION TYPE: Degree
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.733976661638925
# REVERSE ROUTE DISTANCE:  12.535170693591548
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.484732758990102
# REVERSE ROUTE DISTANCE:  13.365935883121995
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.230412217972011
# REVERSE ROUTE DISTANCE:  12.911387429846418
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.519121280983688
# REVERSE ROUTE DISTANCE:  13.339442795305175
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.290054808301168
# REVERSE ROUTE DISTANCE:  14.861712668981738
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.143024304001178
# REVERSE ROUTE DISTANCE:  14.144202403586547
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.725052628021919
# REVERSE ROUTE DISTANCE:  15.157794609354774
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.809557790950219
# REVERSE ROUTE DISTANCE:  14.43693048905548
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.91709416950555
# REVERSE ROUTE DISTANCE:  14.894013562308626
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.344679853067179
# REVERSE ROUTE DISTANCE:  15.799819163888953
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.193731081619493
# REVERSE ROUTE DISTANCE:  12.192203626779087
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 13.68058552676771
# REVERSE ROUTE DISTANCE:  15.217311140367643
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.324581002118677
# REVERSE ROUTE DISTANCE:  14.255039856107887
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.818181925941328
# REVERSE ROUTE DISTANCE:  14.91398975947088
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 12.626993621030184
# REVERSE ROUTE DISTANCE:  13.656338004073369
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.812226749355684
# REVERSE ROUTE DISTANCE:  14.15852223546511
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.32184376382386
# REVERSE ROUTE DISTANCE:  12.231368859371084
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.470858206168938
# REVERSE ROUTE DISTANCE:  12.535650389905808
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.739911124718375
# REVERSE ROUTE DISTANCE:  14.033105518082923
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 12.976567523968269
# REVERSE ROUTE DISTANCE:  14.072091226656951
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 13.401340145830195
# REVERSE ROUTE DISTANCE:  13.82850233452216
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.377573822273996
# REVERSE ROUTE DISTANCE:  12.255846042104498
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.840247938431585
# REVERSE ROUTE DISTANCE:  14.490682139364663
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.980251277218375
# REVERSE ROUTE DISTANCE:  14.263128868373885
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.882328663793817
# REVERSE ROUTE DISTANCE:  15.416593764931363
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.328382680190158
# REVERSE ROUTE DISTANCE:  15.834076326252529
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.893443146200887
# REVERSE ROUTE DISTANCE:  15.108398412100975
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.328005277501777
# REVERSE ROUTE DISTANCE:  15.042491885194718
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.920193074210898
# REVERSE ROUTE DISTANCE:  12.424352063543573
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.139454363448134
# REVERSE ROUTE DISTANCE:  13.470873937743512
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 4
# NETWORK CONNECTION TYPE: Degree
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.260963777040462
# REVERSE ROUTE DISTANCE:  13.792151487471074
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.220474208745765
# REVERSE ROUTE DISTANCE:  14.406531655216241
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.06298622813298
# REVERSE ROUTE DISTANCE:  13.412465052573367
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.096854396698028
# REVERSE ROUTE DISTANCE:  13.408411005144579
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.033917594252726
# REVERSE ROUTE DISTANCE:  14.11855255592485
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.769107694327232
# REVERSE ROUTE DISTANCE:  13.794157200658733
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.482281903170891
# REVERSE ROUTE DISTANCE:  14.273443835368306
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.216743778705679
# REVERSE ROUTE DISTANCE:  14.95110179347453
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.026283626659337
# REVERSE ROUTE DISTANCE:  13.041078800411276
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.452104391764694
# REVERSE ROUTE DISTANCE:  13.060448452040777
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.397594512113532
# REVERSE ROUTE DISTANCE:  16.52774595505493
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.616665093900913
# REVERSE ROUTE DISTANCE:  12.675217971594009
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.333179381503273
# REVERSE ROUTE DISTANCE:  12.792714362056259
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.730624385691078
# REVERSE ROUTE DISTANCE:  13.696127584337313
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.88801465567077
# REVERSE ROUTE DISTANCE:  14.236498558643142
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.623559097036422
# REVERSE ROUTE DISTANCE:  12.637783881943463
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.882731076960063
# REVERSE ROUTE DISTANCE:  15.9039862016884
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.671416616505379
# REVERSE ROUTE DISTANCE:  12.989454969788229
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.89508360162466
# REVERSE ROUTE DISTANCE:  13.77822875083567
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.745753644123525
# REVERSE ROUTE DISTANCE:  10.882532336137512
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.518734733566781
# REVERSE ROUTE DISTANCE:  13.3862740109291
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.431003626365282
# REVERSE ROUTE DISTANCE:  11.917731618021154
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 12.604298280723757
# REVERSE ROUTE DISTANCE:  12.441720043437028
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.587914985428949
# REVERSE ROUTE DISTANCE:  14.482326908798793
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.075136497736539
# REVERSE ROUTE DISTANCE:  12.825236602414101
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.428217216522702
# REVERSE ROUTE DISTANCE:  13.441802208999047
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.439585251542983
# REVERSE ROUTE DISTANCE:  15.611978684649873
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.178380902728064
# REVERSE ROUTE DISTANCE:  11.848560996626787
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.7565745599024
# REVERSE ROUTE DISTANCE:  13.835851800894662
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 13.966195287601842
# REVERSE ROUTE DISTANCE:  12.27289452549118
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 5
# NETWORK CONNECTION TYPE: Area
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.650837526738227
# REVERSE ROUTE DISTANCE:  16.37882046944347
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.865260084100974
# REVERSE ROUTE DISTANCE:  11.421225109497549
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.010423969857456
# REVERSE ROUTE DISTANCE:  13.000182080040279
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.565186592472205
# REVERSE ROUTE DISTANCE:  14.541730791280617
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.79611466406107
# REVERSE ROUTE DISTANCE:  13.572091236092849
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.082377428294778
# REVERSE ROUTE DISTANCE:  14.110544142412593
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.018981946685566
# REVERSE ROUTE DISTANCE:  12.856706429990796
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.407771062436822
# REVERSE ROUTE DISTANCE:  14.682254628674704
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.721279638288193
# REVERSE ROUTE DISTANCE:  16.335291158447696
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.952759043767106
# REVERSE ROUTE DISTANCE:  13.437615928659477
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.943349003911761
# REVERSE ROUTE DISTANCE:  12.54622356868994
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.261031835925138
# REVERSE ROUTE DISTANCE:  13.374689659192885
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.096784314084875
# REVERSE ROUTE DISTANCE:  14.279828826462994
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.344900958913895
# REVERSE ROUTE DISTANCE:  13.453889713596606
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.614712375448642
# REVERSE ROUTE DISTANCE:  12.981090960911882
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.14556789451322
# REVERSE ROUTE DISTANCE:  14.156165650087965
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.169826239306278
# REVERSE ROUTE DISTANCE:  14.956892157749746
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.671615211223951
# REVERSE ROUTE DISTANCE:  13.283204084762215
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.632174048047837
# REVERSE ROUTE DISTANCE:  13.946972065108415
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 14.54829916301925
# REVERSE ROUTE DISTANCE:  14.373995156010297
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 12.322707263008622
# REVERSE ROUTE DISTANCE:  13.319460502641572
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.19804813713745
# REVERSE ROUTE DISTANCE:  14.10196409244787
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.778742800319977
# REVERSE ROUTE DISTANCE:  16.691501423924876
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 13.810863521849168
# REVERSE ROUTE DISTANCE:  14.111516135354034
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.423732097223933
# REVERSE ROUTE DISTANCE:  13.14317573785313
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.603318367211623
# REVERSE ROUTE DISTANCE:  14.688573211353319
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.21591204313541
# REVERSE ROUTE DISTANCE:  15.478398339184098
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.991610871328426
# REVERSE ROUTE DISTANCE:  14.734109821509191
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.930168983497955
# REVERSE ROUTE DISTANCE:  13.235664839517852
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.734416142024923
# REVERSE ROUTE DISTANCE:  12.180893506122855
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 6
# NETWORK CONNECTION TYPE: Degree
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.775080875517105
# REVERSE ROUTE DISTANCE:  11.931321920216257
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.765529192024125
# REVERSE ROUTE DISTANCE:  14.730088587023452
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.538083079186656
# REVERSE ROUTE DISTANCE:  12.119427539757636
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.878085361876657
# REVERSE ROUTE DISTANCE:  14.600114038278589
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.364060613179019
# REVERSE ROUTE DISTANCE:  14.17132190102941
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.57103036070173
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.782075372905767
# REVERSE ROUTE DISTANCE:  14.24096925191017
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.02007350149725
# REVERSE ROUTE DISTANCE:  15.10749445659669
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.638793455439078
# REVERSE ROUTE DISTANCE:  15.00662025866442
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.950136423667878
# REVERSE ROUTE DISTANCE:  13.60030234368412
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.809059975039432
# REVERSE ROUTE DISTANCE:  14.652516909911565
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.239094662481076
# REVERSE ROUTE DISTANCE:  15.559490405473337
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.376659650458738
# REVERSE ROUTE DISTANCE:  13.6643385299229
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.37719997945497
# REVERSE ROUTE DISTANCE:  16.15360321530971
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.859447395749289
# REVERSE ROUTE DISTANCE:  17.85297906628324
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.187323149598965
# REVERSE ROUTE DISTANCE:  14.496594691613534
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 13.184516587465591
# REVERSE ROUTE DISTANCE:  12.840822205612733
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.47593652854906
# REVERSE ROUTE DISTANCE:  13.27978006261646
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.841521097622262
# REVERSE ROUTE DISTANCE:  13.539731639159129
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.155198099606771
# REVERSE ROUTE DISTANCE:  14.054946325839705
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 11.51079483349642
# REVERSE ROUTE DISTANCE:  10.000341080804386
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.144728095957422
# REVERSE ROUTE DISTANCE:  14.612009453355673
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.706519273423424
# REVERSE ROUTE DISTANCE:  13.619030891385878
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.939841715866047
# REVERSE ROUTE DISTANCE:  12.186880790197726
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.14865691023453
# REVERSE ROUTE DISTANCE:  15.192968628432839
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.972730520664218
# REVERSE ROUTE DISTANCE:  14.409328322359464
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.960365424831021
# REVERSE ROUTE DISTANCE:  15.676843832403222
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.734893451439007
# REVERSE ROUTE DISTANCE:  14.485689435261397
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.912155804487668
# REVERSE ROUTE DISTANCE:  14.301056529478526
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.217840621864127
# REVERSE ROUTE DISTANCE:  14.162661593049629
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 7
# NETWORK CONNECTION TYPE: Degree
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.7233082336281
# REVERSE ROUTE DISTANCE:  14.823905219417941
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.193602136179376
# REVERSE ROUTE DISTANCE:  12.454337804477328
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.656177855826083
# REVERSE ROUTE DISTANCE:  13.956465398727012
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.365289560385925
# REVERSE ROUTE DISTANCE:  14.066329490580049
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.852778562319454
# REVERSE ROUTE DISTANCE:  12.722167634401325
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.604808023093689
# REVERSE ROUTE DISTANCE:  14.288926929798018
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.552917216850506
# REVERSE ROUTE DISTANCE:  12.071268660006748
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.006800145250612
# REVERSE ROUTE DISTANCE:  13.071689226090093
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.811511538709992
# REVERSE ROUTE DISTANCE:  13.536987749806249
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.336568226511382
# REVERSE ROUTE DISTANCE:  13.252976518874824
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.331993992094741
# REVERSE ROUTE DISTANCE:  13.354396053785166
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.189816290464249
# REVERSE ROUTE DISTANCE:  14.97878052203863
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.178445639718552
# REVERSE ROUTE DISTANCE:  16.3817327308082
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.847630322570442
# REVERSE ROUTE DISTANCE:  14.091234096572721
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.173320995284197
# REVERSE ROUTE DISTANCE:  12.512927920638916
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.152701884361155
# REVERSE ROUTE DISTANCE:  12.667126162711828
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.78752601657327
# REVERSE ROUTE DISTANCE:  15.31378424988116
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.814130828015594
# REVERSE ROUTE DISTANCE:  13.671603177199593
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.436737233952845
# REVERSE ROUTE DISTANCE:  11.88472876606658
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.99175837984993
# REVERSE ROUTE DISTANCE:  14.244146941978832
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.040115690632641
# REVERSE ROUTE DISTANCE:  12.936071646453229
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.2045906080496
# REVERSE ROUTE DISTANCE:  14.151071933891911
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.569860344816375
# REVERSE ROUTE DISTANCE:  14.554629347569778
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.687212692488124
# REVERSE ROUTE DISTANCE:  14.017394543062785
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.168874966108614
# REVERSE ROUTE DISTANCE:  15.240466603537241
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.681143873988873
# REVERSE ROUTE DISTANCE:  14.031486574171502
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.19899035169804
# REVERSE ROUTE DISTANCE:  11.993547885662847
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.977941954912465
# REVERSE ROUTE DISTANCE:  14.527342479574191
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.055805748617338
# REVERSE ROUTE DISTANCE:  16.611029115474988
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.791690722359316
# REVERSE ROUTE DISTANCE:  13.548148979119185
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 8
# NETWORK CONNECTION TYPE: Degree
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.3837962522956
# REVERSE ROUTE DISTANCE:  12.202426545337296
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.700174782686226
# REVERSE ROUTE DISTANCE:  13.856249852837173
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.424112017691474
# REVERSE ROUTE DISTANCE:  13.617436087061103
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.559905169077334
# REVERSE ROUTE DISTANCE:  13.336275174800736
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.86618919422985
# REVERSE ROUTE DISTANCE:  15.24496127079691
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.06491439661814
# REVERSE ROUTE DISTANCE:  13.212677514564648
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.657892431818935
# REVERSE ROUTE DISTANCE:  15.62238524406156
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.328544464102446
# REVERSE ROUTE DISTANCE:  13.435482599626415
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.400991523446319
# REVERSE ROUTE DISTANCE:  13.162680531909341
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.727077291341118
# REVERSE ROUTE DISTANCE:  13.144297532143062
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.311041215383591
# REVERSE ROUTE DISTANCE:  14.72999124067034
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.8005775316348
# REVERSE ROUTE DISTANCE:  14.874500114066102
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.893157761564947
# REVERSE ROUTE DISTANCE:  14.184945937818663
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.497244831201241
# REVERSE ROUTE DISTANCE:  12.686408295242089
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.461729020435072
# REVERSE ROUTE DISTANCE:  13.991002177786905
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 12.83312666083605
# REVERSE ROUTE DISTANCE:  12.850683173952913
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.475311817240048
# REVERSE ROUTE DISTANCE:  14.87171639725997
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.540137023601257
# REVERSE ROUTE DISTANCE:  16.332958450202533
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.589430940666048
# REVERSE ROUTE DISTANCE:  15.35980002618025
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.894910247569479
# REVERSE ROUTE DISTANCE:  13.67963665843019
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.986887368269455
# REVERSE ROUTE DISTANCE:  15.979082570923712
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.93139696411598
# REVERSE ROUTE DISTANCE:  14.60499429503425
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.580201576999677
# REVERSE ROUTE DISTANCE:  14.345483682704554
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.357716649677748
# REVERSE ROUTE DISTANCE:  13.294707574040862
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.134497081766987
# REVERSE ROUTE DISTANCE:  13.672491812399873
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.824902476964327
# REVERSE ROUTE DISTANCE:  15.15708857409153
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.382979330252322
# REVERSE ROUTE DISTANCE:  14.21620282321752
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.55150214778094
# REVERSE ROUTE DISTANCE:  15.013948340153576
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.903919340923267
# REVERSE ROUTE DISTANCE:  14.665089879000693
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.814487044435296
# REVERSE ROUTE DISTANCE:  14.30399991261693
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 9
# NETWORK CONNECTION TYPE: Degree
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.704638793049043
# REVERSE ROUTE DISTANCE:  13.104263137892122
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.207178467872634
# REVERSE ROUTE DISTANCE:  13.080880362756261
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.033462292359701
# REVERSE ROUTE DISTANCE:  11.585268313321967
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.60663797906399
# REVERSE ROUTE DISTANCE:  14.943210898499851
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.848689403542906
# REVERSE ROUTE DISTANCE:  13.230375308086883
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.500467846887876
# REVERSE ROUTE DISTANCE:  10.883948870041246
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.793600197737929
# REVERSE ROUTE DISTANCE:  13.483188957892423
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.999521355256906
# REVERSE ROUTE DISTANCE:  14.280646477374633
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.990894069926648
# REVERSE ROUTE DISTANCE:  17.851829042617176
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.79085610752094
# REVERSE ROUTE DISTANCE:  14.262899381417089
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.444368284384916
# REVERSE ROUTE DISTANCE:  15.862595755250396
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 11.678874862409737
# REVERSE ROUTE DISTANCE:  11.2888657308628
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.559320691775973
# REVERSE ROUTE DISTANCE:  12.392543155606234
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.88607510525469
# REVERSE ROUTE DISTANCE:  15.04923875199323
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.842590212022554
# REVERSE ROUTE DISTANCE:  15.076840876904548
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.559158527487726
# REVERSE ROUTE DISTANCE:  15.540277911268003
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.272626639127104
# REVERSE ROUTE DISTANCE:  14.628689164132298
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.809606093713452
# REVERSE ROUTE DISTANCE:  13.068439164906684
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.50281350841331
# REVERSE ROUTE DISTANCE:  12.951855504048225
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.531149955218698
# REVERSE ROUTE DISTANCE:  13.61106237636575
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.904402112251903
# REVERSE ROUTE DISTANCE:  13.667004015396024
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.361455817907942
# REVERSE ROUTE DISTANCE:  13.874639747108922
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.721248227393598
# REVERSE ROUTE DISTANCE:  14.381198100935045
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.733823310099249
# REVERSE ROUTE DISTANCE:  13.449904886633785
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.118008618527952
# REVERSE ROUTE DISTANCE:  14.859479207184652
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.497481594167004
# REVERSE ROUTE DISTANCE:  14.22203959253837
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.958706008211209
# REVERSE ROUTE DISTANCE:  15.42157049966905
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.354750517247759
# REVERSE ROUTE DISTANCE:  14.855811380218862
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.605449025267575
# REVERSE ROUTE DISTANCE:  14.404244073138395
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.76085044057348
# REVERSE ROUTE DISTANCE:  14.83265362141992
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 10
# NETWORK CONNECTION TYPE: Degree
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 12.90184556344619
# REVERSE ROUTE DISTANCE:  12.717545498241677
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.11360746041623
# REVERSE ROUTE DISTANCE:  13.778480412877679
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.107729268717115
# REVERSE ROUTE DISTANCE:  14.983894625006723
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 13.416488782686407
# REVERSE ROUTE DISTANCE:  13.892098921798718
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.282390951431413
# REVERSE ROUTE DISTANCE:  16.413245979353903
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 11.95092896117452
# REVERSE ROUTE DISTANCE:  12.586862104431779
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.262737356409676
# REVERSE ROUTE DISTANCE:  15.039709118931283
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.20930499623289
# REVERSE ROUTE DISTANCE:  12.13695191049194
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.11254705409081
# REVERSE ROUTE DISTANCE:  12.60812141523295
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.107665790509264
# REVERSE ROUTE DISTANCE:  13.726933023064284
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.626105324880262
# REVERSE ROUTE DISTANCE:  14.533280275766781
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.452331355628269
# REVERSE ROUTE DISTANCE:  13.07721257977856
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 14.248733373987427
# REVERSE ROUTE DISTANCE:  14.58799618067632
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.359581529075278
# REVERSE ROUTE DISTANCE:  14.423242156453185
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.006019882027953
# REVERSE ROUTE DISTANCE:  13.016357552893288
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.248781009020997
# REVERSE ROUTE DISTANCE:  15.376162708395913
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.140137469547051
# REVERSE ROUTE DISTANCE:  14.516552894536796
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.315829085209714
# REVERSE ROUTE DISTANCE:  14.94291182487765
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.508076402423917
# REVERSE ROUTE DISTANCE:  13.803577053377593
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.730967712171365
# REVERSE ROUTE DISTANCE:  14.78971204292107
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.971237290670807
# REVERSE ROUTE DISTANCE:  13.584336494113135
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.635901219440864
# REVERSE ROUTE DISTANCE:  14.881184348779426
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.561592032643532
# REVERSE ROUTE DISTANCE:  11.67182877207933
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.952598255562636
# REVERSE ROUTE DISTANCE:  13.962806807090645
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.774695527109703
# REVERSE ROUTE DISTANCE:  14.769207463097866
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 13.811301789547647
# REVERSE ROUTE DISTANCE:  13.374191302121188
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.114364226842417
# REVERSE ROUTE DISTANCE:  10.81871548515326
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.227526665278655
# REVERSE ROUTE DISTANCE:  13.074183404766524
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.545742653185926
# REVERSE ROUTE DISTANCE:  14.828146839741715
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.257133094903994
# REVERSE ROUTE DISTANCE:  13.95734491832188
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 11
# NETWORK CONNECTION TYPE: Degree
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.002159994232256
# REVERSE ROUTE DISTANCE:  12.990970095391829
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.776850472322476
# REVERSE ROUTE DISTANCE:  14.620908374935453
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.838396464974892
# REVERSE ROUTE DISTANCE:  17.553743994917397
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 13.039363379494233
# REVERSE ROUTE DISTANCE:  14.336541309435685
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.443634593439814
# REVERSE ROUTE DISTANCE:  12.356205528390602
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.346346221446588
# REVERSE ROUTE DISTANCE:  13.600233586173196
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.402204549414801
# REVERSE ROUTE DISTANCE:  13.351588327640094
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.214037634476654
# REVERSE ROUTE DISTANCE:  11.226358953475264
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.332647065334683
# REVERSE ROUTE DISTANCE:  13.697322768710873
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.656366009663305
# REVERSE ROUTE DISTANCE:  17.734245257479138
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.398540705395062
# REVERSE ROUTE DISTANCE:  13.490039272628703
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.761600788080791
# REVERSE ROUTE DISTANCE:  13.295326603042058
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 12.874230780395138
# REVERSE ROUTE DISTANCE:  14.279399085395022
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.942639940439713
# REVERSE ROUTE DISTANCE:  15.962856521331702
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.17390714376681
# REVERSE ROUTE DISTANCE:  12.95545216456884
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.494951541884262
# REVERSE ROUTE DISTANCE:  16.09581238869726
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.443994278158597
# REVERSE ROUTE DISTANCE:  14.422650502210967
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.949977322716304
# REVERSE ROUTE DISTANCE:  11.723990162806812
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.066933466773207
# REVERSE ROUTE DISTANCE:  14.669459800453346
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.061206900392806
# REVERSE ROUTE DISTANCE:  13.250784613602024
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.131252875665798
# REVERSE ROUTE DISTANCE:  13.810207318400181
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.741524315146396
# REVERSE ROUTE DISTANCE:  14.352941128051231
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.116843144838871
# REVERSE ROUTE DISTANCE:  13.730486677753998
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.820690438102991
# REVERSE ROUTE DISTANCE:  13.681885874828517
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.212407346950224
# REVERSE ROUTE DISTANCE:  14.49523922395421
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.543058471346036
# REVERSE ROUTE DISTANCE:  14.135971166598525
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.501667304731031
# REVERSE ROUTE DISTANCE:  13.991176019767023
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.994583329982984
# REVERSE ROUTE DISTANCE:  14.034682443522158
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.271515272127466
# REVERSE ROUTE DISTANCE:  13.683455476102681
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.29030542042026
# REVERSE ROUTE DISTANCE:  13.505027758243848
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 12
# NETWORK CONNECTION TYPE: Area
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.513413132708445
# REVERSE ROUTE DISTANCE:  13.750672265872158
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.013705370970497
# REVERSE ROUTE DISTANCE:  14.379838847063409
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.898080065290173
# REVERSE ROUTE DISTANCE:  15.146468955948007
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.396557444111808
# REVERSE ROUTE DISTANCE:  13.964731543087854
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.688692120658146
# REVERSE ROUTE DISTANCE:  14.530101552416697
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.618850513752166
# REVERSE ROUTE DISTANCE:  13.552198910529096
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.364630551082115
# REVERSE ROUTE DISTANCE:  12.801479931601412
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 13.827753635285926
# REVERSE ROUTE DISTANCE:  12.823965553747637
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 13.043703060437299
# REVERSE ROUTE DISTANCE:  13.781292097893225
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.096111528064252
# REVERSE ROUTE DISTANCE:  12.162373089983776
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 10.690378832270124
# REVERSE ROUTE DISTANCE:  9.39854459880862
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.169759548678995
# REVERSE ROUTE DISTANCE:  14.783997320520944
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.430566335800975
# REVERSE ROUTE DISTANCE:  15.405626706467416
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.49583427782773
# REVERSE ROUTE DISTANCE:  15.046968933477384
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.310198141471524
# REVERSE ROUTE DISTANCE:  13.916795493082155
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.055335793873688
# REVERSE ROUTE DISTANCE:  14.28039923584532
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.639972839855812
# REVERSE ROUTE DISTANCE:  14.147917507478194
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.683638158783813
# REVERSE ROUTE DISTANCE:  15.310461930620017
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.143361272830123
# REVERSE ROUTE DISTANCE:  14.877906511772872
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.637008682739271
# REVERSE ROUTE DISTANCE:  14.38312611567806
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.852809334700643
# REVERSE ROUTE DISTANCE:  14.14934905266739
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.3181759535935
# REVERSE ROUTE DISTANCE:  12.519237845086955
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.830503599641709
# REVERSE ROUTE DISTANCE:  15.919260180992307
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.652624749026819
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.846881398807335
# REVERSE ROUTE DISTANCE:  13.81457257565542
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.024421000044216
# REVERSE ROUTE DISTANCE:  15.43786316561659
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.238014516747755
# REVERSE ROUTE DISTANCE:  13.797370818926588
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.155438845821509
# REVERSE ROUTE DISTANCE:  13.793412107574916
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.347657037135559
# REVERSE ROUTE DISTANCE:  14.196898126892847
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.97285102876011
# REVERSE ROUTE DISTANCE:  15.458342946573397
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 13
# NETWORK CONNECTION TYPE: Area
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.61024641071706
# REVERSE ROUTE DISTANCE:  15.527675598645768
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 12.902829209804418
# REVERSE ROUTE DISTANCE:  12.722849939733967
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.24312646061589
# REVERSE ROUTE DISTANCE:  14.135791767552147
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.95868954449801
# REVERSE ROUTE DISTANCE:  13.915192105043436
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 12.573593039729854
# REVERSE ROUTE DISTANCE:  13.083875815031547
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.356006382498823
# REVERSE ROUTE DISTANCE:  14.033857527448962
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.596543786897492
# REVERSE ROUTE DISTANCE:  14.28654400588703
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.192974060542156
# REVERSE ROUTE DISTANCE:  14.132823796262867
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.60860750652125
# REVERSE ROUTE DISTANCE:  12.542389934397697
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.918716414296917
# REVERSE ROUTE DISTANCE:  13.170955970541385
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.406011472087313
# REVERSE ROUTE DISTANCE:  13.86807963855922
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.970079362947718
# REVERSE ROUTE DISTANCE:  15.276063169619022
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.272080917109557
# REVERSE ROUTE DISTANCE:  13.163812221844918
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.331469912300236
# REVERSE ROUTE DISTANCE:  13.182896584429244
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.188021149553586
# REVERSE ROUTE DISTANCE:  11.876960212161928
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.640275902988266
# REVERSE ROUTE DISTANCE:  14.157845456825907
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.95640042034405
# REVERSE ROUTE DISTANCE:  12.065851723291454
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.969745078884042
# REVERSE ROUTE DISTANCE:  13.921680361516128
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.45411038899373
# REVERSE ROUTE DISTANCE:  11.277726171203064
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.507802792062789
# REVERSE ROUTE DISTANCE:  15.590057288134272
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.27628021898217
# REVERSE ROUTE DISTANCE:  14.709080536142721
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.222570994373404
# REVERSE ROUTE DISTANCE:  12.290170529143424
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.35654380646898
# REVERSE ROUTE DISTANCE:  14.992948100692189
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.236946915277658
# REVERSE ROUTE DISTANCE:  12.65519463611415
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.121353956780041
# REVERSE ROUTE DISTANCE:  14.306078981308337
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.701459020807377
# REVERSE ROUTE DISTANCE:  13.560384764191555
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.594175011990375
# REVERSE ROUTE DISTANCE:  14.828428110637653
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.413590673007883
# REVERSE ROUTE DISTANCE:  11.949500135876082
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.017525587137307
# REVERSE ROUTE DISTANCE:  11.447314854327109
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.866702869397086
# REVERSE ROUTE DISTANCE:  13.647368939777206
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 14
# NETWORK CONNECTION TYPE: Default
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.652057556750211
# REVERSE ROUTE DISTANCE:  13.776477480362498
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.734511805535087
# ...
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 12.864086713201957
# REVERSE ROUTE DISTANCE:  12.1219174552524
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.458646782091414
# REVERSE ROUTE DISTANCE:  13.421718653980992
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.854354663993213
# REVERSE ROUTE DISTANCE:  14.720883407499478
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.922331444525286
# REVERSE ROUTE DISTANCE:  13.971257025582474
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 12.646868564688775
# REVERSE ROUTE DISTANCE:  13.751403995106202
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.647789871962804
# REVERSE ROUTE DISTANCE:  16.001063044165015
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.903476713699014
# REVERSE ROUTE DISTANCE:  14.587184068371847
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.899648855286905
# REVERSE ROUTE DISTANCE:  13.960829949015547
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.668695362301143
# REVERSE ROUTE DISTANCE:  14.824037235114549
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.40402408268288
# REVERSE ROUTE DISTANCE:  15.803451878075471
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.533229999424076
# REVERSE ROUTE DISTANCE:  12.702724740790782
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.434049905797867
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.499295909188248
# REVERSE ROUTE DISTANCE:  13.324789357563478
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.841005082832796
# REVERSE ROUTE DISTANCE:  13.728427816758522
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.727438801847608
# REVERSE ROUTE DISTANCE:  12.66756053262659
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.966549533729415
# REVERSE ROUTE DISTANCE:  13.835513241628894
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.965036189295516
# REVERSE ROUTE DISTANCE:  16.21454430069421
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.01819448472054
# REVERSE ROUTE DISTANCE:  13.374357665876383
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.873595726475383
# REVERSE ROUTE DISTANCE:  14.554647705924825
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.033599551287974
# REVERSE ROUTE DISTANCE:  14.232833890409415
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 96
# NETWORK CONNECTION TYPE: Area
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.560586949906451
# REVERSE ROUTE DISTANCE:  13.252406181586128
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.472167107267763
# REVERSE ROUTE DISTANCE:  14.007581087963498
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.904426306937083
# REVERSE ROUTE DISTANCE:  13.190883912393113
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.844376409327454
# REVERSE ROUTE DISTANCE:  13.445838912524465
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 13.65652021065837
# REVERSE ROUTE DISTANCE:  13.72144737905026
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.144468532039136
# REVERSE ROUTE DISTANCE:  14.165590669671884
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.105829384313259
# REVERSE ROUTE DISTANCE:  15.402641888683094
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.684843773085515
# REVERSE ROUTE DISTANCE:  15.540294037092728
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.909396948825556
# REVERSE ROUTE DISTANCE:  15.377195620508544
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.09143843996914
# REVERSE ROUTE DISTANCE:  13.90330084499233
# # OF CONNECTIONS AND TOTAL DISTANCE: 10 - 14.881024287151217
# REVERSE ROUTE DISTANCE:  16.08733527053673
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.470912503114713
# REVERSE ROUTE DISTANCE:  15.084561123361556
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.695523339694635
# REVERSE ROUTE DISTANCE:  13.39413544016992
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.433837691565119
# REVERSE ROUTE DISTANCE:  14.449131858115138
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.726869985172215
# REVERSE ROUTE DISTANCE:  15.666997867187064
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 12.79446873967374
# REVERSE ROUTE DISTANCE:  13.376636328644324
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.601604377297287
# REVERSE ROUTE DISTANCE:  12.82098147009777
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.801209597808723
# REVERSE ROUTE DISTANCE:  11.476867893235918
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.561963819597683
# REVERSE ROUTE DISTANCE:  16.218415016112242
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.235022413584346
# REVERSE ROUTE DISTANCE:  11.995061195017971
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.168182772084545
# REVERSE ROUTE DISTANCE:  15.7138102945084
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.269530369708015
# REVERSE ROUTE DISTANCE:  13.988730287193498
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.320434613648008
# REVERSE ROUTE DISTANCE:  13.425247020079354
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.155542969535102
# REVERSE ROUTE DISTANCE:  13.976275483480455
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.237141915931755
# REVERSE ROUTE DISTANCE:  15.161722423070945
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.784520786695253
# REVERSE ROUTE DISTANCE:  14.640030567661732
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.99384554478275
# REVERSE ROUTE DISTANCE:  12.797987244934408
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.474222206842176
# REVERSE ROUTE DISTANCE:  14.187078514959241
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.771892212572688
# REVERSE ROUTE DISTANCE:  14.920317731781642
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 13.240345618079733
# REVERSE ROUTE DISTANCE:  13.954855794875709
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 97
# NETWORK CONNECTION TYPE: Area
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.494160614365587
# REVERSE ROUTE DISTANCE:  15.048596710002212
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.112313460595729
# REVERSE ROUTE DISTANCE:  14.794383355734404
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.861785317317786
# REVERSE ROUTE DISTANCE:  14.548669997898637
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.140106544844041
# REVERSE ROUTE DISTANCE:  14.104139589197867
# # OF CONNECTIONS AND TOTAL DISTANCE: 10 - 14.358120230669753
# REVERSE ROUTE DISTANCE:  11.804710583239059
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.307002358984386
# REVERSE ROUTE DISTANCE:  14.097471768510152
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.869878230422966
# REVERSE ROUTE DISTANCE:  13.588912861368206
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.398475278116857
# REVERSE ROUTE DISTANCE:  14.90573441524323
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.740791253753052
# REVERSE ROUTE DISTANCE:  14.37778578698254
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.713816366217642
# REVERSE ROUTE DISTANCE:  15.194219142481327
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.247766373769021
# REVERSE ROUTE DISTANCE:  12.098814534205172
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.086929704064598
# REVERSE ROUTE DISTANCE:  12.73716894071406
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.35344119073816
# REVERSE ROUTE DISTANCE:  15.108057216117352
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.918591504577101
# REVERSE ROUTE DISTANCE:  12.77198120751645
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.734179161564528
# REVERSE ROUTE DISTANCE:  15.204645144834089
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.912947048202415
# REVERSE ROUTE DISTANCE:  13.657344542768614
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.609496675040376
# REVERSE ROUTE DISTANCE:  13.787275361238137
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.21878073839957
# REVERSE ROUTE DISTANCE:  13.913789562019002
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.88055376988233
# REVERSE ROUTE DISTANCE:  12.271783810445127
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.237534434141324
# REVERSE ROUTE DISTANCE:  14.3208468038671
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.645026780907836
# REVERSE ROUTE DISTANCE:  15.505260420710956
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.105595953987255
# REVERSE ROUTE DISTANCE:  13.049328500328087
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.968687112316756
# REVERSE ROUTE DISTANCE:  13.981532395928523
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.63411670962538
# REVERSE ROUTE DISTANCE:  13.457902260189892
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.268095094134733
# REVERSE ROUTE DISTANCE:  14.297134967596147
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.62871441926002
# REVERSE ROUTE DISTANCE:  13.013373738488623
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.870535892134452
# REVERSE ROUTE DISTANCE:  12.068721245492629
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.823438958603209
# REVERSE ROUTE DISTANCE:  14.548007969680441
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.793684641893188
# REVERSE ROUTE DISTANCE:  12.815463973862448
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.910968874253422
# REVERSE ROUTE DISTANCE:  15.104898778742687
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 98
# NETWORK CONNECTION TYPE: Area
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.719475589899949
# REVERSE ROUTE DISTANCE:  13.137085278064545
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 13.3665934130002
# REVERSE ROUTE DISTANCE:  13.531555447956178
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.860360842853149
# REVERSE ROUTE DISTANCE:  15.848188788968368
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.793979287971757
# REVERSE ROUTE DISTANCE:  11.733995831584435
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.554441698281066
# REVERSE ROUTE DISTANCE:  14.471125414917463
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.536600528702628
# REVERSE ROUTE DISTANCE:  14.149527156395173
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.89968519583242
# REVERSE ROUTE DISTANCE:  14.162944939347678
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.387822184565902
# REVERSE ROUTE DISTANCE:  13.118028705562262
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.596576066337109
# REVERSE ROUTE DISTANCE:  14.469057277683552
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.873204553448506
# REVERSE ROUTE DISTANCE:  12.93147089593009
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.046928776384169
# REVERSE ROUTE DISTANCE:  13.213901322160165
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.212938321568988
# REVERSE ROUTE DISTANCE:  14.36790233015099
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.824230547908947
# REVERSE ROUTE DISTANCE:  14.006688441414259
# # OF CONNECTIONS AND TOTAL DISTANCE: 5 - 13.796591694309335
# REVERSE ROUTE DISTANCE:  13.405812650907322
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.029177143409632
# REVERSE ROUTE DISTANCE:  14.255028428968355
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.396934899956937
# REVERSE ROUTE DISTANCE:  14.875040170420958
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.214433570382154
# REVERSE ROUTE DISTANCE:  14.037023326657762
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.541253785204661
# REVERSE ROUTE DISTANCE:  12.107306186039786
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.008447228010777
# REVERSE ROUTE DISTANCE:  12.674046186114884
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.892532899247755
# REVERSE ROUTE DISTANCE:  14.171792880444059
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.49179676343433
# REVERSE ROUTE DISTANCE:  16.799838808991037
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.385319437050075
# REVERSE ROUTE DISTANCE:  13.806362704539609
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.717696708956463
# REVERSE ROUTE DISTANCE:  12.081868319870097
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.10900744586699
# REVERSE ROUTE DISTANCE:  13.521246126732171
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.692968099600726
# REVERSE ROUTE DISTANCE:  13.359955727193153
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.678869718613553
# REVERSE ROUTE DISTANCE:  15.312763757149217
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.013452065792983
# REVERSE ROUTE DISTANCE:  16.265088174350996
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 12.993662711804609
# REVERSE ROUTE DISTANCE:  13.267510228365225
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.620915166202796
# REVERSE ROUTE DISTANCE:  14.379499491516912
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.333761436464721
# REVERSE ROUTE DISTANCE:  14.774210737068078
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# NETWORK 99
# NETWORK CONNECTION TYPE: Area
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.37847502518405
# REVERSE ROUTE DISTANCE:  15.515945030077534
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.011577059053351
# REVERSE ROUTE DISTANCE:  14.031611550232551
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.967432644168595
# REVERSE ROUTE DISTANCE:  15.791936979118852
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.232026509361718
# REVERSE ROUTE DISTANCE:  14.709776006629191
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.580205997439958
# REVERSE ROUTE DISTANCE:  14.247928694009499
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.890867554755978
# REVERSE ROUTE DISTANCE:  14.183788899009906
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.01857583254016
# REVERSE ROUTE DISTANCE:  12.927492461430186
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.68319265247311
# REVERSE ROUTE DISTANCE:  14.813521904989555
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 13.802439398486246
# REVERSE ROUTE DISTANCE:  14.166106727313249
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.768476980380559
# REVERSE ROUTE DISTANCE:  14.886046103197616
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 12.02205661824263
# REVERSE ROUTE DISTANCE:  12.988615759913017
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.68458096899417
# REVERSE ROUTE DISTANCE:  13.364696046144708
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.048834857645728
# REVERSE ROUTE DISTANCE:  14.096163604319559
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.394368635838674
# REVERSE ROUTE DISTANCE:  14.900004378834673
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 12.810409599937497
# REVERSE ROUTE DISTANCE:  12.642245192495523
# # OF CONNECTIONS AND TOTAL DISTANCE: 9 - 14.386678335591991
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.927042444073894
# REVERSE ROUTE DISTANCE:  14.830234816746255
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.383499542452952
# REVERSE ROUTE DISTANCE:  16.135590535561995
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.286409171572897
# REVERSE ROUTE DISTANCE:  14.028404388252207
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.880238251760382
# REVERSE ROUTE DISTANCE:  13.96780178533047
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.119669928328506
# REVERSE ROUTE DISTANCE:  14.585716247140473
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 14.509966989967914
# REVERSE ROUTE DISTANCE:  13.757485553718965
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.623421622651131
# REVERSE ROUTE DISTANCE:  15.312158119800408
# # OF CONNECTIONS AND TOTAL DISTANCE: 6 - 13.06175828730018
# REVERSE ROUTE DISTANCE:  13.795898180240595
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.60335630746033
# REVERSE ROUTE DISTANCE:  14.130683693057403
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.581488758112235
# REVERSE ROUTE DISTANCE:  15.177781101422346
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.600777736542875
# REVERSE ROUTE DISTANCE:  13.372827779396099
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 13.884633638087234
# REVERSE ROUTE DISTANCE:  15.37604844351631
# # OF CONNECTIONS AND TOTAL DISTANCE: 7 - 14.080110042751375
# REVERSE ROUTE DISTANCE:  12.066832993716625
# # OF CONNECTIONS AND TOTAL DISTANCE: 8 - 14.154739395160378
# REVERSE ROUTE DISTANCE:  14.009757111738551
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...

# %%
# Creating Maps for visualization
i = 1
for route_network in list_of_networks_Manila:
    map_center = (14.599512, 120.984222)
    m = folium.Map(location=map_center, zoom_start=10, tiles='openstreetmap')

    # Plotting in the Map
    add_markers(route_network.stops, route_network.graph, m, False)

    for route in route_network.routes:
        for connection in route.route:
            plot_route_folium(graph_of_stops_Manila, connection, m, route.route_id, False)
    m.save(f"{map_html_location}Route Map-{i}.html")
    i += 1

# %%
# Creating Maps for visualization
i = 1
for route_network in list_of_networks_Manila:
    map_center = (14.599512, 120.984222)
    m = folium.Map(location=map_center, zoom_start=10, tiles='openstreetmap')

    # Plotting in the Map
    add_markers(route_network.reversed_stops, route_network.graph, m, True)
        
    for route in route_network.reversed_routes:
        if route is None:
            continue
        for connection in route.route:
            plot_route_folium(graph_of_stops_Manila, connection, m, route.route_id, True)
            
    m.save(f"{map_html_location}Reverse Route Map-{i}.html")
    i += 1

# %% [markdown]
# #### Genetic Algorithm (Only to generate new GA results)

# %%
# TESTING GA ---------------------------------------------------------]
# There should a pickle file already of the latest networks

# GA Configuration
mutation_probability = 0.2
num_mutations_probabilities = [0.1, 0.1, 0.4, 0.2, 0.2]
plateau_threshold = 0.0001
plateau_max_count = 500
max_generations = 10000

#Weights and Fitness Function configuration
num_failure_removal = 4
weight_random_failure = 0.15
weight_targeted_failure = 0.15
weight_connectivity = 0.5
weight_network_coverage = 0.2

population = perform_genetic_algorithm(list_of_networks_Manila, graph_of_stops_Manila, mutation_probability, num_mutations_probabilities, num_failure_removal,
                                  weight_random_failure, weight_network_coverage, weight_targeted_failure, weight_connectivity, plateau_threshold, plateau_max_count, max_generations)
# Out:
# Generation 1
# Network Score: 35.968635155096145
# Network Score: 35.905776746733025
# Network Score: 35.85204160077789
# Network Score: 35.757443284010826
# Network Score: 35.728915710868435
# Network Score: 35.715418947715435
# Network Score: 35.641045302490696
# Network Score: 35.40220890364493
# Network Score: 35.37339242750552
# Network Score: 35.310296542624165
# Network Score: 34.9401873003943
# Network Score: 34.899041209275744
# Network Score: 34.78079219520493
# Network Score: 34.613613163911644
# Network Score: 34.527808149209385
# Network Score: 34.412097925102955
# Network Score: 34.289715452328934
# Network Score: 34.15471074547073
# Network Score: 34.01142302227446
# Network Score: 33.99047093289235
# Network Score: 33.87446566525143
# Network Score: 33.85842789975986
# Network Score: 33.85208112735794
# Network Score: 33.80920538028759
# Network Score: 33.770181866558346
# Network Score: 33.73738886486087
# Network Score: 33.72167473113008
# Network Score: 33.616189666290495
# Network Score: 33.569966250416364
# Network Score: 33.51132494985046
# Network Score: 33.48085307802566
# Network Score: 33.477961443807736
# Network Score: 33.47279354808862
# Network Score: 33.467663969434355
# Network Score: 33.42949493371762
# Network Score: 33.241949957568195
# Network Score: 33.20511155243981
# Network Score: 33.203181643991115
# Network Score: 33.16887844527218
# Network Score: 33.03023880216071
# Network Score: 32.91198432145912
# Network Score: 32.910471443760834
# Network Score: 32.75712080912436
# Network Score: 32.67645005747623
# Network Score: 32.58297201095784
# Network Score: 32.56254155081151
# Network Score: 32.410990177920894
# Network Score: 32.346152849455734
# Network Score: 32.1975779257431
# Network Score: 32.185408923454794
# Network Score: 32.179973018745414
# Network Score: 32.16146033141015
# Network Score: 32.15933173269187
# Network Score: 32.15384479294894
# Network Score: 32.09915570264984
# Network Score: 32.07781539061801
# Network Score: 31.935441064406167
# Network Score: 31.921042371514133
# Network Score: 31.84914083266055
# Network Score: 31.7683618710293
# Network Score: 31.728314438350175
# Network Score: 31.70658479190967
# Network Score: 31.689653935740242
# Network Score: 31.645379291394836
# Network Score: 31.549118384956262
# Network Score: 31.456130137912282
# Network Score: 31.442467796013783
# Network Score: 31.39553198572265
# Network Score: 31.389595395020404
# Network Score: 31.350080999146815
# Network Score: 31.32146831923765
# Network Score: 31.261864430056395
# Network Score: 31.257480694163217
# Network Score: 31.117590423292196
# Network Score: 31.106344473868155
# Network Score: 31.098759078700198
# Network Score: 31.013033840171758
# Network Score: 30.96034209371406
# Network Score: 30.84727372674614
# Network Score: 30.79106915977476
# Network Score: 30.770581570579257
# Network Score: 30.678276124513488
# Network Score: 30.65876946250246
# Network Score: 30.422879221690724
# Network Score: 30.406342977233496
# Network Score: 30.33281020600005
# Network Score: 30.12114247928363
# Network Score: 29.98618250344986
# Network Score: 29.980775619146506
# Network Score: 29.979142202580466
# Network Score: 29.963479571635215
# Network Score: 29.784432383806358
# Network Score: 29.74346744774783
# Network Score: 29.47024268926054
# Network Score: 29.429303839036674
# Network Score: 29.308040661912024
# Network Score: 28.918222647682875
# Network Score: 28.803323120441647
# Network Score: 28.544708340283574
# Network Score: 26.55817574078823
# Generation 1 Max Score: 35.968635155096145
# Generation 1 Average Score: 32.37609687878107
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 8-B
# Key: 8-A
# 3637 - 3862
# 3862 - 3059
# 3059 - 3693
# 3693 - 1564
# 1564 - 4415
# 4415 - 3832
# REVERSE ROUTE DISTANCE:  14.010662052260749
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 26-B
# Key: 26-A
# 243 - 2494
# 2494 - 1803
# 1803 - 1965
# 1965 - 2541
# 2541 - 1574
# 1574 - 4370
# REVERSE ROUTE DISTANCE:  15.627994956409957
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 26-B
# Key: 26-A
# 2320 - 1850
# 1850 - 1490
# 1490 - 1981
# 1981 - 1752
# 1752 - 3015
# 3015 - 1822
# 1822 - 3329
# 3329 - 3350
# REVERSE ROUTE DISTANCE:  13.661388471555616
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 14-B
# Key: 14-A
# 4018 - 2715
# 2715 - 2649
# 2649 - 3173
# 3173 - 4311
# 4311 - 3192
# 3192 - 1875
# 1875 - 2557
# REVERSE ROUTE DISTANCE:  15.521853609777352
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
#
# Generation 2
# Network Score: 35.968635155096145
# Network Score: 35.905776746733025
# Network Score: 35.85204160077789
# Network Score: 35.757443284010826
# Network Score: 35.728915710868435
# Network Score: 35.715418947715435
# Network Score: 35.641045302490696
# Network Score: 35.40220890364493
# Network Score: 35.37339242750552
# Network Score: 35.310296542624165
# Network Score: 34.9401873003943
# Network Score: 34.899041209275744
# Network Score: 34.89543542453717
# Network Score: 34.78079219520493
# Network Score: 34.613613163911644
# Network Score: 34.527808149209385
# Network Score: 34.412097925102955
# Network Score: 34.289715452328934
# Network Score: 34.15471074547073
# Network Score: 34.01142302227446
# Network Score: 33.99047093289235
# Network Score: 33.87446566525143
# Network Score: 33.85842789975986
# Network Score: 33.85208112735794
# Network Score: 33.80920538028759
# Network Score: 33.770181866558346
# Network Score: 33.73738886486087
# Network Score: 33.72167473113008
# Network Score: 33.616189666290495
# Network Score: 33.569966250416364
# Network Score: 33.51132494985046
# Network Score: 33.48085307802566
# Network Score: 33.477961443807736
# Network Score: 33.47279354808862
# Network Score: 33.467663969434355
# Network Score: 33.42949493371762
# Network Score: 33.241949957568195
# Network Score: 33.20511155243981
# Network Score: 33.203181643991115
# Network Score: 33.16887844527218
# Network Score: 33.09200475258956
# Network Score: 33.03023880216071
# Network Score: 32.91198432145912
# Network Score: 32.910471443760834
# Network Score: 32.75712080912436
# Network Score: 32.67645005747623
# Network Score: 32.58297201095784
# Network Score: 32.56254155081151
# Network Score: 32.410990177920894
# Network Score: 32.39150609036062
# Network Score: 32.3857773768017
# Network Score: 32.346152849455734
# Network Score: 32.320169972211495
# Network Score: 32.1975779257431
# Network Score: 32.185408923454794
# Network Score: 32.179973018745414
# Network Score: 32.16146033141015
# Network Score: 32.15933173269187
# Network Score: 32.15384479294894
# Network Score: 32.09915570264984
# Network Score: 32.07781539061801
# Network Score: 31.935441064406167
# Network Score: 31.921042371514133
# Network Score: 31.84914083266055
# Network Score: 31.7683618710293
# Network Score: 31.728314438350175
# Network Score: 31.70658479190967
# Network Score: 31.689653935740242
# Network Score: 31.6627549018832
# Network Score: 31.645379291394836
# Network Score: 31.549118384956262
# Network Score: 31.456130137912282
# Network Score: 31.442467796013783
# Network Score: 31.39553198572265
# Network Score: 31.389595395020404
# Network Score: 31.350080999146815
# Network Score: 31.32146831923765
# Network Score: 31.261864430056395
# Network Score: 31.257480694163217
# Network Score: 31.117590423292196
# Network Score: 31.106344473868155
# Network Score: 31.098759078700198
# Network Score: 31.013033840171758
# Network Score: 30.99462267593702
# Network Score: 30.96034209371406
# Network Score: 30.866270262393112
# Network Score: 30.84727372674614
# Network Score: 30.79106915977476
# Network Score: 30.770581570579257
# Network Score: 30.678276124513488
# Network Score: 30.65876946250246
# Network Score: 30.422879221690724
# Network Score: 30.406342977233496
# Network Score: 30.33281020600005
# Network Score: 30.12114247928363
# Network Score: 29.98618250344986
# Network Score: 29.980775619146506
# Network Score: 29.979142202580466
# Network Score: 29.688247447683697
# Network Score: 29.216021285256225
# Generation 2 Max Score: 35.968635155096145
# Generation 2 Average Score: 32.645991016251656
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 17-B
# Key: 17-A
# 2833 - 1403
# 1403 - 1811
# 1811 - 2896
# 2896 - 2041
# 2041 - 925
# 925 - 2465
# 2465 - 2887
# 2887 - 2900
# REVERSE ROUTE DISTANCE:  15.58358325656907
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 9-B
# Key: 9-A
# 358 - 1855
# 1855 - 2950
# 2950 - 1819
# 1819 - 2583
# 2583 - 4333
# 4333 - 3598
# 3598 - 3949
# REVERSE ROUTE DISTANCE:  14.344867964202546
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# Reverse Key: 18-B
# Key: 18-A
# 2046 - 3226
# 3226 - 3895
# 3895 - 2725
# 2725 - 1492
# 1492 - 4204
# 4204 - 4378
# 4378 - 113
# REVERSE ROUTE DISTANCE:  14.718966089845399
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 21-B
# Key: 21-A
# 1853 - 1277
# 1277 - 1492
# 1492 - 1265
# 1265 - 1936
# 1936 - 2613
# 2613 - 1977
# 1977 - 4334
# 4334 - 4356
# REVERSE ROUTE DISTANCE:  14.612641500367953
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
#
# Generation 3
# Network Score: 35.968635155096145
# Network Score: 35.905776746733025
# Network Score: 35.85204160077789
# Network Score: 35.757443284010826
# Network Score: 35.728915710868435
# Network Score: 35.715418947715435
# Network Score: 35.641045302490696
# Network Score: 35.52876757913933
# Network Score: 35.40220890364493
# Network Score: 35.37339242750552
# Network Score: 35.310296542624165
# Network Score: 35.04616233220132
# Network Score: 34.95549597546063
# Network Score: 34.9401873003943
# Network Score: 34.899041209275744
# Network Score: 34.89543542453717
# Network Score: 34.78079219520493
# Network Score: 34.739614919040704
# Network Score: 34.613613163911644
# Network Score: 34.527808149209385
# Network Score: 34.412097925102955
# Network Score: 34.289715452328934
# Network Score: 34.15471074547073
# Network Score: 34.01142302227446
# Network Score: 33.99047093289235
# Network Score: 33.87446566525143
# Network Score: 33.85842789975986
# Network Score: 33.85208112735794
# Network Score: 33.80920538028759
# Network Score: 33.770181866558346
# Network Score: 33.73738886486087
# Network Score: 33.72167473113008
# Network Score: 33.616189666290495
# Network Score: 33.569966250416364
# Network Score: 33.5624687390394
# Network Score: 33.51132494985046
# Network Score: 33.48085307802566
# Network Score: 33.477961443807736
# Network Score: 33.47279354808862
# Network Score: 33.467663969434355
# Network Score: 33.42949493371762
# Network Score: 33.241949957568195
# Network Score: 33.20511155243981
# Network Score: 33.203181643991115
# Network Score: 33.16887844527218
# Network Score: 33.0957707353087
# Network Score: 33.09200475258956
# Network Score: 33.03023880216071
# Network Score: 32.91198432145912
# Network Score: 32.910471443760834
# Network Score: 32.86303424972075
# Network Score: 32.83373414981723
# Network Score: 32.75712080912436
# Network Score: 32.67645005747623
# Network Score: 32.58297201095784
# Network Score: 32.56254155081151
# Network Score: 32.410990177920894
# Network Score: 32.39150609036062
# Network Score: 32.3857773768017
# Network Score: 32.346152849455734
# Network Score: 32.33856041251542
# Network Score: 32.320169972211495
# Network Score: 32.1975779257431
# Network Score: 32.185408923454794
# Network Score: 32.179973018745414
# Network Score: 32.16146033141015
# Network Score: 32.15933173269187
# Network Score: 32.15384479294894
# Network Score: 32.09915570264984
# Network Score: 32.07781539061801
# Network Score: 32.01078414981693
# Network Score: 31.935441064406167
# Network Score: 31.921042371514133
# Network Score: 31.84914083266055
# Network Score: 31.7683618710293
# Network Score: 31.728314438350175
# Network Score: 31.70658479190967
# Network Score: 31.689653935740242
# Network Score: 31.6627549018832
# Network Score: 31.645379291394836
# Network Score: 31.549118384956262
# Network Score: 31.456130137912282
# Network Score: 31.442467796013783
# Network Score: 31.39553198572265
# Network Score: 31.389595395020404
# Network Score: 31.350080999146815
# Network Score: 31.32146831923765
# Network Score: 31.261864430056395
# Network Score: 31.257480694163217
# Network Score: 31.117590423292196
# Network Score: 31.106344473868155
# Network Score: 31.098759078700198
# Network Score: 31.013033840171758
# Network Score: 30.99462267593702
# Network Score: 30.96034209371406
# Network Score: 30.866270262393112
# Network Score: 30.84727372674614
# Network Score: 30.79106915977476
# Network Score: 30.770581570579257
# Network Score: 30.678276124513488
# Generation 3 Max Score: 35.968635155096145
# Generation 3 Average Score: 33.00781181462399
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 22-B
# Key: 22-A
# 3626 - 4015
# 4015 - 3117
# 3117 - 3906
# 3906 - 2654
# 2654 - 1781
# 1781 - 2887
# REVERSE ROUTE DISTANCE:  15.078270599547297
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# Reverse Key: 28-B
# Key: 28-A
# 1106 - 3903
# 3903 - 3825
# 3825 - 2950
# 2950 - 938
# 938 - 828
# 828 - 10
# 10 - 369
# REVERSE ROUTE DISTANCE:  15.663024362929983
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# Reverse Key: 27-B
# Key: 27-A
# 3220 - 3363
# 3363 - 3666
# 3666 - 3999
# 3999 - 3728
# 3728 - 2865
# 2865 - 1889
# 1889 - 2313
# REVERSE ROUTE DISTANCE:  14.681088703453451
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# Reverse Key: 21-B
# Key: 21-A
# 2736 - 3343
# 3343 - 2464
# 2464 - 255
# 255 - 2191
# 2191 - 4383
# 4383 - 1973
# REVERSE ROUTE DISTANCE:  15.55140618142385
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 3-B
# Key: 3-A
# 2542 - 2909
# 2909 - 2637
# 2637 - 4340
# 4340 - 3700
# 3700 - 3623
# 3623 - 3389
# 3389 - 3467
# REVERSE ROUTE DISTANCE:  15.019994492038972
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
#
# Generation 4
# Network Score: 36.116625187995986
# Network Score: 35.968635155096145
# Network Score: 35.905776746733025
# Network Score: 35.85204160077789
# Network Score: 35.757443284010826
# Network Score: 35.728915710868435
# Network Score: 35.715418947715435
# Network Score: 35.641045302490696
# Network Score: 35.52876757913933
# Network Score: 35.40220890364493
# Network Score: 35.37339242750552
# Network Score: 35.310296542624165
# Network Score: 35.04616233220132
# Network Score: 34.95549597546063
# Network Score: 34.9401873003943
# Network Score: 34.899041209275744
# Network Score: 34.89543542453717
# Network Score: 34.78079219520493
# Network Score: 34.739614919040704
# Network Score: 34.613613163911644
# Network Score: 34.527808149209385
# Network Score: 34.412097925102955
# Network Score: 34.289715452328934
# Network Score: 34.15471074547073
# Network Score: 34.01142302227446
# Network Score: 33.99047093289235
# Network Score: 33.87446566525143
# Network Score: 33.85842789975986
# Network Score: 33.85208112735794
# Network Score: 33.80920538028759
# Network Score: 33.770181866558346
# Network Score: 33.73738886486087
# Network Score: 33.72167473113008
# Network Score: 33.71926070742465
# Network Score: 33.616189666290495
# Network Score: 33.591308081538074
# Network Score: 33.569966250416364
# Network Score: 33.5624687390394
# Network Score: 33.51132494985046
# Network Score: 33.48085307802566
# Network Score: 33.477961443807736
# Network Score: 33.47279354808862
# Network Score: 33.467663969434355
# Network Score: 33.44147836794258
# Network Score: 33.43569299861315
# Network Score: 33.42949493371762
# Network Score: 33.241949957568195
# Network Score: 33.239612667632215
# Network Score: 33.20511155243981
# Network Score: 33.203181643991115
# Network Score: 33.16887844527218
# Network Score: 33.0957707353087
# Network Score: 33.09200475258956
# Network Score: 33.03023880216071
# Network Score: 32.91198432145912
# Network Score: 32.910471443760834
# Network Score: 32.86303424972075
# Network Score: 32.83373414981723
# Network Score: 32.75712080912436
# Network Score: 32.67645005747623
# Network Score: 32.58297201095784
# Network Score: 32.56254155081151
# Network Score: 32.410990177920894
# Network Score: 32.39150609036062
# Network Score: 32.3857773768017
# Network Score: 32.346152849455734
# Network Score: 32.33856041251542
# Network Score: 32.320169972211495
# Network Score: 32.1975779257431
# Network Score: 32.185408923454794
# Network Score: 32.179973018745414
# Network Score: 32.16146033141015
# Network Score: 32.15933173269187
# Network Score: 32.15384479294894
# Network Score: 32.09915570264984
# Network Score: 32.07781539061801
# Network Score: 32.01078414981693
# Network Score: 31.935441064406167
# Network Score: 31.921042371514133
# Network Score: 31.84914083266055
# Network Score: 31.7683618710293
# Network Score: 31.728314438350175
# Network Score: 31.70658479190967
# Network Score: 31.689653935740242
# Network Score: 31.680404905572868
# Network Score: 31.6627549018832
# Network Score: 31.645379291394836
# Network Score: 31.616548499324562
# Network Score: 31.549118384956262
# Network Score: 31.456130137912282
# Network Score: 31.442467796013783
# Network Score: 31.39553198572265
# Network Score: 31.389595395020404
# Network Score: 31.350080999146815
# Network Score: 31.32146831923765
# Network Score: 31.261864430056395
# Network Score: 31.257480694163217
# Network Score: 31.13473335328067
# Network Score: 31.117590423292196
# Network Score: 29.024555541484087
# Generation 4 Max Score: 36.116625187995986
# Generation 4 Average Score: 33.1865482876681
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 10-B
# Key: 10-A
# 3453 - 3663
# 3663 - 4316
# 4316 - 2666
# 2666 - 3059
# 3059 - 1746
# 1746 - 2882
# 2882 - 3787
# 3787 - 3841
# REVERSE ROUTE DISTANCE:  14.25341745876831
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 20-B
# Key: 20-A
# 4214 - 2613
# 2613 - 1127
# 1127 - 1407
# 1407 - 2545
# 2545 - 2205
# 2205 - 1267
# 1267 - 2267
# REVERSE ROUTE DISTANCE:  16.039686103448023
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 24-B
# Key: 24-A
# 4594 - 176
# 176 - 2278
# 2278 - 388
# 388 - 308
# 308 - 566
# 566 - 4120
# 4120 - 226
# REVERSE ROUTE DISTANCE:  12.244418234085927
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# Reverse Key: 5-B
# Key: 5-A
# 3142 - 3023
# 3023 - 2997
# 2997 - 2694
# 2694 - 2718
# 2718 - 3372
# 3372 - 2798
# REVERSE ROUTE DISTANCE:  13.551411988820076
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
#
# Generation 5
# Network Score: 36.116625187995986
# Network Score: 35.968635155096145
# Network Score: 35.905776746733025
# Network Score: 35.85204160077789
# Network Score: 35.757443284010826
# Network Score: 35.728915710868435
# Network Score: 35.715418947715435
# Network Score: 35.641045302490696
# Network Score: 35.52876757913933
# Network Score: 35.40220890364493
# Network Score: 35.37339242750552
# Network Score: 35.310296542624165
# Network Score: 35.04616233220132
# Network Score: 34.95549597546063
# Network Score: 34.9401873003943
# Network Score: 34.899041209275744
# Network Score: 34.89543542453717
# Network Score: 34.78079219520493
# Network Score: 34.77879144959789
# Network Score: 34.739614919040704
# Network Score: 34.613613163911644
# Network Score: 34.527808149209385
# Network Score: 34.412097925102955
# Network Score: 34.289715452328934
# Network Score: 34.15471074547073
# Network Score: 34.01142302227446
# Network Score: 33.99047093289235
# Network Score: 33.88878222386357
# Network Score: 33.87446566525143
# Network Score: 33.85842789975986
# Network Score: 33.85208112735794
# Network Score: 33.80920538028759
# Network Score: 33.770181866558346
# Network Score: 33.73738886486087
# Network Score: 33.72167473113008
# Network Score: 33.71926070742465
# Network Score: 33.616189666290495
# Network Score: 33.591308081538074
# Network Score: 33.569966250416364
# Network Score: 33.5624687390394
# Network Score: 33.51132494985046
# Network Score: 33.48085307802566
# Network Score: 33.477961443807736
# Network Score: 33.47279354808862
# Network Score: 33.467663969434355
# Network Score: 33.44147836794258
# Network Score: 33.43569299861315
# Network Score: 33.42949493371762
# Network Score: 33.296731195150095
# Network Score: 33.241949957568195
# Network Score: 33.239612667632215
# Network Score: 33.20511155243981
# Network Score: 33.203181643991115
# Network Score: 33.16887844527218
# Network Score: 33.0957707353087
# Network Score: 33.09200475258956
# Network Score: 33.03023880216071
# Network Score: 32.91198432145912
# Network Score: 32.910471443760834
# Network Score: 32.86303424972075
# Network Score: 32.83373414981723
# Network Score: 32.75712080912436
# Network Score: 32.75106520768851
# Network Score: 32.67645005747623
# Network Score: 32.58297201095784
# Network Score: 32.56254155081151
# Network Score: 32.55894653065025
# Network Score: 32.417609662107544
# Network Score: 32.410990177920894
# Network Score: 32.39150609036062
# Network Score: 32.3857773768017
# Network Score: 32.346152849455734
# Network Score: 32.33856041251542
# Network Score: 32.320169972211495
# Network Score: 32.1975779257431
# Network Score: 32.185408923454794
# Network Score: 32.179973018745414
# Network Score: 32.16146033141015
# Network Score: 32.15933173269187
# Network Score: 32.15384479294894
# Network Score: 32.09915570264984
# Network Score: 32.07781539061801
# Network Score: 32.053448063097804
# Network Score: 32.01078414981693
# Network Score: 31.935441064406167
# Network Score: 31.921042371514133
# Network Score: 31.84914083266055
# Network Score: 31.7683618710293
# Network Score: 31.728314438350175
# Network Score: 31.70658479190967
# Network Score: 31.689653935740242
# Network Score: 31.680404905572868
# Network Score: 31.6627549018832
# Network Score: 31.645379291394836
# Network Score: 31.616548499324562
# Network Score: 31.566361363624402
# Network Score: 31.549118384956262
# Network Score: 31.527603112729366
# Network Score: 31.456130137912282
# Network Score: 30.678376302169
# Generation 5 Max Score: 36.116625187995986
# Generation 5 Average Score: 33.33477174940071
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 17-B
# Key: 17-A
# 1917 - 2369
# 2369 - 2638
# 2638 - 2938
# 2938 - 1416
# 1416 - 1530
# 1530 - 1454
# 1454 - 1143
# 1143 - 1244
# REVERSE ROUTE DISTANCE:  16.263903142774698
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# Reverse Key: 27-B
# Key: 27-A
# 3139 - 2340
# 2340 - 1679
# 1679 - 2960
# 2960 - 2106
# 2106 - 4565
# REVERSE ROUTE DISTANCE:  10.82453006077333
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 18-B
# Key: 18-A
# 4330 - 1405
# 1405 - 1541
# 1541 - 4149
# 4149 - 2092
# 2092 - 2844
# 2844 - 3383
# 3383 - 4352
# 4352 - 3971
# REVERSE ROUTE DISTANCE:  13.324214148151798
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 26-B
# Key: 26-A
# 1193 - 1537
# 1537 - 4412
# 4412 - 3770
# 3770 - 1891
# 1891 - 4559
# 4559 - 2930
# 2930 - 2483
# REVERSE ROUTE DISTANCE:  13.47000376958178
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 10-B
# Key: 10-A
# 2762 - 4259
# 4259 - 3934
# 3934 - 2943
# 2943 - 4366
# 4366 - 1515
# 1515 - 3684
# REVERSE ROUTE DISTANCE:  14.129519504852384
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
#
# Generation 6
# Network Score: 36.116625187995986
# Network Score: 35.968635155096145
# Network Score: 35.905776746733025
# Network Score: 35.85204160077789
# Network Score: 35.81822231985502
# Network Score: 35.757443284010826
# Network Score: 35.728915710868435
# Network Score: 35.715418947715435
# Network Score: 35.641045302490696
# Network Score: 35.52876757913933
# Network Score: 35.40220890364493
# Network Score: 35.37339242750552
# Network Score: 35.310296542624165
# Network Score: 35.07170292890624
# Network Score: 35.04616233220132
# Network Score: 34.95549597546063
# Network Score: 34.9401873003943
# Network Score: 34.899041209275744
# Network Score: 34.89543542453717
# Network Score: 34.78079219520493
# Network Score: 34.77879144959789
# Network Score: 34.739614919040704
# Network Score: 34.613613163911644
# Network Score: 34.5404798144526
# Network Score: 34.527808149209385
# Network Score: 34.412097925102955
# Network Score: 34.289715452328934
# Network Score: 34.15471074547073
# Network Score: 34.01142302227446
# Network Score: 33.99047093289235
# Network Score: 33.88878222386357
# Network Score: 33.87446566525143
# Network Score: 33.85842789975986
# Network Score: 33.85208112735794
# Network Score: 33.80920538028759
# Network Score: 33.770181866558346
# Network Score: 33.73738886486087
# Network Score: 33.72167473113008
# Network Score: 33.71926070742465
# Network Score: 33.616189666290495
# Network Score: 33.591308081538074
# Network Score: 33.569966250416364
# Network Score: 33.5624687390394
# Network Score: 33.51132494985046
# Network Score: 33.50179763519653
# Network Score: 33.48085307802566
# Network Score: 33.477961443807736
# Network Score: 33.47279354808862
# Network Score: 33.467663969434355
# Network Score: 33.44147836794258
# Network Score: 33.43569299861315
# Network Score: 33.42949493371762
# Network Score: 33.37885947951714
# Network Score: 33.296731195150095
# Network Score: 33.241949957568195
# Network Score: 33.239612667632215
# Network Score: 33.20511155243981
# Network Score: 33.203181643991115
# Network Score: 33.16887844527218
# Network Score: 33.0957707353087
# Network Score: 33.09200475258956
# Network Score: 33.03023880216071
# Network Score: 32.91198432145912
# Network Score: 32.910471443760834
# Network Score: 32.86303424972075
# Network Score: 32.83373414981723
# Network Score: 32.75712080912436
# Network Score: 32.75106520768851
# Network Score: 32.67645005747623
# Network Score: 32.58297201095784
# Network Score: 32.56254155081151
# Network Score: 32.55894653065025
# Network Score: 32.417609662107544
# Network Score: 32.410990177920894
# Network Score: 32.39150609036062
# Network Score: 32.3857773768017
# Network Score: 32.346152849455734
# Network Score: 32.33856041251542
# Network Score: 32.320169972211495
# Network Score: 32.1975779257431
# Network Score: 32.185408923454794
# Network Score: 32.179973018745414
# Network Score: 32.16756475469227
# Network Score: 32.16146033141015
# Network Score: 32.15933173269187
# Network Score: 32.15384479294894
# Network Score: 32.10299196495608
# Network Score: 32.09915570264984
# Network Score: 32.07781539061801
# Network Score: 32.053448063097804
# Network Score: 32.01078414981693
# Network Score: 31.935441064406167
# Network Score: 31.921042371514133
# Network Score: 31.84914083266055
# Network Score: 31.78994397796823
# Network Score: 31.7683618710293
# Network Score: 31.760695266778328
# Network Score: 31.728314438350175
# Network Score: 31.70658479190967
# Network Score: 31.556344286518723
# Generation 6 Max Score: 36.116625187995986
# Generation 6 Average Score: 33.50093446533605
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 21-B
# Key: 21-A
# 594 - 2504
# 2504 - 638
# 638 - 175
# 175 - 2407
# 2407 - 2127
# 2127 - 2636
# 2636 - 1897
# REVERSE ROUTE DISTANCE:  12.845712495519859
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# ...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 8-B
# Key: 8-A
# 2107 - 40
# 40 - 674
# 674 - 68
# 68 - 2143
# 2143 - 469
# 469 - 2472
# REVERSE ROUTE DISTANCE:  14.410173097140197
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 8-B
# Key: 8-A
# 4099 - 4143
# 4143 - 283
# 283 - 342
# 342 - 909
# 909 - 4494
# 4494 - 1330
# 1330 - 3684
# 3684 - 3699
# 3699 - 3493
# REVERSE ROUTE DISTANCE:  14.063196575637452
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 10-B
# Key: 10-A
# 4323 - 3850
# 3850 - 3898
# 3898 - 3152
# 3152 - 2384
# 2384 - 1906
# 1906 - 2634
# 2634 - 2736
# REVERSE ROUTE DISTANCE:  14.659986694034725
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# Reverse Key: 5-B
# Key: 5-A
# 3579 - 1244
# 1244 - 1119
# 1119 - 4278
# 4278 - 1243
# 1243 - 1371
# 1371 - 4153
# REVERSE ROUTE DISTANCE:  11.637440084829793
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# Reverse Key: 9-B
# Key: 9-A
# 159 - 4565
# 4565 - 778
# 778 - 228
# 228 - 116
# 116 - 4115
# 4115 - 195
# 195 - 388
# 388 - 2143
# REVERSE ROUTE DISTANCE:  15.563094435471227
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
#
# Generation 51
# Network Score: 40.04046641529679
# Network Score: 39.027420592251694
# Network Score: 38.19565654301254
# Network Score: 38.087836799305364
# Network Score: 38.01727993999513
# Network Score: 38.003140580836664
# Network Score: 37.917826826370465
# Network Score: 37.892555360265746
# Network Score: 37.88646283838549
# Network Score: 37.85639094353033
# Network Score: 37.85579029744026
# Network Score: 37.84420657347493
# Network Score: 37.84412865250308
# Network Score: 37.80785480645123
# Network Score: 37.80069527405316
# Network Score: 37.6872611168519
# Network Score: 37.66472642083541
# Network Score: 37.663703391285516
# Network Score: 37.64556050926981
# Network Score: 37.63919211474915
# Network Score: 37.58311113094237
# Network Score: 37.50382363911493
# Network Score: 37.46116548080073
# Network Score: 37.44970745423245
# Network Score: 37.43403677079332
# Network Score: 37.422700051451685
# Network Score: 37.34654834853623
# Network Score: 37.3293584741743
# Network Score: 37.3222314260343
# Network Score: 37.24582273578256
# Network Score: 37.216638334465905
# Network Score: 37.21460354960972
# Network Score: 37.192285975294645
# Network Score: 37.183316698548424
# Network Score: 37.177173353838526
# Network Score: 37.165015807741426
# Network Score: 37.122157364331756
# Network Score: 37.027955145931415
# Network Score: 37.025783130372595
# Network Score: 37.02452014599576
# Network Score: 37.02155027489906
# Network Score: 37.01275753414784
# Network Score: 36.997263430191445
# Network Score: 36.977217464461425
# Network Score: 36.96945228187026
# Network Score: 36.94593460276618
# Network Score: 36.94434290719992
# Network Score: 36.923561721410245
# Network Score: 36.923561721410245
# Network Score: 36.92355169457401
# Network Score: 36.923535320311416
# Network Score: 36.88911196870447
# Network Score: 36.87605099839606
# Network Score: 36.87241892805586
# Network Score: 36.86908808899948
# Network Score: 36.868767789452775
# Network Score: 36.86785731929231
# Network Score: 36.84345097489556
# Network Score: 36.84239090422418
# Network Score: 36.81468116650051
# Network Score: 36.81370703442834
# Network Score: 36.780839887880035
# Network Score: 36.74760821912688
# Network Score: 36.74684477269014
# Network Score: 36.74441546750062
# Network Score: 36.74123774446336
# Network Score: 36.7142217189257
# Network Score: 36.700636460994055
# Network Score: 36.69037058960187
# Network Score: 36.68735090241576
# Network Score: 36.68708861885568
# Network Score: 36.68695402856162
# Network Score: 36.68157676878648
# Network Score: 36.68157676878648
# Network Score: 36.67237336520245
# Network Score: 36.6723244604155
# Network Score: 36.66953149452314
# Network Score: 36.66928808135046
# Network Score: 36.648610010622654
# Network Score: 36.6414139558593
# Network Score: 36.608483354243845
# Network Score: 36.604287550048035
# Network Score: 36.601538920325154
# Network Score: 36.59720304262625
# Network Score: 36.58643655925819
# Network Score: 36.58190255434879
# Network Score: 36.573617260002386
# Network Score: 36.55309024742211
# Network Score: 36.550171007048775
# Network Score: 36.540617762886676
# Network Score: 36.52380555700386
# Network Score: 36.52380555700386
# Network Score: 36.51521764019872
# Network Score: 36.51193045963162
# Network Score: 36.50911692468334
# Network Score: 36.501633682918204
# Network Score: 36.498451397682686
# Network Score: 36.41336470959389
# Network Score: 36.17602442793336
# Network Score: 35.8196348934666
# Generation 51 Max Score: 40.04046641529679
# Generation 51 Average Score: 37.08000961965238
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 2-B
# Key: 2-A
# 1441 - 3782
# 3782 - 4173
# 4173 - 3715
# 3715 - 1437
# 1437 - 3204
# 3204 - 4458
# 4458 - 1250
# REVERSE ROUTE DISTANCE:  12.766649570256654
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 7-B
# Key: 7-A
# 3493 - 3368
# 3368 - 4555
# 4555 - 1789
# 1789 - 2571
# 2571 - 1566
# 1566 - 1503
# REVERSE ROUTE DISTANCE:  12.926485732421899
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# Reverse Key: 18-B
# Key: 18-A
# 3460 - 3044
# 3044 - 4285
# 4285 - 3371
# 3371 - 3825
# 3825 - 2622
# 2622 - 2453
# 2453 - 2518
# 2518 - 169
# REVERSE ROUTE DISTANCE:  15.451489532582574
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 5-B
# Key: 5-A
# 2541 - 3839
# 3839 - 1129
# 1129 - 1514
# 1514 - 2488
# 2488 - 2610
# 2610 - 1282
# 1282 - 1458
# 1458 - 1241
# REVERSE ROUTE DISTANCE:  12.274957396380302
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
# * Checking Child 1 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# * Checking Child 2 for errors:
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# Reverse Key: 8-B
# Key: 8-A
# 3322 - 2875
# 2875 - 2748
# 2748 - 3282
# 3282 - 2062
# 2062 - 2123
# 2123 - 2487
# 2487 - 3072
# REVERSE ROUTE DISTANCE:  14.236585130239163
# Checking for graph and route consistency...
# Checking for graph and list of stops consistency...
# Checking if order of routes is correct...
# Checking for list of stops and route consistency...
# Checking for duplicates in routes...
# Checking for duplicate stops and connections...
#
# MUTATION DONE
#
#
# Generation 52
# Network Score: 40.04046641529679
# Network Score: 39.44860054075716
# Network Score: 39.027420592251694
# Network Score: 38.19565654301254
# Network Score: 38.087836799305364
# Network Score: 38.01727993999513
# Network Score: 38.003140580836664
# Network Score: 37.917826826370465
# Network Score: 37.892555360265746
# Network Score: 37.88646283838549
# Network Score: 37.85639094353033
# Network Score: 37.85579029744026
# Network Score: 37.84420657347493
# Network Score: 37.84412865250308
# Network Score: 37.8372966172416
# Network Score: 37.80785480645123
# Network Score: 37.80069527405316
# Network Score: 37.6872611168519
# Network Score: 37.66472642083541
# Network Score: 37.663703391285516
# Network Score: 37.64556050926981
# Network Score: 37.63919211474915
# Network Score: 37.58311113094237
# Network Score: 37.50382363911493
# Network Score: 37.46116548080073
# Network Score: 37.44970745423245
# Network Score: 37.444494518502154
# Network Score: 37.43403677079332
# Network Score: 37.422700051451685
# Network Score: 37.34654834853623
# Network Score: 37.3293584741743
# Network Score: 37.3222314260343
# Network Score: 37.24582273578256
# Network Score: 37.216638334465905
# Network Score: 37.21460354960972
# Network Score: 37.192285975294645
# Network Score: 37.183316698548424
# Network Score: 37.177173353838526
# Network Score: 37.165015807741426
# Network Score: 37.122157364331756
# Network Score: 37.027955145931415
# Network Score: 37.025783130372595
# Network Score: 37.02452014599576
# Network Score: 37.02155027489906
# Network Score: 37.01275753414784
# Network Score: 36.997263430191445
# Network Score: 36.977217464461425
# Network Score: 36.96945228187026
# Network Score: 36.94593460276618
# Network Score: 36.94434290719992
# Network Score: 36.923561721410245
# Network Score: 36.923561721410245
# Network Score: 36.92355169457401
# Network Score: 36.923535320311416
# Network Score: 36.88911196870447
# Network Score: 36.87605099839606
# Network Score: 36.87241892805586
# Network Score: 36.86908808899948
# Network Score: 36.868767789452775
# Network Score: 36.86785731929231
# Network Score: 36.84345097489556
# Network Score: 36.84239090422418
# Network Score: 36.81468116650051
# Network Score: 36.81370703442834
# Network Score: 36.780839887880035
# Network Score: 36.74760821912688
# Network Score: 36.74684477269014
# Network Score: 36.74441546750062
# Network Score: 36.74123774446336
# Network Score: 36.74099714323402
# Network Score: 36.7142217189257
# Network Score: 36.700636460994055
# Network Score: 36.69037058960187
# Network Score: 36.68735090241576
# Network Score: 36.68708861885568
# Network Score: 36.68695402856162
# Network Score: 36.68157676878648
# Network Score: 36.68157676878648
# Network Score: 36.67237336520245
# Network Score: 36.6723244604155
# Network Score: 36.66953149452314
# Network Score: 36.66928808135046
# Network Score: 36.64978594916072
# Network Score: 36.648610010622654
# Network Score: 36.6414139558593
# Network Score: 36.6176433168746
# Network Score: 36.608483354243845
# Network Score: 36.604287550048035
# Network Score: 36.601538920325154
# Network Score: 36.59720304262625
# Network Score: 36.58643655925819
# Network Score: 36.58190255434879
# Network Score: 36.573617260002386
# Network Score: 36.55309024742211
# Network Score: 36.550171007048775
# Network Score: 36.540617762886676
# Network Score: 36.50109997005973
# Network Score: 36.32614161091624
# Network Score: 35.78643910121314
# Network Score: 34.224882011401846
# Generation 52 Max Score: 40.04046641529679
# Generation 52 Average Score: 37.11585357494483

# %%
for network in population:
    print(f"Network Score {network.fitness_score}")
    i += 1

# %%
# Exporting GA Results
unique_types = {obj.conn_type for obj in population}
if len(unique_types) > 1:
    export_conn_type = "Mixed"
    
    export_networks(population, f"{Manila_pikl_filepath}Manila_GA_Route_networks_{export_conn_type}.pkl")
    print(f"Exported: Manila_GA_Route_networks_{export_conn_type}.pkl")
else:
    export_conn_type = population[0].conn_type
    export_walk_distance = population[0].walk_distance

    export_networks(population, f"{Manila_pikl_filepath}Manila_GA_Route_networks_{export_conn_type}_{export_walk_distance}.pkl")
    print(f"Exported: Manila_GA_Route_networks_{export_conn_type}_{export_walk_distance}.pkl")

# %% [markdown]
# #### Visualization of Genetic Algorithm Results

# %%
# Visualization
unique_types = {obj.conn_type for obj in population}
if len(unique_types) > 1:
    export_conn_type = "Mixed"
    map_html_location = "GA Result Route Networks HTML/Manila/Mixed/"
else:
    export_conn_type = population[0].conn_type
    export_walk_distance = population[0].walk_distance
    map_html_location = f"GA Result Route Networks HTML/Manila/{export_conn_type}/{export_walk_distance}/"

i = 1
for network in population:
    map_center = (14.599512, 120.984222)
    m = folium.Map(location=map_center, zoom_start=10, tiles='openstreetmap')
    add_markers(network.stops, network.graph)
    
    for route in network.routes:
        for connection in route.route:
            ox.plot_route_folium(graph_of_stops_Manila, connection, route_map=m, tiles='openstreetmap', route_color="green")

    m.save(f"{map_html_location}GA Map-{i}.html")
    i += 1

# %% [markdown]
# #### Visualization of Allowed Roads for Stops

# %%
filtered_road_map = plot_all_filtered_roads()
filtered_road_map.save(f"{Manila_map_filepath}Allowed_Roads.html")
